# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cd=pd.read_csv('C:/Users/Laptop Shop/Downloads/candyhierarchy2017.csv')

# %%
pd.set_option('display.max_columns',120)
pd.set_option('display.max_rows',120)

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0        90258773            NaN        NaN     NaN         NaN
# 1        90272821             No       Male      44        USA
# 2        90272829            NaN       Male      49         USA
# 3        90272840             No       Male      40          us
# 4        90272841             No       Male      23         usa
# ...           ...            ...        ...     ...         ...
# 2455     90314359             No       Male      24         USA
# 2456     90314580             No     Female      33         USA
# 2457     90314634             No     Female      26        USA
# 2458     90314658             No       Male      58         Usa
# 2459     90314802             No     Female      66         usa
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                                 NaN                NaN
# 1                                  NM                MEH
# 2                            Virginia                NaN
# 3                                  or                MEH
# 4                            exton pa                JOY
# ...                               ...                ...
# 2455                               MD                JOY
# 2456                         New York                MEH
# 2457                        Tennessee                MEH
# 2458                   North Carolina                NaN
# 2459                     Pennsylvania            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                   NaN
# 1                                               DESPAIR
# 2                                                   NaN
# 3                                               DESPAIR
# 4                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 0                              NaN              NaN                      NaN
# 1                              JOY              MEH                  DESPAIR
# 2                              NaN              NaN                      NaN
# 3                              JOY              MEH                      MEH
# 4                              JOY          DESPAIR                      MEH
# ...                            ...              ...                      ...
# 2455                           MEH          DESPAIR                  DESPAIR
# 2456                           JOY              NaN                      NaN
# 2457                           JOY          DESPAIR                      MEH
# 2458                           NaN              NaN                      NaN
# 2459                           JOY          DESPAIR                  DESPAIR
#
#      Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 0                              NaN              NaN                NaN
# 1                          DESPAIR          DESPAIR            DESPAIR
# 2                              NaN              NaN                NaN
# 3                          DESPAIR              MEH            DESPAIR
# 4                          DESPAIR              MEH            DESPAIR
# ...                            ...              ...                ...
# 2455                           MEH              MEH            DESPAIR
# 2456                           NaN              NaN            DESPAIR
# 2457                           JOY          DESPAIR                MEH
# 2458                           NaN              NaN                NaN
# 2459                       DESPAIR          DESPAIR                MEH
#
#      Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 0                       NaN               NaN                     NaN
# 1                   DESPAIR           DESPAIR                     MEH
# 2                       NaN               NaN                     NaN
# 3                   DESPAIR               MEH                     MEH
# 4                   DESPAIR               MEH                     MEH
# ...                     ...               ...                     ...
# 2455                DESPAIR               MEH                 DESPAIR
# 2456                DESPAIR               JOY                     JOY
# 2457                    MEH           DESPAIR                     JOY
# 2458                    NaN               NaN                     NaN
# 2459                DESPAIR               JOY                     MEH
#
#      Q6 | Candy Corn  \
# 0                NaN
# 1                MEH
# 2                NaN
# 3            DESPAIR
# 4            DESPAIR
# ...              ...
# 2455         DESPAIR
# 2456             JOY
# 2457         DESPAIR
# 2458             NaN
# 2459             MEH
#
#      Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 0                                                   NaN
# 1                                               DESPAIR
# 2                                                   NaN
# 3                                               DESPAIR
# 4                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                                MEH
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Caramellos Q6 | Cash, or other forms of legal tender  \
# 0                NaN                                       NaN
# 1                MEH                                       JOY
# 2                NaN                                       NaN
# 3                MEH                                       JOY
# 4                JOY                                       MEH
# ...              ...                                       ...
# 2455             JOY                                       JOY
# 2456             JOY                                       JOY
# 2457         DESPAIR                                       JOY
# 2458             NaN                                       NaN
# 2459             MEH                                       JOY
#
#      Q6 | Chardonnay Q6 | Chick-o-Sticks (we don’t know what that is)  \
# 0                NaN                                              NaN
# 1                MEH                                          DESPAIR
# 2                NaN                                              NaN
# 3                MEH                                              JOY
# 4                JOY                                          DESPAIR
# ...              ...                                              ...
# 2455             JOY                                              MEH
# 2456             JOY                                              JOY
# 2457             JOY                                              MEH
# 2458             NaN                                              NaN
# 2459             JOY                                          DESPAIR
#
#      Q6 | Chiclets Q6 | Coffee Crisp  \
# 0              NaN               NaN
# 1          DESPAIR           DESPAIR
# 2              NaN               NaN
# 3              MEH           DESPAIR
# 4          DESPAIR               MEH
# ...            ...               ...
# 2455           JOY               JOY
# 2456       DESPAIR               NaN
# 2457           MEH           DESPAIR
# 2458           NaN               NaN
# 2459           MEH           DESPAIR
#
#      Q6 | Creepy Religious comics/Chick Tracts Q6 | Dental paraphenalia  \
# 0                                          NaN                      NaN
# 1                                      DESPAIR                  DESPAIR
# 2                                          NaN                      NaN
# 3                                      DESPAIR                  DESPAIR
# 4                                      DESPAIR                  DESPAIR
# ...                                        ...                      ...
# 2455                                   DESPAIR                      MEH
# 2456                                   DESPAIR                  DESPAIR
# 2457                                   DESPAIR                  DESPAIR
# 2458                                       NaN                      NaN
# 2459                                   DESPAIR                  DESPAIR
#
#      Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 0          NaN            NaN                NaN
# 1          MEH            JOY            DESPAIR
# 2          NaN            NaN                NaN
# 3          JOY            JOY                MEH
# 4          MEH            JOY            DESPAIR
# ...        ...            ...                ...
# 2455   DESPAIR            JOY                MEH
# 2456   DESPAIR            MEH                NaN
# 2457       MEH            JOY                MEH
# 2458       NaN            NaN                NaN
# 2459       JOY            JOY                MEH
#
#      Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 0                                 NaN              NaN                   NaN
# 1                             DESPAIR          DESPAIR               DESPAIR
# 2                                 NaN              NaN                   NaN
# 3                                 MEH              JOY                   JOY
# 4                             DESPAIR          DESPAIR                   MEH
# ...                               ...              ...                   ...
# 2455                              JOY          DESPAIR                   JOY
# 2456                              MEH          DESPAIR                   NaN
# 2457                              JOY              JOY               DESPAIR
# 2458                              NaN              NaN                   NaN
# 2459                          DESPAIR              MEH               DESPAIR
#
#      Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 0                    NaN                          NaN
# 1                    MEH                      DESPAIR
# 2                    NaN                          NaN
# 3                    MEH                      DESPAIR
# 4                    MEH                      DESPAIR
# ...                  ...                          ...
# 2455                 JOY                          JOY
# 2456             DESPAIR                      DESPAIR
# 2457             DESPAIR                      DESPAIR
# 2458                 NaN                          NaN
# 2459                 JOY                      DESPAIR
#
#      Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 0                             NaN             NaN                NaN
# 1                             MEH             MEH            DESPAIR
# 2                             NaN             NaN                NaN
# 3                             JOY             MEH                MEH
# 4                             JOY             MEH            DESPAIR
# ...                           ...             ...                ...
# 2455                          MEH         DESPAIR                MEH
# 2456                          MEH             MEH            DESPAIR
# 2457                          MEH             MEH            DESPAIR
# 2458                          NaN             NaN                NaN
# 2459                          MEH         DESPAIR            DESPAIR
#
#      Q6 | Heath Bar Q6 | Hershey's Dark Chocolate  \
# 0               NaN                           NaN
# 1               MEH                           JOY
# 2               NaN                           NaN
# 3           DESPAIR                           MEH
# 4           DESPAIR                           JOY
# ...             ...                           ...
# 2455        DESPAIR                           JOY
# 2456            JOY                           MEH
# 2457            MEH                           JOY
# 2458            NaN                           NaN
# 2459        DESPAIR                           JOY
#
#      Q6 | Hershey’s Milk Chocolate Q6 | Hershey's Kisses  \
# 0                              NaN                   NaN
# 1                              JOY                   MEH
# 2                              NaN                   NaN
# 3                              MEH                   MEH
# 4                              MEH                   MEH
# ...                            ...                   ...
# 2455                           MEH                   MEH
# 2456                           JOY                   MEH
# 2457                           JOY                   JOY
# 2458                           NaN                   NaN
# 2459                           JOY                   JOY
#
#      Q6 | Hugs (actual physical hugs) Q6 | Jolly Rancher (bad flavor)  \
# 0                                 NaN                             NaN
# 1                             DESPAIR                         DESPAIR
# 2                                 NaN                             NaN
# 3                                 MEH                             MEH
# 4                             DESPAIR                             MEH
# ...                               ...                             ...
# 2455                              JOY                             MEH
# 2456                          DESPAIR                             MEH
# 2457                              MEH                         DESPAIR
# 2458                              NaN                             NaN
# 2459                          DESPAIR                         DESPAIR
#
#      Q6 | Jolly Ranchers (good flavor) Q6 | JoyJoy (Mit Iodine!)  \
# 0                                  NaN                       NaN
# 1                                  MEH                   DESPAIR
# 2                                  NaN                       NaN
# 3                                  MEH                   DESPAIR
# 4                                  JOY                       MEH
# ...                                ...                       ...
# 2455                               MEH                       MEH
# 2456                               JOY                       NaN
# 2457                               JOY                   DESPAIR
# 2458                               NaN                       NaN
# 2459                               MEH                   DESPAIR
#
#      Q6 | Junior Mints Q6 | Senior Mints Q6 | Kale smoothie  \
# 0                  NaN               NaN                NaN
# 1              DESPAIR           DESPAIR            DESPAIR
# 2                  NaN               NaN                NaN
# 3              DESPAIR           DESPAIR            DESPAIR
# 4                  JOY           DESPAIR            DESPAIR
# ...                ...               ...                ...
# 2455           DESPAIR           DESPAIR                MEH
# 2456               JOY               NaN            DESPAIR
# 2457               JOY               MEH            DESPAIR
# 2458               NaN               NaN                NaN
# 2459               JOY           DESPAIR            DESPAIR
#
#      Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy Q6 | LemonHeads  \
# 0                        NaN          NaN             NaN             NaN
# 1                    DESPAIR          JOY         DESPAIR             MEH
# 2                        NaN          NaN             NaN             NaN
# 3                        MEH          MEH             JOY             JOY
# 4                        JOY          JOY             JOY             JOY
# ...                      ...          ...             ...             ...
# 2455                     JOY          JOY             MEH             MEH
# 2456                     NaN          JOY         DESPAIR         DESPAIR
# 2457                 DESPAIR      DESPAIR             JOY         DESPAIR
# 2458                     NaN          NaN             NaN             NaN
# 2459                 DESPAIR          MEH         DESPAIR         DESPAIR
#
#      Q6 | Licorice (not black) Q6 | Licorice (yes black) Q6 | Lindt Truffle  \
# 0                          NaN                       NaN                NaN
# 1                          MEH                       JOY                MEH
# 2                          NaN                       NaN                NaN
# 3                          MEH                       JOY                JOY
# 4                          MEH                   DESPAIR                JOY
# ...                        ...                       ...                ...
# 2455                       JOY                   DESPAIR                JOY
# 2456                       MEH                   DESPAIR                MEH
# 2457                       MEH                   DESPAIR                JOY
# 2458                       NaN                       NaN                NaN
# 2459                   DESPAIR                   DESPAIR                JOY
#
#      Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike Q6 | Milk Duds  \
# 0               NaN       NaN           NaN               NaN            NaN
# 1           DESPAIR   DESPAIR       DESPAIR               MEH            MEH
# 2               NaN       NaN           NaN               NaN            NaN
# 3           DESPAIR       JOY           MEH               MEH        DESPAIR
# 4               MEH       MEH       DESPAIR               MEH            MEH
# ...             ...       ...           ...               ...            ...
# 2455        DESPAIR       MEH           MEH               MEH            JOY
# 2456            MEH       NaN           NaN           DESPAIR            MEH
# 2457            MEH       JOY       DESPAIR               MEH            JOY
# 2458            NaN       NaN           NaN               NaN            NaN
# 2459        DESPAIR       JOY       DESPAIR               MEH        DESPAIR
#
#      Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s Q6 | Blue M&M's  \
# 0               NaN               NaN               NaN             NaN
# 1               JOY               JOY               MEH             JOY
# 2               NaN               NaN               NaN             NaN
# 3               JOY               MEH               JOY             MEH
# 4               JOY               JOY               JOY             JOY
# ...             ...               ...               ...             ...
# 2455            JOY               MEH               JOY             JOY
# 2456            MEH               JOY               JOY             NaN
# 2457            JOY               JOY           DESPAIR             JOY
# 2458            NaN               NaN               NaN             NaN
# 2459            JOY               JOY               JOY             JOY
#
#      Q6 | Red M&M's Q6 | Green Party M&M's Q6 | Independent M&M's  \
# 0               NaN                    NaN                    NaN
# 1               JOY                    JOY                    JOY
# 2               NaN                    NaN                    NaN
# 3               MEH                    MEH                    MEH
# 4               JOY                    JOY                    JOY
# ...             ...                    ...                    ...
# 2455            MEH                    JOY                    JOY
# 2456            NaN                    NaN                    NaN
# 2457            JOY                    JOY                    JOY
# 2458            NaN                    NaN                    NaN
# 2459            JOY                    JOY                DESPAIR
#
#      Q6 | Abstained from M&M'ing. Q6 | Minibags of chips Q6 | Mint Kisses  \
# 0                             NaN                    NaN              NaN
# 1                         DESPAIR                DESPAIR              MEH
# 2                             NaN                    NaN              NaN
# 3                             MEH                DESPAIR          DESPAIR
# 4                             MEH                DESPAIR              JOY
# ...                           ...                    ...              ...
# 2455                          MEH                    MEH              JOY
# 2456                          NaN                    MEH              JOY
# 2457                      DESPAIR                    JOY              JOY
# 2458                          NaN                    NaN              NaN
# 2459                      DESPAIR                    MEH              MEH
#
#      Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers Q6 | Nerds  \
# 0                 NaN              NaN               NaN        NaN
# 1             DESPAIR          DESPAIR           DESPAIR    DESPAIR
# 2                 NaN              NaN               NaN        NaN
# 3                 MEH              MEH           DESPAIR        MEH
# 4                 JOY              MEH           DESPAIR        JOY
# ...               ...              ...               ...        ...
# 2455              JOY              JOY               MEH        MEH
# 2456              NaN              JOY           DESPAIR        JOY
# 2457              JOY          DESPAIR           DESPAIR        MEH
# 2458              NaN              NaN               NaN        NaN
# 2459          DESPAIR              JOY               MEH    DESPAIR
#
#      Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 0                   NaN               NaN        NaN          NaN
# 1                   JOY           DESPAIR    DESPAIR      DESPAIR
# 2                   NaN               NaN        NaN          NaN
# 3                   MEH               MEH    DESPAIR      DESPAIR
# 4                   JOY               JOY        MEH      DESPAIR
# ...                 ...               ...        ...          ...
# 2455                JOY               JOY    DESPAIR      DESPAIR
# 2456                MEH               JOY    DESPAIR      DESPAIR
# 2457            DESPAIR               MEH        MEH          MEH
# 2458                NaN               NaN        NaN          NaN
# 2459                MEH           DESPAIR        MEH      DESPAIR
#
#      Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 0               NaN                                                NaN
# 1           DESPAIR                                            DESPAIR
# 2               NaN                                                NaN
# 3           DESPAIR                                            DESPAIR
# 4               JOY                                            DESPAIR
# ...             ...                                                ...
# 2455            JOY                                                MEH
# 2456            MEH                                            DESPAIR
# 2457            JOY                                                JOY
# 2458            NaN                                                NaN
# 2459        DESPAIR                                            DESPAIR
#
#      Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces  \
# 0                                NaN                 NaN
# 1                                JOY                 JOY
# 2                                NaN                 NaN
# 3                                JOY                 MEH
# 4                                JOY                 JOY
# ...                              ...                 ...
# 2455                             JOY                 JOY
# 2456                             JOY                 JOY
# 2457                             JOY                 MEH
# 2458                             NaN                 NaN
# 2459                             MEH             DESPAIR
#
#      Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 0                        NaN        NaN
# 1                    DESPAIR        JOY
# 2                        NaN        NaN
# 3                        MEH        MEH
# 4                        MEH        JOY
# ...                      ...        ...
# 2455                     JOY        JOY
# 2456                     NaN        MEH
# 2457                     MEH        JOY
# 2458                     NaN        NaN
# 2459                 DESPAIR    DESPAIR
#
#      Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 0                                                   NaN             NaN
# 1                                               DESPAIR         DESPAIR
# 2                                                   NaN             NaN
# 3                                               DESPAIR         DESPAIR
# 4                                                   NaN             JOY
# ...                                                 ...             ...
# 2455                                                JOY             MEH
# 2456                                            DESPAIR             JOY
# 2457                                            DESPAIR         DESPAIR
# 2458                                                NaN             NaN
# 2459                                            DESPAIR         DESPAIR
#
#      Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 0                         NaN                          NaN           NaN
# 1                     DESPAIR                      DESPAIR           MEH
# 2                         NaN                          NaN           NaN
# 3                     DESPAIR                          MEH           JOY
# 4                         JOY                      DESPAIR           NaN
# ...                       ...                          ...           ...
# 2455                  DESPAIR                      DESPAIR           JOY
# 2456                  DESPAIR                          NaN           JOY
# 2457                      JOY                          MEH       DESPAIR
# 2458                      NaN                          NaN           NaN
# 2459                      MEH                      DESPAIR           JOY
#
#      Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 0                                                  NaN               NaN
# 1                                              DESPAIR           DESPAIR
# 2                                                  NaN               NaN
# 3                                                  MEH           DESPAIR
# 4                                                  MEH           DESPAIR
# ...                                                ...               ...
# 2455                                               JOY               JOY
# 2456                                               MEH               NaN
# 2457                                           DESPAIR           DESPAIR
# 2458                                               NaN               NaN
# 2459                                               JOY           DESPAIR
#
#      Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 0               NaN              NaN               NaN
# 1               MEH          DESPAIR               MEH
# 2               NaN              NaN               NaN
# 3               MEH              MEH               JOY
# 4               JOY              JOY               MEH
# ...             ...              ...               ...
# 2455            JOY              MEH               JOY
# 2456            MEH              MEH               MEH
# 2457        DESPAIR              JOY           DESPAIR
# 2458            NaN              NaN               NaN
# 2459            MEH              MEH           DESPAIR
#
#      Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 0                                     NaN         NaN           NaN
# 1                                 DESPAIR     DESPAIR       DESPAIR
# 2                                     NaN         NaN           NaN
# 3                                     MEH         JOY           MEH
# 4                                 DESPAIR         MEH       DESPAIR
# ...                                   ...         ...           ...
# 2455                              DESPAIR         MEH           JOY
# 2456                                  NaN         JOY       DESPAIR
# 2457                              DESPAIR         MEH           MEH
# 2458                                  NaN         NaN           NaN
# 2459                              DESPAIR     DESPAIR       DESPAIR
#
#      Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 0                                                NaN                   NaN
# 1                                            DESPAIR                   JOY
# 2                                                NaN                   NaN
# 3                                            DESPAIR               DESPAIR
# 4                                            DESPAIR                   JOY
# ...                                              ...                   ...
# 2455                                         DESPAIR                   MEH
# 2456                                         DESPAIR                   MEH
# 2457                                         DESPAIR                   JOY
# 2458                                             NaN                   NaN
# 2459                                         DESPAIR                   JOY
#
#      Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 0                                  NaN            NaN       NaN
# 1                                  JOY        DESPAIR       JOY
# 2                                  NaN            NaN       NaN
# 3                                  JOY            MEH       JOY
# 4                                  JOY        DESPAIR       JOY
# ...                                ...            ...       ...
# 2455                               MEH            JOY       JOY
# 2456                               MEH        DESPAIR       JOY
# 2457                               JOY            MEH       MEH
# 2458                               NaN            NaN       NaN
# 2459                               MEH        DESPAIR   DESPAIR
#
#      Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 0                                                   NaN
# 1                                               DESPAIR
# 2                                                   NaN
# 3                                               DESPAIR
# 4                                                   MEH
# ...                                                 ...
# 2455                                                MEH
# 2456                                                NaN
# 2457                                                MEH
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 0             NaN                       NaN              NaN
# 1         DESPAIR                   DESPAIR          DESPAIR
# 2             NaN                       NaN              NaN
# 3             JOY                       JOY          DESPAIR
# 4             JOY                       JOY          DESPAIR
# ...           ...                       ...              ...
# 2455          JOY                   DESPAIR              MEH
# 2456          NaN                       JOY          DESPAIR
# 2457          JOY                       MEH          DESPAIR
# 2458          NaN                       NaN              NaN
# 2459          JOY                   DESPAIR              MEH
#
#      Q6 | Whole Wheat anything Q6 | York Peppermint Patties  \
# 0                          NaN                          NaN
# 1                      DESPAIR                      DESPAIR
# 2                          NaN                          NaN
# 3                      DESPAIR                      DESPAIR
# 4                      DESPAIR                          JOY
# ...                        ...                          ...
# 2455                   DESPAIR                          MEH
# 2456                       MEH                          JOY
# 2457                   DESPAIR                          MEH
# 2458                       NaN                          NaN
# 2459                   DESPAIR                          JOY
#
#                                           Q7: JOY OTHER Q8: DESPAIR OTHER  \
# 0                                                   NaN               NaN
# 1                                                Mounds               NaN
# 2                                                   NaN               NaN
# 3     Reese's crispy crunchy bars, 5th avenue bars, ...               NaN
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 2455                                             Mounds  Fruit Stripe Gum
# 2456                                                NaN            Capers
# 2457  Tiny bottles of maple syrup as given out by Cr...               NaN
# 2458                                                NaN               NaN
# 2459                                                NaN               NaN
#
#                                      Q9: OTHER COMMENTS      Q10: DRESS  \
# 0                                                   NaN             NaN
# 1     Bottom line is Twix is really the only candy w...  White and gold
# 2                                                   NaN             NaN
# 3                                Raisins can go to hell  White and gold
# 4                                                   NaN  White and gold
# ...                                                 ...             ...
# 2455                                                NaN  White and gold
# 2456                                                NaN  Blue and black
# 2457                                                NaN  Blue and black
# 2458                                                NaN             NaN
# 2459  You hit all my chocolate highlights, and broug...  White and gold
#
#      Unnamed: 113 Q11: DAY  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# 0             NaN      NaN                      NaN                   NaN
# 1             NaN   Sunday                      NaN                   1.0
# 2             NaN      NaN                      NaN                   NaN
# 3             NaN   Sunday                      NaN                   1.0
# 4             NaN   Friday                      NaN                   1.0
# ...           ...      ...                      ...                   ...
# 2455          NaN   Friday                      NaN                   NaN
# 2456          NaN   Friday                      NaN                   1.0
# 2457          NaN   Friday                      NaN                   1.0
# 2458          NaN      NaN                      NaN                   NaN
# 2459          NaN   Sunday                      1.0                   NaN
#
#       Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 0                   NaN                 NaN                      NaN
# 1                   NaN                 NaN                 (84, 25)
# 2                   NaN                 NaN                      NaN
# 3                   NaN                 NaN                 (75, 23)
# 4                   NaN                 NaN                 (70, 10)
# ...                 ...                 ...                      ...
# 2455                NaN                 NaN                      NaN
# 2456                NaN                 NaN                 (70, 26)
# 2457                NaN                 NaN                 (67, 35)
# 2458                NaN                 NaN                      NaN
# 2459                NaN                 NaN                 (19, 26)
#
# [2460 rows x 120 columns]

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Columns: 120 entries, Internal ID to Click Coordinates (x, y)
# dtypes: float64(4), int64(1), object(115)
# memory usage: 2.3+ MB

# %%
cd.drop(['Unnamed: 113'],axis=1,inplace=True)

# %%
for i in cd:
    print(cd[i].value_counts())
# Out:
# 90273795    1
# 90277365    1
# 90279452    1
# 90274486    1
# 90277176    1
#            ..
# 90273164    1
# 90275215    1
# 90277264    1
# 90288432    1
# 90277887    1
# Name: Internal ID, Length: 2460, dtype: int64
# No     2038
# Yes     312
# Name: Q1: GOING OUT?, dtype: int64
# Male                  1467
# Female                 839
# I'd rather not say      83
# Other                   30
# Name: Q2: GENDER, dtype: int64
# 40                                                  92
# 34                                                  90
# 37                                                  89
# 43                                                  86
# 36                                                  79
# 42                                                  79
# 35                                                  77
# 44                                                  76
# 38                                                  76
# 45                                                  75
# 33                                                  75
# 41                                                  74
# 50                                                  71
# 49                                                  69
# 39                                                  69
# 32                                                  68
# 48                                                  64
# 47                                                  63
# 30                                                  62
# 53                                                  57
# 46                                                  55
# 52                                                  50
# 56                                                  46
# 27                                                  45
# 31                                                  45
# 51                                                  41
# 28                                                  37
# 54                                                  36
# 58                                                  34
# 55                                                  32
# 60                                                  31
# 29                                                  27
# 57                                                  25
# 59                                                  24
# 26                                                  23
# 63                                                  20
# 62                                                  20
# 61                                                  20
# 25                                                  19
# 64                                                  17
# 24                                                  16
# 21                                                  14
# 65                                                  13
# 20                                                  12
# 22                                                  11
# 18                                                  10
# 23                                                   9
# 12                                                   9
# 66                                                   9
# 68                                                   8
# 15                                                   8
# 70                                                   8
# 11                                                   7
# 67                                                   6
# 71                                                   6
# 72                                                   6
# 13                                                   6
# 17                                                   5
# 69                                                   5
# 16                                                   4
# 9                                                    4
# 73                                                   4
# 75                                                   3
# 19                                                   3
# 10                                                   3
# 7                                                    2
# 8                                                    2
# 76                                                   2
# 14                                                   2
# 6                                                    2
# old                                                  2
# 100                                                  2
# 90                                                   2
# no                                                   1
# 46 Halloweens.                                       1
# 70 1/2                                               1
# older than dirt                                      1
# sixty-nine                                           1
# MY NAME JEFF                                         1
# 1000                                                 1
# 39.4                                                 1
# 74                                                   1
# old enough                                           1
# hahahahaha                                           1
# your mom                                             1
# ancient                                              1
# OLD                                                  1
# See question 2                                       1
# 24-50                                                1
# 99                                                   1
# 45-55                                                1
# 88                                                   1
# Many                                                 1
# 77                                                   1
# 5u                                                   1
# 102                                                  1
# 60+                                                  1
# 1                                                    1
# Enough                                               1
# 59 on the day after Halloween                        1
# 312                                                  1
# I can remember when Java was a cool new language     1
# Old enough                                           1
# ?                                                    1
# Over 50                                              1
# 4                                                    1
# Name: Q3: AGE, dtype: int64
# USA              699
# United States    497
# usa              217
# Canada           179
# Usa              139
#                 ...
# 'merica            1
# A                  1
# 1                  1
# UAE                1
# UK                 1
# Name: Q4: COUNTRY, Length: 128, dtype: int64
# California           132
# CA                    89
# Texas                 60
# Ontario               56
# Illinois              55
#                     ...
# Ontario,  Canada       1
# FL, Orange County      1
# in                     1
# California, USA        1
# ont                    1
# Name: Q5: STATE, PROVINCE, COUNTY, ETC, Length: 511, dtype: int64
# JOY        873
# MEH        755
# DESPAIR     85
# Name: Q6 | 100 Grand Bar, dtype: int64
# DESPAIR    1089
# MEH         461
# JOY         176
# Name: Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes), dtype: int64
# JOY        1559
# MEH         212
# DESPAIR      17
# Name: Q6 | Any full-sized candy bar, dtype: int64
# DESPAIR    793
# MEH        617
# JOY         92
# Name: Q6 | Black Jacks, dtype: int64
# MEH        857
# DESPAIR    495
# JOY        116
# Name: Q6 | Bonkers (the candy), dtype: int64
# MEH        715
# DESPAIR    546
# JOY        193
# Name: Q6 | Bonkers (the board game), dtype: int64
# MEH        670
# DESPAIR    560
# JOY        465
# Name: Q6 | Bottle Caps, dtype: int64
# DESPAIR    1179
# MEH         476
# JOY         117
# Name: Q6 | Box'o'Raisins, dtype: int64
# DESPAIR    1625
# MEH         105
# JOY          24
# Name: Q6 | Broken glow stick, dtype: int64
# JOY        1177
# MEH         460
# DESPAIR     141
# Name: Q6 | Butterfinger, dtype: int64
# JOY        820
# MEH        562
# DESPAIR    395
# Name: Q6 | Cadbury Creme Eggs, dtype: int64
# DESPAIR    743
# MEH        561
# JOY        478
# Name: Q6 | Candy Corn, dtype: int64
# DESPAIR    1325
# MEH         405
# JOY          39
# Name: Q6 | Candy that is clearly just the stuff given out for free at restaurants, dtype: int64
# JOY        953
# MEH        592
# DESPAIR    163
# Name: Q6 | Caramellos, dtype: int64
# JOY        1439
# MEH         276
# DESPAIR      65
# Name: Q6 | Cash, or other forms of legal tender, dtype: int64
# JOY        1040
# MEH         360
# DESPAIR     317
# Name: Q6 | Chardonnay, dtype: int64
# DESPAIR    644
# MEH        571
# JOY        299
# Name: Q6 | Chick-o-Sticks (we don’t know what that is), dtype: int64
# DESPAIR    761
# MEH        744
# JOY        244
# Name: Q6 | Chiclets, dtype: int64
# MEH        592
# DESPAIR    541
# JOY        474
# Name: Q6 | Coffee Crisp, dtype: int64
# DESPAIR    1406
# JOY         246
# MEH         104
# Name: Q6 | Creepy Religious comics/Chick Tracts, dtype: int64
# DESPAIR    1433
# MEH         244
# JOY          91
# Name: Q6 | Dental paraphenalia, dtype: int64
# DESPAIR    664
# MEH        657
# JOY        410
# Name: Q6 | Dots, dtype: int64
# JOY        1176
# MEH         474
# DESPAIR     108
# Name: Q6 | Dove Bars, dtype: int64
# DESPAIR    676
# MEH        559
# JOY        402
# Name: Q6 | Fuzzy Peaches, dtype: int64
# DESPAIR    1176
# MEH         391
# JOY         162
# Name: Q6 | Generic Brand Acetaminophen, dtype: int64
# MEH        703
# JOY        612
# DESPAIR    448
# Name: Q6 | Glow sticks, dtype: int64
# MEH        708
# DESPAIR    464
# JOY        409
# Name: Q6 | Goo Goo Clusters, dtype: int64
# DESPAIR    742
# MEH        576
# JOY        408
# Name: Q6 | Good N' Plenty, dtype: int64
# DESPAIR    1462
# MEH         238
# JOY          44
# Name: Q6 | Gum from baseball cards, dtype: int64
# JOY        748
# MEH        584
# DESPAIR    431
# Name: Q6 | Gummy Bears straight up, dtype: int64
# MEH        907
# DESPAIR    586
# JOY        272
# Name: Q6 | Hard Candy, dtype: int64
# DESPAIR    855
# MEH        683
# JOY        228
# Name: Q6 | Healthy Fruit, dtype: int64
# JOY        1069
# MEH         466
# DESPAIR     213
# Name: Q6 | Heath Bar, dtype: int64
# JOY        1105
# MEH         507
# DESPAIR     175
# Name: Q6 | Hershey's Dark Chocolate, dtype: int64
# JOY        896
# MEH        667
# DESPAIR    225
# Name: Q6 | Hershey’s Milk Chocolate, dtype: int64
# JOY        834
# MEH        726
# DESPAIR    222
# Name: Q6 | Hershey's Kisses, dtype: int64
# DESPAIR    889
# JOY        433
# MEH        425
# Name: Q6 | Hugs (actual physical hugs), dtype: int64
# DESPAIR    1061
# MEH         607
# JOY          98
# Name: Q6 | Jolly Rancher (bad flavor), dtype: int64
# JOY        747
# MEH        638
# DESPAIR    380
# Name: Q6 | Jolly Ranchers (good flavor), dtype: int64
# DESPAIR    956
# MEH        402
# JOY         76
# Name: Q6 | JoyJoy (Mit Iodine!), dtype: int64
# JOY        1020
# MEH         496
# DESPAIR     246
# Name: Q6 | Junior Mints, dtype: int64
# DESPAIR    895
# MEH        472
# JOY        151
# Name: Q6 | Senior Mints, dtype: int64
# DESPAIR    1435
# MEH         173
# JOY         108
# Name: Q6 | Kale smoothie, dtype: int64
# DESPAIR    570
# JOY        503
# MEH        442
# Name: Q6 | Kinder Happy Hippo, dtype: int64
# JOY        1447
# MEH         287
# DESPAIR      52
# Name: Q6 | Kit Kat, dtype: int64
# MEH        729
# DESPAIR    545
# JOY        450
# Name: Q6 | LaffyTaffy, dtype: int64
# MEH        690
# JOY        670
# DESPAIR    370
# Name: Q6 | LemonHeads, dtype: int64
# MEH        707
# JOY        557
# DESPAIR    510
# Name: Q6 | Licorice (not black), dtype: int64
# DESPAIR    902
# JOY        543
# MEH        330
# Name: Q6 | Licorice (yes black), dtype: int64
# JOY        1277
# MEH         367
# DESPAIR      98
# Name: Q6 | Lindt Truffle, dtype: int64
# MEH        931
# DESPAIR    474
# JOY        364
# Name: Q6 | Lollipops, dtype: int64
# JOY        1026
# MEH         587
# DESPAIR     122
# Name: Q6 | Mars, dtype: int64
# MEH        709
# DESPAIR    579
# JOY        148
# Name: Q6 | Maynards, dtype: int64
# MEH        647
# DESPAIR    550
# JOY        534
# Name: Q6 | Mike and Ike, dtype: int64
# JOY        878
# MEH        639
# DESPAIR    250
# Name: Q6 | Milk Duds, dtype: int64
# JOY        1185
# MEH         485
# DESPAIR     102
# Name: Q6 | Milky Way, dtype: int64
# JOY        1122
# MEH         588
# DESPAIR      75
# Name: Q6 | Regular M&Ms, dtype: int64
# JOY        1291
# MEH         377
# DESPAIR     121
# Name: Q6 | Peanut M&M’s, dtype: int64
# JOY        1018
# MEH         595
# DESPAIR     120
# Name: Q6 | Blue M&M's, dtype: int64
# JOY        1001
# MEH         606
# DESPAIR     124
# Name: Q6 | Red M&M's, dtype: int64
# JOY        972
# MEH        587
# DESPAIR    137
# Name: Q6 | Green Party M&M's, dtype: int64
# JOY        757
# MEH        626
# DESPAIR    264
# Name: Q6 | Independent M&M's, dtype: int64
# DESPAIR    693
# MEH        607
# JOY        218
# Name: Q6 | Abstained from M&M'ing., dtype: int64
# MEH        759
# JOY        537
# DESPAIR    440
# Name: Q6 | Minibags of chips, dtype: int64
# MEH        644
# JOY        619
# DESPAIR    421
# Name: Q6 | Mint Kisses, dtype: int64
# JOY        904
# DESPAIR    413
# MEH        332
# Name: Q6 | Mint Juleps, dtype: int64
# JOY        857
# MEH        643
# DESPAIR    220
# Name: Q6 | Mr. Goodbar, dtype: int64
# DESPAIR    805
# MEH        558
# JOY        353
# Name: Q6 | Necco Wafers, dtype: int64
# JOY        769
# MEH        609
# DESPAIR    359
# Name: Q6 | Nerds, dtype: int64
# JOY        1188
# MEH         472
# DESPAIR     102
# Name: Q6 | Nestle Crunch, dtype: int64
# MEH        725
# DESPAIR    557
# JOY        361
# Name: Q6 | Now'n'Laters, dtype: int64
# DESPAIR    1085
# MEH         426
# JOY         239
# Name: Q6 | Peeps, dtype: int64
# DESPAIR    1076
# MEH         494
# JOY         181
# Name: Q6 | Pencils, dtype: int64
# MEH        649
# DESPAIR    546
# JOY        543
# Name: Q6 | Pixy Stix, dtype: int64
# DESPAIR    1480
# MEH         136
# JOY          91
# Name: Q6 | Real Housewives of Orange County Season 9 Blue-Ray, dtype: int64
# JOY        1498
# MEH         188
# DESPAIR      95
# Name: Q6 | Reese’s Peanut Butter Cups, dtype: int64
# JOY        1136
# MEH         465
# DESPAIR     168
# Name: Q6 | Reese's Pieces, dtype: int64
# MEH        706
# DESPAIR    486
# JOY        254
# Name: Q6 | Reggie Jackson Bar, dtype: int64
# JOY        1151
# MEH         455
# DESPAIR     140
# Name: Q6 | Rolos, dtype: int64
# DESPAIR    1151
# MEH         322
# JOY         211
# Name: Q6 | Sandwich-sized bags filled with BooBerry Crunch, dtype: int64
# JOY        829
# MEH        604
# DESPAIR    321
# Name: Q6 | Skittles, dtype: int64
# JOY        729
# MEH        581
# DESPAIR    425
# Name: Q6 | Smarties (American), dtype: int64
# MEH        605
# JOY        539
# DESPAIR    415
# Name: Q6 | Smarties (Commonwealth), dtype: int64
# JOY        1399
# MEH         292
# DESPAIR      79
# Name: Q6 | Snickers, dtype: int64
# JOY        770
# DESPAIR    511
# MEH        441
# Name: Q6 | Sourpatch Kids (i.e. abominations of nature), dtype: int64
# DESPAIR    1140
# MEH         310
# JOY         128
# Name: Q6 | Spotted Dick, dtype: int64
# JOY        853
# MEH        615
# DESPAIR    299
# Name: Q6 | Starburst, dtype: int64
# JOY        783
# MEH        610
# DESPAIR    359
# Name: Q6 | Sweet Tarts, dtype: int64
# JOY        754
# MEH        542
# DESPAIR    449
# Name: Q6 | Swedish Fish, dtype: int64
# DESPAIR    763
# MEH        544
# JOY        151
# Name: Q6 | Sweetums (a friend to diabetes), dtype: int64
# MEH        613
# JOY        577
# DESPAIR    353
# Name: Q6 | Take 5, dtype: int64
# DESPAIR    754
# MEH        728
# JOY        264
# Name: Q6 | Tic Tacs, dtype: int64
# DESPAIR    1252
# MEH         283
# JOY         189
# Name: Q6 | Those odd marshmallow circus peanut things, dtype: int64
# JOY        1058
# MEH         518
# DESPAIR     176
# Name: Q6 | Three Musketeers, dtype: int64
# JOY        1320
# MEH         350
# DESPAIR      84
# Name: Q6 | Tolberone something or other, dtype: int64
# DESPAIR    836
# MEH        688
# JOY        228
# Name: Q6 | Trail Mix, dtype: int64
# JOY        1413
# MEH         286
# DESPAIR      71
# Name: Q6 | Twix, dtype: int64
# DESPAIR    1146
# MEH         289
# JOY         233
# Name: Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein, dtype: int64
# DESPAIR    723
# JOY        707
# MEH        241
# Name: Q6 | Vicodin, dtype: int64
# JOY        840
# MEH        509
# DESPAIR    288
# Name: Q6 | Whatchamacallit Bars, dtype: int64
# DESPAIR    1455
# MEH         204
# JOY          44
# Name: Q6 | White Bread, dtype: int64
# DESPAIR    1289
# MEH         307
# JOY         117
# Name: Q6 | Whole Wheat anything, dtype: int64
# JOY        1105
# MEH         418
# DESPAIR     232
# Name: Q6 | York Peppermint Patties, dtype: int64
# Beer                                                                                                                    10
# Almond Joy                                                                                                              10
# beer                                                                                                                     3
# Mounds, Almond Joy                                                                                                       3
# Sex                                                                                                                      3
#                                                                                                                         ..
# using my elbows to get in front of the little kids in line.                                                              1
# Lady Godiva chocolates, Belgian chocolates, Bourbon Balls                                                                1
# Safety suckers. I don't know what it is about the flavoring used for those loop-sticked suckers, but they are great!     1
# Math and sciences, technology, the girl I like (with out her boy friend), soccer, running.                               1
# Dairy Milk                                                                                                               1
# Name: Q7: JOY OTHER, Length: 867, dtype: int64
# Trump                                                                                                                    7
# Tootsie Rolls                                                                                                            3
# Popcorn balls                                                                                                            3
# Almond Joy, Mounds                                                                                                       3
# Pennies                                                                                                                  3
#                                                                                                                         ..
# Mike and Ike Bounty bar                                                                                                  1
# Heroin                                                                                                                   1
# 5 hour energy drink                                                                                                      1
# that goddamn molasses candy that tasted like earwax and stuck to the wrapper, chicken bones, grape flavoured anything    1
# Anything with gluten (Celiac) Cheap nasty chocolate (e.g. pretty much anything mass produced)                            1
# Name: Q8: DESPAIR OTHER, Length: 685, dtype: int64
# nom nom nom!                                                                                                                                                                                                                                                                                                                                                                                2
# The moment I realized you expected me to evaluate what might be over 100 items I stopped. Follow this link to see a better approach to evaluating a large list of items: http://walthickey.com/2017/10/18/whats-the-best-halloween-candy/  It's essentially random pairwise comparison. Allourideas.org provides a similar platform but allows users too add their own items. Good luck!    1
# Smarties (Commonwealth) are awesome. Sweetums is a blight upon the fair town of Pawnee.                                                                                                                                                                                                                                                                                                     1
# Bad chocolate candy is somehow better than bad fruit-flavored candy.                                                                                                                                                                                                                                                                                                                        1
# Why?                                                                                                                                                                                                                                                                                                                                                                                        1
#                                                                                                                                                                                                                                                                                                                                                                                            ..
# snickers #1                                                                                                                                                                                                                                                                                                                                                                                 1
# Why no spare change?  More vegan options?  What about " patriotic or politically themed plastic tchotchke "?                                                                                                                                                                                                                                                                                1
# No.                                                                                                                                                                                                                                                                                                                                                                                         1
# no rockets listed?                                                                                                                                                                                                                                                                                                                                                                          1
# Wouldn't it be something if people gave out fried chicken on Halloween?                                                                                                                                                                                                                                                                                                                     1
# Name: Q9: OTHER COMMENTS, Length: 385, dtype: int64
# White and gold    1081
# Blue and black     635
# Name: Q10: DRESS, dtype: int64
# Friday    1091
# Sunday     644
# Name: Q11: DAY, dtype: int64
# 1.0    85
# Name: Q12: MEDIA [Daily Dish], dtype: int64
# 1.0    1362
# Name: Q12: MEDIA [Science], dtype: int64
# 1.0    99
# Name: Q12: MEDIA [ESPN], dtype: int64
# 1.0    67
# Name: Q12: MEDIA [Yahoo], dtype: int64
# (77, 24)    9
# (77, 26)    8
# (78, 22)    7
# (73, 26)    7
# (77, 30)    7
#            ..
# (87, 22)    1
# (88, 39)    1
# (30, 33)    1
# (30, 27)    1
# (80, 61)    1
# Name: Click Coordinates (x, y), Length: 952, dtype: int64

# %%
cd.dropna(subset=['Q1: GOING OUT?'],inplace=True)

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male      44        USA
# 3        90272840             No       Male      40          us
# 4        90272841             No       Male      23         usa
# 5        90272852             No       Male     NaN         NaN
# 6        90272853             No       Male      53         usa
# ...           ...            ...        ...     ...         ...
# 2455     90314359             No       Male      24         USA
# 2456     90314580             No     Female      33         USA
# 2457     90314634             No     Female      26        USA
# 2458     90314658             No       Male      58         Usa
# 2459     90314802             No     Female      66         usa
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 1                                  NM                MEH
# 3                                  or                MEH
# 4                            exton pa                JOY
# 5                                 NaN                JOY
# 6                           Colorado                 NaN
# ...                               ...                ...
# 2455                               MD                JOY
# 2456                         New York                MEH
# 2457                        Tennessee                MEH
# 2458                   North Carolina                NaN
# 2459                     Pennsylvania            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 5                                               DESPAIR
# 6                                                   NaN
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 1                              JOY              MEH                  DESPAIR
# 3                              JOY              MEH                      MEH
# 4                              JOY          DESPAIR                      MEH
# 5                              JOY              NaN                      NaN
# 6                              NaN              NaN                      NaN
# ...                            ...              ...                      ...
# 2455                           MEH          DESPAIR                  DESPAIR
# 2456                           JOY              NaN                      NaN
# 2457                           JOY          DESPAIR                      MEH
# 2458                           NaN              NaN                      NaN
# 2459                           JOY          DESPAIR                  DESPAIR
#
#      Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 1                          DESPAIR          DESPAIR            DESPAIR
# 3                          DESPAIR              MEH            DESPAIR
# 4                          DESPAIR              MEH            DESPAIR
# 5                              NaN              MEH                MEH
# 6                              NaN              NaN                NaN
# ...                            ...              ...                ...
# 2455                           MEH              MEH            DESPAIR
# 2456                           NaN              NaN            DESPAIR
# 2457                           JOY          DESPAIR                MEH
# 2458                           NaN              NaN                NaN
# 2459                       DESPAIR          DESPAIR                MEH
#
#      Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 1                   DESPAIR           DESPAIR                     MEH
# 3                   DESPAIR               MEH                     MEH
# 4                   DESPAIR               MEH                     MEH
# 5                   DESPAIR               JOY                 DESPAIR
# 6                       NaN               NaN                     NaN
# ...                     ...               ...                     ...
# 2455                DESPAIR               MEH                 DESPAIR
# 2456                DESPAIR               JOY                     JOY
# 2457                    MEH           DESPAIR                     JOY
# 2458                    NaN               NaN                     NaN
# 2459                DESPAIR               JOY                     MEH
#
#      Q6 | Candy Corn  \
# 1                MEH
# 3            DESPAIR
# 4            DESPAIR
# 5                MEH
# 6                NaN
# ...              ...
# 2455         DESPAIR
# 2456             JOY
# 2457         DESPAIR
# 2458             NaN
# 2459             MEH
#
#      Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 5                                                   MEH
# 6                                                   NaN
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                                MEH
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Caramellos Q6 | Cash, or other forms of legal tender  \
# 1                MEH                                       JOY
# 3                MEH                                       JOY
# 4                JOY                                       MEH
# 5                JOY                                       JOY
# 6                NaN                                       NaN
# ...              ...                                       ...
# 2455             JOY                                       JOY
# 2456             JOY                                       JOY
# 2457         DESPAIR                                       JOY
# 2458             NaN                                       NaN
# 2459             MEH                                       JOY
#
#      Q6 | Chardonnay Q6 | Chick-o-Sticks (we don’t know what that is)  \
# 1                MEH                                          DESPAIR
# 3                MEH                                              JOY
# 4                JOY                                          DESPAIR
# 5                JOY                                              MEH
# 6                NaN                                              NaN
# ...              ...                                              ...
# 2455             JOY                                              MEH
# 2456             JOY                                              JOY
# 2457             JOY                                              MEH
# 2458             NaN                                              NaN
# 2459             JOY                                          DESPAIR
#
#      Q6 | Chiclets Q6 | Coffee Crisp  \
# 1          DESPAIR           DESPAIR
# 3              MEH           DESPAIR
# 4          DESPAIR               MEH
# 5              MEH               JOY
# 6              NaN               NaN
# ...            ...               ...
# 2455           JOY               JOY
# 2456       DESPAIR               NaN
# 2457           MEH           DESPAIR
# 2458           NaN               NaN
# 2459           MEH           DESPAIR
#
#      Q6 | Creepy Religious comics/Chick Tracts Q6 | Dental paraphenalia  \
# 1                                      DESPAIR                  DESPAIR
# 3                                      DESPAIR                  DESPAIR
# 4                                      DESPAIR                  DESPAIR
# 5                                      DESPAIR                      MEH
# 6                                          NaN                      NaN
# ...                                        ...                      ...
# 2455                                   DESPAIR                      MEH
# 2456                                   DESPAIR                  DESPAIR
# 2457                                   DESPAIR                  DESPAIR
# 2458                                       NaN                      NaN
# 2459                                   DESPAIR                  DESPAIR
#
#      Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 1          MEH            JOY            DESPAIR
# 3          JOY            JOY                MEH
# 4          MEH            JOY            DESPAIR
# 5          MEH            JOY                NaN
# 6          NaN            NaN                NaN
# ...        ...            ...                ...
# 2455   DESPAIR            JOY                MEH
# 2456   DESPAIR            MEH                NaN
# 2457       MEH            JOY                MEH
# 2458       NaN            NaN                NaN
# 2459       JOY            JOY                MEH
#
#      Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 1                             DESPAIR          DESPAIR               DESPAIR
# 3                                 MEH              JOY                   JOY
# 4                             DESPAIR          DESPAIR                   MEH
# 5                             DESPAIR              MEH                   JOY
# 6                                 NaN              NaN                   NaN
# ...                               ...              ...                   ...
# 2455                              JOY          DESPAIR                   JOY
# 2456                              MEH          DESPAIR                   NaN
# 2457                              JOY              JOY               DESPAIR
# 2458                              NaN              NaN                   NaN
# 2459                          DESPAIR              MEH               DESPAIR
#
#      Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 1                    MEH                      DESPAIR
# 3                    MEH                      DESPAIR
# 4                    MEH                      DESPAIR
# 5                    MEH                      DESPAIR
# 6                    NaN                          NaN
# ...                  ...                          ...
# 2455                 JOY                          JOY
# 2456             DESPAIR                      DESPAIR
# 2457             DESPAIR                      DESPAIR
# 2458                 NaN                          NaN
# 2459                 JOY                      DESPAIR
#
#      Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 1                             MEH             MEH            DESPAIR
# 3                             JOY             MEH                MEH
# 4                             JOY             MEH            DESPAIR
# 5                             MEH             MEH                MEH
# 6                             NaN             NaN                NaN
# ...                           ...             ...                ...
# 2455                          MEH         DESPAIR                MEH
# 2456                          MEH             MEH            DESPAIR
# 2457                          MEH             MEH            DESPAIR
# 2458                          NaN             NaN                NaN
# 2459                          MEH         DESPAIR            DESPAIR
#
#      Q6 | Heath Bar Q6 | Hershey's Dark Chocolate  \
# 1               MEH                           JOY
# 3           DESPAIR                           MEH
# 4           DESPAIR                           JOY
# 5               JOY                           JOY
# 6               NaN                           NaN
# ...             ...                           ...
# 2455        DESPAIR                           JOY
# 2456            JOY                           MEH
# 2457            MEH                           JOY
# 2458            NaN                           NaN
# 2459        DESPAIR                           JOY
#
#      Q6 | Hershey’s Milk Chocolate Q6 | Hershey's Kisses  \
# 1                              JOY                   MEH
# 3                              MEH                   MEH
# 4                              MEH                   MEH
# 5                              MEH                   MEH
# 6                              NaN                   NaN
# ...                            ...                   ...
# 2455                           MEH                   MEH
# 2456                           JOY                   MEH
# 2457                           JOY                   JOY
# 2458                           NaN                   NaN
# 2459                           JOY                   JOY
#
#      Q6 | Hugs (actual physical hugs) Q6 | Jolly Rancher (bad flavor)  \
# 1                             DESPAIR                         DESPAIR
# 3                                 MEH                             MEH
# 4                             DESPAIR                             MEH
# 5                                 MEH                             MEH
# 6                                 NaN                             NaN
# ...                               ...                             ...
# 2455                              JOY                             MEH
# 2456                          DESPAIR                             MEH
# 2457                              MEH                         DESPAIR
# 2458                              NaN                             NaN
# 2459                          DESPAIR                         DESPAIR
#
#      Q6 | Jolly Ranchers (good flavor) Q6 | JoyJoy (Mit Iodine!)  \
# 1                                  MEH                   DESPAIR
# 3                                  MEH                   DESPAIR
# 4                                  JOY                       MEH
# 5                                  MEH                       NaN
# 6                                  NaN                       NaN
# ...                                ...                       ...
# 2455                               MEH                       MEH
# 2456                               JOY                       NaN
# 2457                               JOY                   DESPAIR
# 2458                               NaN                       NaN
# 2459                               MEH                   DESPAIR
#
#      Q6 | Junior Mints Q6 | Senior Mints Q6 | Kale smoothie  \
# 1              DESPAIR           DESPAIR            DESPAIR
# 3              DESPAIR           DESPAIR            DESPAIR
# 4                  JOY           DESPAIR            DESPAIR
# 5                  JOY               NaN            DESPAIR
# 6                  NaN               NaN                NaN
# ...                ...               ...                ...
# 2455           DESPAIR           DESPAIR                MEH
# 2456               JOY               NaN            DESPAIR
# 2457               JOY               MEH            DESPAIR
# 2458               NaN               NaN                NaN
# 2459               JOY           DESPAIR            DESPAIR
#
#      Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy Q6 | LemonHeads  \
# 1                    DESPAIR          JOY         DESPAIR             MEH
# 3                        MEH          MEH             JOY             JOY
# 4                        JOY          JOY             JOY             JOY
# 5                        NaN          JOY             MEH             MEH
# 6                        NaN          NaN             NaN             NaN
# ...                      ...          ...             ...             ...
# 2455                     JOY          JOY             MEH             MEH
# 2456                     NaN          JOY         DESPAIR         DESPAIR
# 2457                 DESPAIR      DESPAIR             JOY         DESPAIR
# 2458                     NaN          NaN             NaN             NaN
# 2459                 DESPAIR          MEH         DESPAIR         DESPAIR
#
#      Q6 | Licorice (not black) Q6 | Licorice (yes black) Q6 | Lindt Truffle  \
# 1                          MEH                       JOY                MEH
# 3                          MEH                       JOY                JOY
# 4                          MEH                   DESPAIR                JOY
# 5                          MEH                       MEH                JOY
# 6                          NaN                       NaN                NaN
# ...                        ...                       ...                ...
# 2455                       JOY                   DESPAIR                JOY
# 2456                       MEH                   DESPAIR                MEH
# 2457                       MEH                   DESPAIR                JOY
# 2458                       NaN                       NaN                NaN
# 2459                   DESPAIR                   DESPAIR                JOY
#
#      Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike Q6 | Milk Duds  \
# 1           DESPAIR   DESPAIR       DESPAIR               MEH            MEH
# 3           DESPAIR       JOY           MEH               MEH        DESPAIR
# 4               MEH       MEH       DESPAIR               MEH            MEH
# 5               MEH       JOY           NaN               JOY            JOY
# 6               NaN       NaN           NaN               NaN            NaN
# ...             ...       ...           ...               ...            ...
# 2455        DESPAIR       MEH           MEH               MEH            JOY
# 2456            MEH       NaN           NaN           DESPAIR            MEH
# 2457            MEH       JOY       DESPAIR               MEH            JOY
# 2458            NaN       NaN           NaN               NaN            NaN
# 2459        DESPAIR       JOY       DESPAIR               MEH        DESPAIR
#
#      Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s Q6 | Blue M&M's  \
# 1               JOY               JOY               MEH             JOY
# 3               JOY               MEH               JOY             MEH
# 4               JOY               JOY               JOY             JOY
# 5               JOY               JOY               JOY             JOY
# 6               NaN               NaN               NaN             NaN
# ...             ...               ...               ...             ...
# 2455            JOY               MEH               JOY             JOY
# 2456            MEH               JOY               JOY             NaN
# 2457            JOY               JOY           DESPAIR             JOY
# 2458            NaN               NaN               NaN             NaN
# 2459            JOY               JOY               JOY             JOY
#
#      Q6 | Red M&M's Q6 | Green Party M&M's Q6 | Independent M&M's  \
# 1               JOY                    JOY                    JOY
# 3               MEH                    MEH                    MEH
# 4               JOY                    JOY                    JOY
# 5               JOY                    NaN                    NaN
# 6               NaN                    NaN                    NaN
# ...             ...                    ...                    ...
# 2455            MEH                    JOY                    JOY
# 2456            NaN                    NaN                    NaN
# 2457            JOY                    JOY                    JOY
# 2458            NaN                    NaN                    NaN
# 2459            JOY                    JOY                DESPAIR
#
#      Q6 | Abstained from M&M'ing. Q6 | Minibags of chips Q6 | Mint Kisses  \
# 1                         DESPAIR                DESPAIR              MEH
# 3                             MEH                DESPAIR          DESPAIR
# 4                             MEH                DESPAIR              JOY
# 5                             NaN                    JOY              JOY
# 6                             NaN                    NaN              NaN
# ...                           ...                    ...              ...
# 2455                          MEH                    MEH              JOY
# 2456                          NaN                    MEH              JOY
# 2457                      DESPAIR                    JOY              JOY
# 2458                          NaN                    NaN              NaN
# 2459                      DESPAIR                    MEH              MEH
#
#      Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers Q6 | Nerds  \
# 1             DESPAIR          DESPAIR           DESPAIR    DESPAIR
# 3                 MEH              MEH           DESPAIR        MEH
# 4                 JOY              MEH           DESPAIR        JOY
# 5                 JOY              JOY               MEH        JOY
# 6                 NaN              NaN               NaN        NaN
# ...               ...              ...               ...        ...
# 2455              JOY              JOY               MEH        MEH
# 2456              NaN              JOY           DESPAIR        JOY
# 2457              JOY          DESPAIR           DESPAIR        MEH
# 2458              NaN              NaN               NaN        NaN
# 2459          DESPAIR              JOY               MEH    DESPAIR
#
#      Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 1                   JOY           DESPAIR    DESPAIR      DESPAIR
# 3                   MEH               MEH    DESPAIR      DESPAIR
# 4                   JOY               JOY        MEH      DESPAIR
# 5                   MEH               MEH    DESPAIR      DESPAIR
# 6                   NaN               NaN        NaN          NaN
# ...                 ...               ...        ...          ...
# 2455                JOY               JOY    DESPAIR      DESPAIR
# 2456                MEH               JOY    DESPAIR      DESPAIR
# 2457            DESPAIR               MEH        MEH          MEH
# 2458                NaN               NaN        NaN          NaN
# 2459                MEH           DESPAIR        MEH      DESPAIR
#
#      Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 1           DESPAIR                                            DESPAIR
# 3           DESPAIR                                            DESPAIR
# 4               JOY                                            DESPAIR
# 5               MEH                                            DESPAIR
# 6               NaN                                                NaN
# ...             ...                                                ...
# 2455            JOY                                                MEH
# 2456            MEH                                            DESPAIR
# 2457            JOY                                                JOY
# 2458            NaN                                                NaN
# 2459        DESPAIR                                            DESPAIR
#
#      Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces  \
# 1                                JOY                 JOY
# 3                                JOY                 MEH
# 4                                JOY                 JOY
# 5                                JOY                 JOY
# 6                                NaN                 NaN
# ...                              ...                 ...
# 2455                             JOY                 JOY
# 2456                             JOY                 JOY
# 2457                             JOY                 MEH
# 2458                             NaN                 NaN
# 2459                             MEH             DESPAIR
#
#      Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 1                    DESPAIR        JOY
# 3                        MEH        MEH
# 4                        MEH        JOY
# 5                    DESPAIR        JOY
# 6                        NaN        NaN
# ...                      ...        ...
# 2455                     JOY        JOY
# 2456                     NaN        MEH
# 2457                     MEH        JOY
# 2458                     NaN        NaN
# 2459                 DESPAIR    DESPAIR
#
#      Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 1                                               DESPAIR         DESPAIR
# 3                                               DESPAIR         DESPAIR
# 4                                                   NaN             JOY
# 5                                               DESPAIR             JOY
# 6                                                   NaN             NaN
# ...                                                 ...             ...
# 2455                                                JOY             MEH
# 2456                                            DESPAIR             JOY
# 2457                                            DESPAIR         DESPAIR
# 2458                                                NaN             NaN
# 2459                                            DESPAIR         DESPAIR
#
#      Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 1                     DESPAIR                      DESPAIR           MEH
# 3                     DESPAIR                          MEH           JOY
# 4                         JOY                      DESPAIR           NaN
# 5                         JOY                          JOY           JOY
# 6                         NaN                          NaN           NaN
# ...                       ...                          ...           ...
# 2455                  DESPAIR                      DESPAIR           JOY
# 2456                  DESPAIR                          NaN           JOY
# 2457                      JOY                          MEH       DESPAIR
# 2458                      NaN                          NaN           NaN
# 2459                      MEH                      DESPAIR           JOY
#
#      Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 1                                              DESPAIR           DESPAIR
# 3                                                  MEH           DESPAIR
# 4                                                  MEH           DESPAIR
# 5                                              DESPAIR           DESPAIR
# 6                                                  NaN               NaN
# ...                                                ...               ...
# 2455                                               JOY               JOY
# 2456                                               MEH               NaN
# 2457                                           DESPAIR           DESPAIR
# 2458                                               NaN               NaN
# 2459                                               JOY           DESPAIR
#
#      Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 1               MEH          DESPAIR               MEH
# 3               MEH              MEH               JOY
# 4               JOY              JOY               MEH
# 5               MEH              MEH               MEH
# 6               NaN              NaN               NaN
# ...             ...              ...               ...
# 2455            JOY              MEH               JOY
# 2456            MEH              MEH               MEH
# 2457        DESPAIR              JOY           DESPAIR
# 2458            NaN              NaN               NaN
# 2459            MEH              MEH           DESPAIR
#
#      Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 1                                 DESPAIR     DESPAIR       DESPAIR
# 3                                     MEH         JOY           MEH
# 4                                 DESPAIR         MEH       DESPAIR
# 5                                     NaN         NaN           MEH
# 6                                     NaN         NaN           NaN
# ...                                   ...         ...           ...
# 2455                              DESPAIR         MEH           JOY
# 2456                                  NaN         JOY       DESPAIR
# 2457                              DESPAIR         MEH           MEH
# 2458                                  NaN         NaN           NaN
# 2459                              DESPAIR     DESPAIR       DESPAIR
#
#      Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 1                                            DESPAIR                   JOY
# 3                                            DESPAIR               DESPAIR
# 4                                            DESPAIR                   JOY
# 5                                            DESPAIR                   JOY
# 6                                                NaN                   NaN
# ...                                              ...                   ...
# 2455                                         DESPAIR                   MEH
# 2456                                         DESPAIR                   MEH
# 2457                                         DESPAIR                   JOY
# 2458                                             NaN                   NaN
# 2459                                         DESPAIR                   JOY
#
#      Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 1                                  JOY        DESPAIR       JOY
# 3                                  JOY            MEH       JOY
# 4                                  JOY        DESPAIR       JOY
# 5                                  JOY            MEH       JOY
# 6                                  NaN            NaN       NaN
# ...                                ...            ...       ...
# 2455                               MEH            JOY       JOY
# 2456                               MEH        DESPAIR       JOY
# 2457                               JOY            MEH       MEH
# 2458                               NaN            NaN       NaN
# 2459                               MEH        DESPAIR   DESPAIR
#
#      Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                                   MEH
# 5                                               DESPAIR
# 6                                                   NaN
# ...                                                 ...
# 2455                                                MEH
# 2456                                                NaN
# 2457                                                MEH
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 1         DESPAIR                   DESPAIR          DESPAIR
# 3             JOY                       JOY          DESPAIR
# 4             JOY                       JOY          DESPAIR
# 5         DESPAIR                       JOY          DESPAIR
# 6             NaN                       NaN              NaN
# ...           ...                       ...              ...
# 2455          JOY                   DESPAIR              MEH
# 2456          NaN                       JOY          DESPAIR
# 2457          JOY                       MEH          DESPAIR
# 2458          NaN                       NaN              NaN
# 2459          JOY                   DESPAIR              MEH
#
#      Q6 | Whole Wheat anything Q6 | York Peppermint Patties  \
# 1                      DESPAIR                      DESPAIR
# 3                      DESPAIR                      DESPAIR
# 4                      DESPAIR                          JOY
# 5                      DESPAIR                          JOY
# 6                          NaN                          NaN
# ...                        ...                          ...
# 2455                   DESPAIR                          MEH
# 2456                       MEH                          JOY
# 2457                   DESPAIR                          MEH
# 2458                       NaN                          NaN
# 2459                   DESPAIR                          JOY
#
#                                           Q7: JOY OTHER Q8: DESPAIR OTHER  \
# 1                                                Mounds               NaN
# 3     Reese's crispy crunchy bars, 5th avenue bars, ...               NaN
# 4                                                   NaN               NaN
# 5                                                   NaN               NaN
# 6                                                   NaN               NaN
# ...                                                 ...               ...
# 2455                                             Mounds  Fruit Stripe Gum
# 2456                                                NaN            Capers
# 2457  Tiny bottles of maple syrup as given out by Cr...               NaN
# 2458                                                NaN               NaN
# 2459                                                NaN               NaN
#
#                                      Q9: OTHER COMMENTS      Q10: DRESS  \
# 1     Bottom line is Twix is really the only candy w...  White and gold
# 3                                Raisins can go to hell  White and gold
# 4                                                   NaN  White and gold
# 5                                                   NaN             NaN
# 6                                                   NaN             NaN
# ...                                                 ...             ...
# 2455                                                NaN  White and gold
# 2456                                                NaN  Blue and black
# 2457                                                NaN  Blue and black
# 2458                                                NaN             NaN
# 2459  You hit all my chocolate highlights, and broug...  White and gold
#
#      Q11: DAY  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# 1      Sunday                      NaN                   1.0
# 3      Sunday                      NaN                   1.0
# 4      Friday                      NaN                   1.0
# 5         NaN                      NaN                   1.0
# 6         NaN                      NaN                   NaN
# ...       ...                      ...                   ...
# 2455   Friday                      NaN                   NaN
# 2456   Friday                      NaN                   1.0
# 2457   Friday                      NaN                   1.0
# 2458      NaN                      NaN                   NaN
# 2459   Sunday                      1.0                   NaN
#
#       Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 1                   NaN                 NaN                 (84, 25)
# 3                   NaN                 NaN                 (75, 23)
# 4                   NaN                 NaN                 (70, 10)
# 5                   NaN                 NaN                 (75, 23)
# 6                   NaN                 NaN                      NaN
# ...                 ...                 ...                      ...
# 2455                NaN                 NaN                      NaN
# 2456                NaN                 NaN                 (70, 26)
# 2457                NaN                 NaN                 (67, 35)
# 2458                NaN                 NaN                      NaN
# 2459                NaN                 NaN                 (19, 26)
#
# [2350 rows x 119 columns]

# %%
for i in cd:
    print(cd[i].value_counts())
# Out:
# 90273795    1
# 90281515    1
# 90280029    1
# 90292907    1
# 90274476    1
#            ..
# 90275215    1
# 90277264    1
# 90288432    1
# 90277268    1
# 90277887    1
# Name: Internal ID, Length: 2350, dtype: int64
# No     2038
# Yes     312
# Name: Q1: GOING OUT?, dtype: int64
# Male                  1404
# Female                 825
# I'd rather not say      78
# Other                   29
# Name: Q2: GENDER, dtype: int64
# 37                                                  89
# 40                                                  89
# 34                                                  85
# 43                                                  83
# 36                                                  76
# 42                                                  76
# 35                                                  75
# 44                                                  73
# 45                                                  73
# 38                                                  73
# 33                                                  73
# 41                                                  71
# 32                                                  68
# 39                                                  68
# 49                                                  66
# 50                                                  65
# 48                                                  62
# 47                                                  59
# 30                                                  59
# 53                                                  56
# 46                                                  55
# 52                                                  50
# 56                                                  46
# 27                                                  43
# 31                                                  43
# 51                                                  41
# 58                                                  34
# 28                                                  33
# 54                                                  32
# 55                                                  31
# 60                                                  31
# 29                                                  26
# 59                                                  24
# 57                                                  24
# 26                                                  23
# 62                                                  20
# 63                                                  20
# 25                                                  18
# 64                                                  17
# 61                                                  17
# 24                                                  15
# 21                                                  14
# 20                                                  12
# 22                                                  11
# 18                                                  10
# 65                                                  10
# 66                                                   9
# 23                                                   8
# 15                                                   8
# 70                                                   7
# 11                                                   7
# 68                                                   7
# 12                                                   7
# 13                                                   6
# 71                                                   6
# 72                                                   6
# 67                                                   5
# 9                                                    4
# 69                                                   4
# 73                                                   4
# 16                                                   4
# 17                                                   4
# 10                                                   3
# 75                                                   3
# 19                                                   3
# 7                                                    2
# old                                                  2
# 100                                                  2
# 8                                                    2
# 14                                                   2
# 76                                                   2
# 90                                                   2
# 6                                                    2
# sixty-nine                                           1
# 59 on the day after Halloween                        1
# 70 1/2                                               1
# MY NAME JEFF                                         1
# older than dirt                                      1
# OLD                                                  1
# 39.4                                                 1
# old enough                                           1
# hahahahaha                                           1
# your mom                                             1
# 60+                                                  1
# I can remember when Java was a cool new language     1
# 77                                                   1
# 88                                                   1
# 1000                                                 1
# 24-50                                                1
# Over 50                                              1
# 99                                                   1
# See question 2                                       1
# 312                                                  1
# 74                                                   1
# 45-55                                                1
# Many                                                 1
# Old enough                                           1
# ?                                                    1
# 5u                                                   1
# 102                                                  1
# 4                                                    1
# 1                                                    1
# ancient                                              1
# no                                                   1
# 46 Halloweens.                                       1
# Enough                                               1
# Name: Q3: AGE, dtype: int64
# USA              670
# United States    481
# usa              210
# Canada           171
# Usa              138
#                 ...
# 'merica            1
# A                  1
# 1                  1
# UAE                1
# UK                 1
# Name: Q4: COUNTRY, Length: 122, dtype: int64
# California                        126
# CA                                 85
# Texas                              58
# Ontario                            54
# Illinois                           52
#                                  ...
# Massachusetts, Plymouth county      1
# Ontario,  Canada                    1
# FL, Orange County                   1
# in                                  1
# ont                                 1
# Name: Q5: STATE, PROVINCE, COUNTY, ETC, Length: 503, dtype: int64
# JOY        838
# MEH        732
# DESPAIR     82
# Name: Q6 | 100 Grand Bar, dtype: int64
# DESPAIR    1053
# MEH         445
# JOY         170
# Name: Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes), dtype: int64
# JOY        1504
# MEH         205
# DESPAIR      16
# Name: Q6 | Any full-sized candy bar, dtype: int64
# DESPAIR    760
# MEH        598
# JOY         89
# Name: Q6 | Black Jacks, dtype: int64
# MEH        831
# DESPAIR    476
# JOY        111
# Name: Q6 | Bonkers (the candy), dtype: int64
# MEH        693
# DESPAIR    525
# JOY        186
# Name: Q6 | Bonkers (the board game), dtype: int64
# MEH        653
# DESPAIR    536
# JOY        447
# Name: Q6 | Bottle Caps, dtype: int64
# DESPAIR    1134
# MEH         463
# JOY         115
# Name: Q6 | Box'o'Raisins, dtype: int64
# DESPAIR    1568
# MEH         103
# JOY          22
# Name: Q6 | Broken glow stick, dtype: int64
# JOY        1133
# MEH         448
# DESPAIR     135
# Name: Q6 | Butterfinger, dtype: int64
# JOY        791
# MEH        544
# DESPAIR    380
# Name: Q6 | Cadbury Creme Eggs, dtype: int64
# DESPAIR    718
# MEH        537
# JOY        465
# Name: Q6 | Candy Corn, dtype: int64
# DESPAIR    1274
# MEH         396
# JOY          38
# Name: Q6 | Candy that is clearly just the stuff given out for free at restaurants, dtype: int64
# JOY        927
# MEH        565
# DESPAIR    155
# Name: Q6 | Caramellos, dtype: int64
# JOY        1394
# MEH         263
# DESPAIR      61
# Name: Q6 | Cash, or other forms of legal tender, dtype: int64
# JOY        1006
# MEH         348
# DESPAIR     304
# Name: Q6 | Chardonnay, dtype: int64
# DESPAIR    613
# MEH        554
# JOY        291
# Name: Q6 | Chick-o-Sticks (we don’t know what that is), dtype: int64
# DESPAIR    727
# MEH        721
# JOY        241
# Name: Q6 | Chiclets, dtype: int64
# MEH        569
# DESPAIR    523
# JOY        457
# Name: Q6 | Coffee Crisp, dtype: int64
# DESPAIR    1358
# JOY         237
# MEH         100
# Name: Q6 | Creepy Religious comics/Chick Tracts, dtype: int64
# DESPAIR    1385
# MEH         238
# JOY          84
# Name: Q6 | Dental paraphenalia, dtype: int64
# MEH        640
# DESPAIR    639
# JOY        394
# Name: Q6 | Dots, dtype: int64
# JOY        1136
# MEH         458
# DESPAIR     103
# Name: Q6 | Dove Bars, dtype: int64
# DESPAIR    653
# MEH        542
# JOY        383
# Name: Q6 | Fuzzy Peaches, dtype: int64
# DESPAIR    1133
# MEH         381
# JOY         156
# Name: Q6 | Generic Brand Acetaminophen, dtype: int64
# MEH        682
# JOY        587
# DESPAIR    433
# Name: Q6 | Glow sticks, dtype: int64
# MEH        679
# DESPAIR    448
# JOY        398
# Name: Q6 | Goo Goo Clusters, dtype: int64
# DESPAIR    719
# MEH        554
# JOY        392
# Name: Q6 | Good N' Plenty, dtype: int64
# DESPAIR    1408
# MEH         234
# JOY          43
# Name: Q6 | Gum from baseball cards, dtype: int64
# JOY        721
# MEH        570
# DESPAIR    411
# Name: Q6 | Gummy Bears straight up, dtype: int64
# MEH        877
# DESPAIR    567
# JOY        260
# Name: Q6 | Hard Candy, dtype: int64
# DESPAIR    829
# MEH        662
# JOY        214
# Name: Q6 | Healthy Fruit, dtype: int64
# JOY        1034
# MEH         449
# DESPAIR     206
# Name: Q6 | Heath Bar, dtype: int64
# JOY        1069
# MEH         486
# DESPAIR     171
# Name: Q6 | Hershey's Dark Chocolate, dtype: int64
# JOY        867
# MEH        646
# DESPAIR    214
# Name: Q6 | Hershey’s Milk Chocolate, dtype: int64
# JOY        810
# MEH        701
# DESPAIR    209
# Name: Q6 | Hershey's Kisses, dtype: int64
# DESPAIR    852
# JOY        421
# MEH        414
# Name: Q6 | Hugs (actual physical hugs), dtype: int64
# DESPAIR    1029
# MEH         584
# JOY          93
# Name: Q6 | Jolly Rancher (bad flavor), dtype: int64
# JOY        714
# MEH        622
# DESPAIR    368
# Name: Q6 | Jolly Ranchers (good flavor), dtype: int64
# DESPAIR    918
# MEH        391
# JOY         72
# Name: Q6 | JoyJoy (Mit Iodine!), dtype: int64
# JOY        989
# MEH        477
# DESPAIR    237
# Name: Q6 | Junior Mints, dtype: int64
# DESPAIR    860
# MEH        457
# JOY        146
# Name: Q6 | Senior Mints, dtype: int64
# DESPAIR    1387
# MEH         169
# JOY         101
# Name: Q6 | Kale smoothie, dtype: int64
# DESPAIR    549
# JOY        484
# MEH        427
# Name: Q6 | Kinder Happy Hippo, dtype: int64
# JOY        1399
# MEH         277
# DESPAIR      48
# Name: Q6 | Kit Kat, dtype: int64
# MEH        699
# DESPAIR    534
# JOY        431
# Name: Q6 | LaffyTaffy, dtype: int64
# MEH        671
# JOY        641
# DESPAIR    359
# Name: Q6 | LemonHeads, dtype: int64
# MEH        688
# JOY        535
# DESPAIR    491
# Name: Q6 | Licorice (not black), dtype: int64
# DESPAIR    873
# JOY        523
# MEH        318
# Name: Q6 | Licorice (yes black), dtype: int64
# JOY        1233
# MEH         355
# DESPAIR      93
# Name: Q6 | Lindt Truffle, dtype: int64
# MEH        892
# DESPAIR    465
# JOY        351
# Name: Q6 | Lollipops, dtype: int64
# JOY        986
# MEH        572
# DESPAIR    119
# Name: Q6 | Mars, dtype: int64
# MEH        685
# DESPAIR    557
# JOY        143
# Name: Q6 | Maynards, dtype: int64
# MEH        622
# DESPAIR    536
# JOY        515
# Name: Q6 | Mike and Ike, dtype: int64
# JOY        850
# MEH        614
# DESPAIR    242
# Name: Q6 | Milk Duds, dtype: int64
# JOY        1139
# MEH         472
# DESPAIR      99
# Name: Q6 | Milky Way, dtype: int64
# JOY        1086
# MEH         567
# DESPAIR      71
# Name: Q6 | Regular M&Ms, dtype: int64
# JOY        1241
# MEH         368
# DESPAIR     118
# Name: Q6 | Peanut M&M’s, dtype: int64
# JOY        985
# MEH        572
# DESPAIR    115
# Name: Q6 | Blue M&M's, dtype: int64
# JOY        966
# MEH        585
# DESPAIR    119
# Name: Q6 | Red M&M's, dtype: int64
# JOY        936
# MEH        568
# DESPAIR    132
# Name: Q6 | Green Party M&M's, dtype: int64
# JOY        728
# MEH        604
# DESPAIR    257
# Name: Q6 | Independent M&M's, dtype: int64
# DESPAIR    676
# MEH        582
# JOY        206
# Name: Q6 | Abstained from M&M'ing., dtype: int64
# MEH        733
# JOY        518
# DESPAIR    425
# Name: Q6 | Minibags of chips, dtype: int64
# MEH        622
# JOY        598
# DESPAIR    405
# Name: Q6 | Mint Kisses, dtype: int64
# JOY        872
# DESPAIR    395
# MEH        328
# Name: Q6 | Mint Juleps, dtype: int64
# JOY        824
# MEH        619
# DESPAIR    216
# Name: Q6 | Mr. Goodbar, dtype: int64
# DESPAIR    772
# MEH        541
# JOY        343
# Name: Q6 | Necco Wafers, dtype: int64
# JOY        740
# MEH        585
# DESPAIR    351
# Name: Q6 | Nerds, dtype: int64
# JOY        1143
# MEH         460
# DESPAIR      97
# Name: Q6 | Nestle Crunch, dtype: int64
# MEH        699
# DESPAIR    539
# JOY        349
# Name: Q6 | Now'n'Laters, dtype: int64
# DESPAIR    1042
# MEH         417
# JOY         230
# Name: Q6 | Peeps, dtype: int64
# DESPAIR    1036
# MEH         478
# JOY         177
# Name: Q6 | Pencils, dtype: int64
# MEH        623
# DESPAIR    530
# JOY        525
# Name: Q6 | Pixy Stix, dtype: int64
# DESPAIR    1429
# MEH         131
# JOY          88
# Name: Q6 | Real Housewives of Orange County Season 9 Blue-Ray, dtype: int64
# JOY        1444
# MEH         182
# DESPAIR      92
# Name: Q6 | Reese’s Peanut Butter Cups, dtype: int64
# JOY        1096
# MEH         447
# DESPAIR     164
# Name: Q6 | Reese's Pieces, dtype: int64
# MEH        683
# DESPAIR    467
# JOY        243
# Name: Q6 | Reggie Jackson Bar, dtype: int64
# JOY        1110
# MEH         441
# DESPAIR     134
# Name: Q6 | Rolos, dtype: int64
# DESPAIR    1109
# MEH         310
# JOY         205
# Name: Q6 | Sandwich-sized bags filled with BooBerry Crunch, dtype: int64
# JOY        797
# MEH        586
# DESPAIR    312
# Name: Q6 | Skittles, dtype: int64
# JOY        705
# MEH        560
# DESPAIR    410
# Name: Q6 | Smarties (American), dtype: int64
# MEH        585
# JOY        517
# DESPAIR    404
# Name: Q6 | Smarties (Commonwealth), dtype: int64
# JOY        1348
# MEH         284
# DESPAIR      75
# Name: Q6 | Snickers, dtype: int64
# JOY        741
# DESPAIR    495
# MEH        428
# Name: Q6 | Sourpatch Kids (i.e. abominations of nature), dtype: int64
# DESPAIR    1097
# MEH         300
# JOY         126
# Name: Q6 | Spotted Dick, dtype: int64
# JOY        824
# MEH        590
# DESPAIR    293
# Name: Q6 | Starburst, dtype: int64
# JOY        754
# MEH        586
# DESPAIR    351
# Name: Q6 | Sweet Tarts, dtype: int64
# JOY        726
# MEH        521
# DESPAIR    438
# Name: Q6 | Swedish Fish, dtype: int64
# DESPAIR    736
# MEH        521
# JOY        146
# Name: Q6 | Sweetums (a friend to diabetes), dtype: int64
# MEH        588
# JOY        558
# DESPAIR    340
# Name: Q6 | Take 5, dtype: int64
# DESPAIR    728
# MEH        699
# JOY        258
# Name: Q6 | Tic Tacs, dtype: int64
# DESPAIR    1206
# MEH         274
# JOY         183
# Name: Q6 | Those odd marshmallow circus peanut things, dtype: int64
# JOY        1014
# MEH         504
# DESPAIR     171
# Name: Q6 | Three Musketeers, dtype: int64
# JOY        1273
# MEH         340
# DESPAIR      81
# Name: Q6 | Tolberone something or other, dtype: int64
# DESPAIR    805
# MEH        668
# JOY        219
# Name: Q6 | Trail Mix, dtype: int64
# JOY        1368
# MEH         274
# DESPAIR      67
# Name: Q6 | Twix, dtype: int64
# DESPAIR    1102
# MEH         282
# JOY         225
# Name: Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein, dtype: int64
# DESPAIR    694
# JOY        683
# MEH        234
# Name: Q6 | Vicodin, dtype: int64
# JOY        807
# MEH        493
# DESPAIR    277
# Name: Q6 | Whatchamacallit Bars, dtype: int64
# DESPAIR    1405
# MEH         197
# JOY          43
# Name: Q6 | White Bread, dtype: int64
# DESPAIR    1246
# MEH         296
# JOY         114
# Name: Q6 | Whole Wheat anything, dtype: int64
# JOY        1068
# MEH         401
# DESPAIR     225
# Name: Q6 | York Peppermint Patties, dtype: int64
# Beer                                                                                                                    10
# Almond Joy                                                                                                              10
# Sex                                                                                                                      3
# beer                                                                                                                     3
# Mounds, Almond Joy                                                                                                       3
#                                                                                                                         ..
# using my elbows to get in front of the little kids in line.                                                              1
# Lady Godiva chocolates, Belgian chocolates, Bourbon Balls                                                                1
# Safety suckers. I don't know what it is about the flavoring used for those loop-sticked suckers, but they are great!     1
# Math and sciences, technology, the girl I like (with out her boy friend), soccer, running.                               1
# Junior Mints, Thin Mints                                                                                                 1
# Name: Q7: JOY OTHER, Length: 841, dtype: int64
# Trump                                                                                                                    7
# Almond Joy, Mounds                                                                                                       3
# Pennies                                                                                                                  3
# Tootsie Rolls                                                                                                            3
# Popcorn balls                                                                                                            3
#                                                                                                                         ..
# 5 hour energy drink                                                                                                      1
# that goddamn molasses candy that tasted like earwax and stuck to the wrapper, chicken bones, grape flavoured anything    1
# Chocolate covered raisins                                                                                                1
# Broken musical instrument                                                                                                1
# Anything with gluten (Celiac) Cheap nasty chocolate (e.g. pretty much anything mass produced)                            1
# Name: Q8: DESPAIR OTHER, Length: 666, dtype: int64
# The moment I realized you expected me to evaluate what might be over 100 items I stopped. Follow this link to see a better approach to evaluating a large list of items: http://walthickey.com/2017/10/18/whats-the-best-halloween-candy/  It's essentially random pairwise comparison. Allourideas.org provides a similar platform but allows users too add their own items. Good luck!                                                                                                                1
# Rolos.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# Why?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# Awesome list...but where is Merlot!!!                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# Tastes are so individualized!  As I've gotten older (and manage to keep my economic head above water) I've begun to eschew most commercial candy.  I've also grown more attracted to stronger flavors.  Darker chocolates, more bitter/saltier licorices, balances of sweet and savory... this is what I want.  On my "mostly don't care" list are most fruit candies.  They all taste fake to me.  My exception is artificial banana, which is always amusing.                                         1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ..
# No.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# no rockets listed?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# Chocolate>hard candy: Because I'm old but not that old. Brands names usually > generic: Could be cultural conditioning, could be they're actually better. Unclear at this point. Bigger > smaller: because duh. Homemade = nope! Unless Baker = familiar human I love these entries. You guys make it easy to get though the list. PS. Dislike of sour patch kids = demerits :) PPS I'm old AF and haven't gone trick or treating in years. I just buy or make what I want. The one joy of adulting.    1
# Please assume any selection I have made that is different in recipe in the UK to the US/Canada refers to the version available in the UK - I know you lot across the pond have strange ideas about sweets - HFCS, et al.  "Dove Bar" means soap to me - a short Google later informs me that it is an ice cream bar, but I cannot shake the thought of eating a bar of soap.  Why have Black Jacks in the list but not it's better (but still not great) sibling chew Fruit Salad?                      1
# Wouldn't it be something if people gave out fried chicken on Halloween?                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# Name: Q9: OTHER COMMENTS, Length: 376, dtype: int64
# White and gold    1054
# Blue and black     603
# Name: Q10: DRESS, dtype: int64
# Friday    1055
# Sunday     621
# Name: Q11: DAY, dtype: int64
# 1.0    84
# Name: Q12: MEDIA [Daily Dish], dtype: int64
# 1.0    1317
# Name: Q12: MEDIA [Science], dtype: int64
# 1.0    98
# Name: Q12: MEDIA [ESPN], dtype: int64
# 1.0    61
# Name: Q12: MEDIA [Yahoo], dtype: int64
# (77, 26)    8
# (77, 24)    8
# (71, 29)    7
# (73, 26)    7
# (78, 22)    7
#            ..
# (87, 22)    1
# (88, 39)    1
# (30, 33)    1
# (30, 27)    1
# (61, 42)    1
# Name: Click Coordinates (x, y), Length: 928, dtype: int64

# %%
cd.dropna(subset=['Q2: GENDER'],inplace=True)

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male      44        USA
# 3        90272840             No       Male      40          us
# 4        90272841             No       Male      23         usa
# 5        90272852             No       Male     NaN         NaN
# 6        90272853             No       Male      53         usa
# ...           ...            ...        ...     ...         ...
# 2455     90314359             No       Male      24         USA
# 2456     90314580             No     Female      33         USA
# 2457     90314634             No     Female      26        USA
# 2458     90314658             No       Male      58         Usa
# 2459     90314802             No     Female      66         usa
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 1                                  NM                MEH
# 3                                  or                MEH
# 4                            exton pa                JOY
# 5                                 NaN                JOY
# 6                           Colorado                 NaN
# ...                               ...                ...
# 2455                               MD                JOY
# 2456                         New York                MEH
# 2457                        Tennessee                MEH
# 2458                   North Carolina                NaN
# 2459                     Pennsylvania            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 5                                               DESPAIR
# 6                                                   NaN
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 1                              JOY              MEH                  DESPAIR
# 3                              JOY              MEH                      MEH
# 4                              JOY          DESPAIR                      MEH
# 5                              JOY              NaN                      NaN
# 6                              NaN              NaN                      NaN
# ...                            ...              ...                      ...
# 2455                           MEH          DESPAIR                  DESPAIR
# 2456                           JOY              NaN                      NaN
# 2457                           JOY          DESPAIR                      MEH
# 2458                           NaN              NaN                      NaN
# 2459                           JOY          DESPAIR                  DESPAIR
#
#      Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 1                          DESPAIR          DESPAIR            DESPAIR
# 3                          DESPAIR              MEH            DESPAIR
# 4                          DESPAIR              MEH            DESPAIR
# 5                              NaN              MEH                MEH
# 6                              NaN              NaN                NaN
# ...                            ...              ...                ...
# 2455                           MEH              MEH            DESPAIR
# 2456                           NaN              NaN            DESPAIR
# 2457                           JOY          DESPAIR                MEH
# 2458                           NaN              NaN                NaN
# 2459                       DESPAIR          DESPAIR                MEH
#
#      Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 1                   DESPAIR           DESPAIR                     MEH
# 3                   DESPAIR               MEH                     MEH
# 4                   DESPAIR               MEH                     MEH
# 5                   DESPAIR               JOY                 DESPAIR
# 6                       NaN               NaN                     NaN
# ...                     ...               ...                     ...
# 2455                DESPAIR               MEH                 DESPAIR
# 2456                DESPAIR               JOY                     JOY
# 2457                    MEH           DESPAIR                     JOY
# 2458                    NaN               NaN                     NaN
# 2459                DESPAIR               JOY                     MEH
#
#      Q6 | Candy Corn  \
# 1                MEH
# 3            DESPAIR
# 4            DESPAIR
# 5                MEH
# 6                NaN
# ...              ...
# 2455         DESPAIR
# 2456             JOY
# 2457         DESPAIR
# 2458             NaN
# 2459             MEH
#
#      Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 5                                                   MEH
# 6                                                   NaN
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                                MEH
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Caramellos Q6 | Cash, or other forms of legal tender  \
# 1                MEH                                       JOY
# 3                MEH                                       JOY
# 4                JOY                                       MEH
# 5                JOY                                       JOY
# 6                NaN                                       NaN
# ...              ...                                       ...
# 2455             JOY                                       JOY
# 2456             JOY                                       JOY
# 2457         DESPAIR                                       JOY
# 2458             NaN                                       NaN
# 2459             MEH                                       JOY
#
#      Q6 | Chardonnay Q6 | Chick-o-Sticks (we don’t know what that is)  \
# 1                MEH                                          DESPAIR
# 3                MEH                                              JOY
# 4                JOY                                          DESPAIR
# 5                JOY                                              MEH
# 6                NaN                                              NaN
# ...              ...                                              ...
# 2455             JOY                                              MEH
# 2456             JOY                                              JOY
# 2457             JOY                                              MEH
# 2458             NaN                                              NaN
# 2459             JOY                                          DESPAIR
#
#      Q6 | Chiclets Q6 | Coffee Crisp  \
# 1          DESPAIR           DESPAIR
# 3              MEH           DESPAIR
# 4          DESPAIR               MEH
# 5              MEH               JOY
# 6              NaN               NaN
# ...            ...               ...
# 2455           JOY               JOY
# 2456       DESPAIR               NaN
# 2457           MEH           DESPAIR
# 2458           NaN               NaN
# 2459           MEH           DESPAIR
#
#      Q6 | Creepy Religious comics/Chick Tracts Q6 | Dental paraphenalia  \
# 1                                      DESPAIR                  DESPAIR
# 3                                      DESPAIR                  DESPAIR
# 4                                      DESPAIR                  DESPAIR
# 5                                      DESPAIR                      MEH
# 6                                          NaN                      NaN
# ...                                        ...                      ...
# 2455                                   DESPAIR                      MEH
# 2456                                   DESPAIR                  DESPAIR
# 2457                                   DESPAIR                  DESPAIR
# 2458                                       NaN                      NaN
# 2459                                   DESPAIR                  DESPAIR
#
#      Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 1          MEH            JOY            DESPAIR
# 3          JOY            JOY                MEH
# 4          MEH            JOY            DESPAIR
# 5          MEH            JOY                NaN
# 6          NaN            NaN                NaN
# ...        ...            ...                ...
# 2455   DESPAIR            JOY                MEH
# 2456   DESPAIR            MEH                NaN
# 2457       MEH            JOY                MEH
# 2458       NaN            NaN                NaN
# 2459       JOY            JOY                MEH
#
#      Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 1                             DESPAIR          DESPAIR               DESPAIR
# 3                                 MEH              JOY                   JOY
# 4                             DESPAIR          DESPAIR                   MEH
# 5                             DESPAIR              MEH                   JOY
# 6                                 NaN              NaN                   NaN
# ...                               ...              ...                   ...
# 2455                              JOY          DESPAIR                   JOY
# 2456                              MEH          DESPAIR                   NaN
# 2457                              JOY              JOY               DESPAIR
# 2458                              NaN              NaN                   NaN
# 2459                          DESPAIR              MEH               DESPAIR
#
#      Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 1                    MEH                      DESPAIR
# 3                    MEH                      DESPAIR
# 4                    MEH                      DESPAIR
# 5                    MEH                      DESPAIR
# 6                    NaN                          NaN
# ...                  ...                          ...
# 2455                 JOY                          JOY
# 2456             DESPAIR                      DESPAIR
# 2457             DESPAIR                      DESPAIR
# 2458                 NaN                          NaN
# 2459                 JOY                      DESPAIR
#
#      Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 1                             MEH             MEH            DESPAIR
# 3                             JOY             MEH                MEH
# 4                             JOY             MEH            DESPAIR
# 5                             MEH             MEH                MEH
# 6                             NaN             NaN                NaN
# ...                           ...             ...                ...
# 2455                          MEH         DESPAIR                MEH
# 2456                          MEH             MEH            DESPAIR
# 2457                          MEH             MEH            DESPAIR
# 2458                          NaN             NaN                NaN
# 2459                          MEH         DESPAIR            DESPAIR
#
#      Q6 | Heath Bar Q6 | Hershey's Dark Chocolate  \
# 1               MEH                           JOY
# 3           DESPAIR                           MEH
# 4           DESPAIR                           JOY
# 5               JOY                           JOY
# 6               NaN                           NaN
# ...             ...                           ...
# 2455        DESPAIR                           JOY
# 2456            JOY                           MEH
# 2457            MEH                           JOY
# 2458            NaN                           NaN
# 2459        DESPAIR                           JOY
#
#      Q6 | Hershey’s Milk Chocolate Q6 | Hershey's Kisses  \
# 1                              JOY                   MEH
# 3                              MEH                   MEH
# 4                              MEH                   MEH
# 5                              MEH                   MEH
# 6                              NaN                   NaN
# ...                            ...                   ...
# 2455                           MEH                   MEH
# 2456                           JOY                   MEH
# 2457                           JOY                   JOY
# 2458                           NaN                   NaN
# 2459                           JOY                   JOY
#
#      Q6 | Hugs (actual physical hugs) Q6 | Jolly Rancher (bad flavor)  \
# 1                             DESPAIR                         DESPAIR
# 3                                 MEH                             MEH
# 4                             DESPAIR                             MEH
# 5                                 MEH                             MEH
# 6                                 NaN                             NaN
# ...                               ...                             ...
# 2455                              JOY                             MEH
# 2456                          DESPAIR                             MEH
# 2457                              MEH                         DESPAIR
# 2458                              NaN                             NaN
# 2459                          DESPAIR                         DESPAIR
#
#      Q6 | Jolly Ranchers (good flavor) Q6 | JoyJoy (Mit Iodine!)  \
# 1                                  MEH                   DESPAIR
# 3                                  MEH                   DESPAIR
# 4                                  JOY                       MEH
# 5                                  MEH                       NaN
# 6                                  NaN                       NaN
# ...                                ...                       ...
# 2455                               MEH                       MEH
# 2456                               JOY                       NaN
# 2457                               JOY                   DESPAIR
# 2458                               NaN                       NaN
# 2459                               MEH                   DESPAIR
#
#      Q6 | Junior Mints Q6 | Senior Mints Q6 | Kale smoothie  \
# 1              DESPAIR           DESPAIR            DESPAIR
# 3              DESPAIR           DESPAIR            DESPAIR
# 4                  JOY           DESPAIR            DESPAIR
# 5                  JOY               NaN            DESPAIR
# 6                  NaN               NaN                NaN
# ...                ...               ...                ...
# 2455           DESPAIR           DESPAIR                MEH
# 2456               JOY               NaN            DESPAIR
# 2457               JOY               MEH            DESPAIR
# 2458               NaN               NaN                NaN
# 2459               JOY           DESPAIR            DESPAIR
#
#      Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy Q6 | LemonHeads  \
# 1                    DESPAIR          JOY         DESPAIR             MEH
# 3                        MEH          MEH             JOY             JOY
# 4                        JOY          JOY             JOY             JOY
# 5                        NaN          JOY             MEH             MEH
# 6                        NaN          NaN             NaN             NaN
# ...                      ...          ...             ...             ...
# 2455                     JOY          JOY             MEH             MEH
# 2456                     NaN          JOY         DESPAIR         DESPAIR
# 2457                 DESPAIR      DESPAIR             JOY         DESPAIR
# 2458                     NaN          NaN             NaN             NaN
# 2459                 DESPAIR          MEH         DESPAIR         DESPAIR
#
#      Q6 | Licorice (not black) Q6 | Licorice (yes black) Q6 | Lindt Truffle  \
# 1                          MEH                       JOY                MEH
# 3                          MEH                       JOY                JOY
# 4                          MEH                   DESPAIR                JOY
# 5                          MEH                       MEH                JOY
# 6                          NaN                       NaN                NaN
# ...                        ...                       ...                ...
# 2455                       JOY                   DESPAIR                JOY
# 2456                       MEH                   DESPAIR                MEH
# 2457                       MEH                   DESPAIR                JOY
# 2458                       NaN                       NaN                NaN
# 2459                   DESPAIR                   DESPAIR                JOY
#
#      Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike Q6 | Milk Duds  \
# 1           DESPAIR   DESPAIR       DESPAIR               MEH            MEH
# 3           DESPAIR       JOY           MEH               MEH        DESPAIR
# 4               MEH       MEH       DESPAIR               MEH            MEH
# 5               MEH       JOY           NaN               JOY            JOY
# 6               NaN       NaN           NaN               NaN            NaN
# ...             ...       ...           ...               ...            ...
# 2455        DESPAIR       MEH           MEH               MEH            JOY
# 2456            MEH       NaN           NaN           DESPAIR            MEH
# 2457            MEH       JOY       DESPAIR               MEH            JOY
# 2458            NaN       NaN           NaN               NaN            NaN
# 2459        DESPAIR       JOY       DESPAIR               MEH        DESPAIR
#
#      Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s Q6 | Blue M&M's  \
# 1               JOY               JOY               MEH             JOY
# 3               JOY               MEH               JOY             MEH
# 4               JOY               JOY               JOY             JOY
# 5               JOY               JOY               JOY             JOY
# 6               NaN               NaN               NaN             NaN
# ...             ...               ...               ...             ...
# 2455            JOY               MEH               JOY             JOY
# 2456            MEH               JOY               JOY             NaN
# 2457            JOY               JOY           DESPAIR             JOY
# 2458            NaN               NaN               NaN             NaN
# 2459            JOY               JOY               JOY             JOY
#
#      Q6 | Red M&M's Q6 | Green Party M&M's Q6 | Independent M&M's  \
# 1               JOY                    JOY                    JOY
# 3               MEH                    MEH                    MEH
# 4               JOY                    JOY                    JOY
# 5               JOY                    NaN                    NaN
# 6               NaN                    NaN                    NaN
# ...             ...                    ...                    ...
# 2455            MEH                    JOY                    JOY
# 2456            NaN                    NaN                    NaN
# 2457            JOY                    JOY                    JOY
# 2458            NaN                    NaN                    NaN
# 2459            JOY                    JOY                DESPAIR
#
#      Q6 | Abstained from M&M'ing. Q6 | Minibags of chips Q6 | Mint Kisses  \
# 1                         DESPAIR                DESPAIR              MEH
# 3                             MEH                DESPAIR          DESPAIR
# 4                             MEH                DESPAIR              JOY
# 5                             NaN                    JOY              JOY
# 6                             NaN                    NaN              NaN
# ...                           ...                    ...              ...
# 2455                          MEH                    MEH              JOY
# 2456                          NaN                    MEH              JOY
# 2457                      DESPAIR                    JOY              JOY
# 2458                          NaN                    NaN              NaN
# 2459                      DESPAIR                    MEH              MEH
#
#      Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers Q6 | Nerds  \
# 1             DESPAIR          DESPAIR           DESPAIR    DESPAIR
# 3                 MEH              MEH           DESPAIR        MEH
# 4                 JOY              MEH           DESPAIR        JOY
# 5                 JOY              JOY               MEH        JOY
# 6                 NaN              NaN               NaN        NaN
# ...               ...              ...               ...        ...
# 2455              JOY              JOY               MEH        MEH
# 2456              NaN              JOY           DESPAIR        JOY
# 2457              JOY          DESPAIR           DESPAIR        MEH
# 2458              NaN              NaN               NaN        NaN
# 2459          DESPAIR              JOY               MEH    DESPAIR
#
#      Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 1                   JOY           DESPAIR    DESPAIR      DESPAIR
# 3                   MEH               MEH    DESPAIR      DESPAIR
# 4                   JOY               JOY        MEH      DESPAIR
# 5                   MEH               MEH    DESPAIR      DESPAIR
# 6                   NaN               NaN        NaN          NaN
# ...                 ...               ...        ...          ...
# 2455                JOY               JOY    DESPAIR      DESPAIR
# 2456                MEH               JOY    DESPAIR      DESPAIR
# 2457            DESPAIR               MEH        MEH          MEH
# 2458                NaN               NaN        NaN          NaN
# 2459                MEH           DESPAIR        MEH      DESPAIR
#
#      Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 1           DESPAIR                                            DESPAIR
# 3           DESPAIR                                            DESPAIR
# 4               JOY                                            DESPAIR
# 5               MEH                                            DESPAIR
# 6               NaN                                                NaN
# ...             ...                                                ...
# 2455            JOY                                                MEH
# 2456            MEH                                            DESPAIR
# 2457            JOY                                                JOY
# 2458            NaN                                                NaN
# 2459        DESPAIR                                            DESPAIR
#
#      Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces  \
# 1                                JOY                 JOY
# 3                                JOY                 MEH
# 4                                JOY                 JOY
# 5                                JOY                 JOY
# 6                                NaN                 NaN
# ...                              ...                 ...
# 2455                             JOY                 JOY
# 2456                             JOY                 JOY
# 2457                             JOY                 MEH
# 2458                             NaN                 NaN
# 2459                             MEH             DESPAIR
#
#      Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 1                    DESPAIR        JOY
# 3                        MEH        MEH
# 4                        MEH        JOY
# 5                    DESPAIR        JOY
# 6                        NaN        NaN
# ...                      ...        ...
# 2455                     JOY        JOY
# 2456                     NaN        MEH
# 2457                     MEH        JOY
# 2458                     NaN        NaN
# 2459                 DESPAIR    DESPAIR
#
#      Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 1                                               DESPAIR         DESPAIR
# 3                                               DESPAIR         DESPAIR
# 4                                                   NaN             JOY
# 5                                               DESPAIR             JOY
# 6                                                   NaN             NaN
# ...                                                 ...             ...
# 2455                                                JOY             MEH
# 2456                                            DESPAIR             JOY
# 2457                                            DESPAIR         DESPAIR
# 2458                                                NaN             NaN
# 2459                                            DESPAIR         DESPAIR
#
#      Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 1                     DESPAIR                      DESPAIR           MEH
# 3                     DESPAIR                          MEH           JOY
# 4                         JOY                      DESPAIR           NaN
# 5                         JOY                          JOY           JOY
# 6                         NaN                          NaN           NaN
# ...                       ...                          ...           ...
# 2455                  DESPAIR                      DESPAIR           JOY
# 2456                  DESPAIR                          NaN           JOY
# 2457                      JOY                          MEH       DESPAIR
# 2458                      NaN                          NaN           NaN
# 2459                      MEH                      DESPAIR           JOY
#
#      Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 1                                              DESPAIR           DESPAIR
# 3                                                  MEH           DESPAIR
# 4                                                  MEH           DESPAIR
# 5                                              DESPAIR           DESPAIR
# 6                                                  NaN               NaN
# ...                                                ...               ...
# 2455                                               JOY               JOY
# 2456                                               MEH               NaN
# 2457                                           DESPAIR           DESPAIR
# 2458                                               NaN               NaN
# 2459                                               JOY           DESPAIR
#
#      Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 1               MEH          DESPAIR               MEH
# 3               MEH              MEH               JOY
# 4               JOY              JOY               MEH
# 5               MEH              MEH               MEH
# 6               NaN              NaN               NaN
# ...             ...              ...               ...
# 2455            JOY              MEH               JOY
# 2456            MEH              MEH               MEH
# 2457        DESPAIR              JOY           DESPAIR
# 2458            NaN              NaN               NaN
# 2459            MEH              MEH           DESPAIR
#
#      Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 1                                 DESPAIR     DESPAIR       DESPAIR
# 3                                     MEH         JOY           MEH
# 4                                 DESPAIR         MEH       DESPAIR
# 5                                     NaN         NaN           MEH
# 6                                     NaN         NaN           NaN
# ...                                   ...         ...           ...
# 2455                              DESPAIR         MEH           JOY
# 2456                                  NaN         JOY       DESPAIR
# 2457                              DESPAIR         MEH           MEH
# 2458                                  NaN         NaN           NaN
# 2459                              DESPAIR     DESPAIR       DESPAIR
#
#      Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 1                                            DESPAIR                   JOY
# 3                                            DESPAIR               DESPAIR
# 4                                            DESPAIR                   JOY
# 5                                            DESPAIR                   JOY
# 6                                                NaN                   NaN
# ...                                              ...                   ...
# 2455                                         DESPAIR                   MEH
# 2456                                         DESPAIR                   MEH
# 2457                                         DESPAIR                   JOY
# 2458                                             NaN                   NaN
# 2459                                         DESPAIR                   JOY
#
#      Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 1                                  JOY        DESPAIR       JOY
# 3                                  JOY            MEH       JOY
# 4                                  JOY        DESPAIR       JOY
# 5                                  JOY            MEH       JOY
# 6                                  NaN            NaN       NaN
# ...                                ...            ...       ...
# 2455                               MEH            JOY       JOY
# 2456                               MEH        DESPAIR       JOY
# 2457                               JOY            MEH       MEH
# 2458                               NaN            NaN       NaN
# 2459                               MEH        DESPAIR   DESPAIR
#
#      Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                                   MEH
# 5                                               DESPAIR
# 6                                                   NaN
# ...                                                 ...
# 2455                                                MEH
# 2456                                                NaN
# 2457                                                MEH
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 1         DESPAIR                   DESPAIR          DESPAIR
# 3             JOY                       JOY          DESPAIR
# 4             JOY                       JOY          DESPAIR
# 5         DESPAIR                       JOY          DESPAIR
# 6             NaN                       NaN              NaN
# ...           ...                       ...              ...
# 2455          JOY                   DESPAIR              MEH
# 2456          NaN                       JOY          DESPAIR
# 2457          JOY                       MEH          DESPAIR
# 2458          NaN                       NaN              NaN
# 2459          JOY                   DESPAIR              MEH
#
#      Q6 | Whole Wheat anything Q6 | York Peppermint Patties  \
# 1                      DESPAIR                      DESPAIR
# 3                      DESPAIR                      DESPAIR
# 4                      DESPAIR                          JOY
# 5                      DESPAIR                          JOY
# 6                          NaN                          NaN
# ...                        ...                          ...
# 2455                   DESPAIR                          MEH
# 2456                       MEH                          JOY
# 2457                   DESPAIR                          MEH
# 2458                       NaN                          NaN
# 2459                   DESPAIR                          JOY
#
#                                           Q7: JOY OTHER Q8: DESPAIR OTHER  \
# 1                                                Mounds               NaN
# 3     Reese's crispy crunchy bars, 5th avenue bars, ...               NaN
# 4                                                   NaN               NaN
# 5                                                   NaN               NaN
# 6                                                   NaN               NaN
# ...                                                 ...               ...
# 2455                                             Mounds  Fruit Stripe Gum
# 2456                                                NaN            Capers
# 2457  Tiny bottles of maple syrup as given out by Cr...               NaN
# 2458                                                NaN               NaN
# 2459                                                NaN               NaN
#
#                                      Q9: OTHER COMMENTS      Q10: DRESS  \
# 1     Bottom line is Twix is really the only candy w...  White and gold
# 3                                Raisins can go to hell  White and gold
# 4                                                   NaN  White and gold
# 5                                                   NaN             NaN
# 6                                                   NaN             NaN
# ...                                                 ...             ...
# 2455                                                NaN  White and gold
# 2456                                                NaN  Blue and black
# 2457                                                NaN  Blue and black
# 2458                                                NaN             NaN
# 2459  You hit all my chocolate highlights, and broug...  White and gold
#
#      Q11: DAY  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# 1      Sunday                      NaN                   1.0
# 3      Sunday                      NaN                   1.0
# 4      Friday                      NaN                   1.0
# 5         NaN                      NaN                   1.0
# 6         NaN                      NaN                   NaN
# ...       ...                      ...                   ...
# 2455   Friday                      NaN                   NaN
# 2456   Friday                      NaN                   1.0
# 2457   Friday                      NaN                   1.0
# 2458      NaN                      NaN                   NaN
# 2459   Sunday                      1.0                   NaN
#
#       Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 1                   NaN                 NaN                 (84, 25)
# 3                   NaN                 NaN                 (75, 23)
# 4                   NaN                 NaN                 (70, 10)
# 5                   NaN                 NaN                 (75, 23)
# 6                   NaN                 NaN                      NaN
# ...                 ...                 ...                      ...
# 2455                NaN                 NaN                      NaN
# 2456                NaN                 NaN                 (70, 26)
# 2457                NaN                 NaN                 (67, 35)
# 2458                NaN                 NaN                      NaN
# 2459                NaN                 NaN                 (19, 26)
#
# [2336 rows x 119 columns]

# %%
cd['Q4: COUNTRY'].value_counts()
# Out:
# USA              668
# United States    479
# usa              209
# Canada           170
# Usa              137
#                 ...
# 'merica            1
# A                  1
# 1                  1
# UAE                1
# UK                 1
# Name: Q4: COUNTRY, Length: 122, dtype: int64

# %%
cd['Q4: COUNTRY']=cd['Q4: COUNTRY'].str.upper()
cd['Q4: COUNTRY']=cd['Q4: COUNTRY'].str.strip()
cd['Q4: COUNTRY']=cd['Q4: COUNTRY'].str.replace('.','')
# Out:
# <ipython-input-14-96b9d4cee3cf>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   cd['Q4: COUNTRY']=cd['Q4: COUNTRY'].str.replace('.','')

# %%
cd['Q4: COUNTRY'].value_counts()
# Out:
# USA                                                                    1093
# UNITED STATES                                                           571
# CANADA                                                                  213
# US                                                                      187
# UNITED STATES OF AMERICA                                                 72
# UK                                                                       19
# UNITED KINGDOM                                                           14
# GERMANY                                                                  10
# AUSTRALIA                                                                 7
# NETHERLANDS                                                               6
# SCOTLAND                                                                  5
# JAPAN                                                                     5
# AMERICA                                                                   5
# UNITES STATES                                                             4
# IRELAND                                                                   4
# US OF A                                                                   4
# MEXICO                                                                    4
# SWITZERLAND                                                               3
# FRANCE                                                                    3
# THE UNITED STATES                                                         2
# UNITED STATE                                                              2
# DENMARK                                                                   2
# UNITED STATED                                                             2
# CHINA                                                                     2
# HONG KONG                                                                 2
# SWEDEN                                                                    2
# UNHINGED STATES                                                           1
# A                                                                         1
# N AMERICA                                                                 1
# EUROPE                                                                    1
# UNITED STATSS                                                             1
# ICELAND                                                                   1
# 32                                                                        1
# COSTA RICA                                                                1
# MURRIKA                                                                   1
# NARNIA                                                                    1
# ATLANTIS                                                                  1
# 1                                                                         1
# SUBSCRIBE TO DM4UZ3 ON YOUTUBE                                            1
# USA! USA! USA!                                                            1
# UNITE STATES                                                              1
# KOREA                                                                     1
# UNIED STATES                                                              1
# USSA                                                                      1
# 'MERICA                                                                   1
# UNITED STSTES                                                             1
# I PRETEND TO BE FROM CANADA, BUT I AM REALLY FROM THE UNITED STATES       1
# PITTSBURGH                                                                1
# SINGAPORE                                                                 1
# CAN                                                                       1
# USAUSAUSA                                                                 1
# GREECE                                                                    1
# USAA                                                                      1
# MURICA                                                                    1
# USA USA USA!!!!                                                           1
# 35                                                                        1
# ENDLAND                                                                   1
# SOVIET CANUCKISTAN                                                        1
# UD                                                                        1
# FEAR AND LOATHING                                                         1
# THE UNITED STATES OF AMERICA                                              1
# USAS                                                                      1
# CALIFORNIA                                                                1
# 45                                                                        1
# INDONESIA                                                                 1
# U S                                                                       1
# UNITED SATES                                                              1
# UNITED STAES                                                              1
# UAE                                                                       1
# USA? HARD TO TELL ANYMORE                                                 1
# EARTH                                                                     1
# 46                                                                        1
# UNITED STATEA                                                             1
# NEW JERSEY                                                                1
# CANAE                                                                     1
# U S A                                                                     1
# TAIWAN                                                                    1
# I DON'T KNOW ANYMORE                                                      1
# FINLAND                                                                   1
# SOUTH AFRICA                                                              1
# ENGLAND                                                                   1
# INSANITY LATELY                                                           1
# TRUMPISTAN                                                                1
# NORTH CAROLINA                                                            1
# AHEMAMERCA                                                                1
# THE NETHERLANDS                                                           1
# ALASKA                                                                    1
# SPAIN                                                                     1
# Name: Q4: COUNTRY, dtype: int64

# %%
len(cd['Q4: COUNTRY'])
# Out:
# 2336

# %%
x='USA'
cd['Q4: COUNTRY'].replace({"United States": x , "'MERICA": x,"UNITED STSTES": x,"USA USA USA!!!!": x,"UNITED STATES": x}, inplace=True)

# %%
cd['Q4: COUNTRY'].value_counts()
# Out:
# USA                                                                    1667
# CANADA                                                                  213
# US                                                                      187
# UNITED STATES OF AMERICA                                                 72
# UK                                                                       19
# UNITED KINGDOM                                                           14
# GERMANY                                                                  10
# AUSTRALIA                                                                 7
# NETHERLANDS                                                               6
# SCOTLAND                                                                  5
# AMERICA                                                                   5
# JAPAN                                                                     5
# MEXICO                                                                    4
# US OF A                                                                   4
# UNITES STATES                                                             4
# IRELAND                                                                   4
# SWITZERLAND                                                               3
# FRANCE                                                                    3
# UNITED STATE                                                              2
# THE UNITED STATES                                                         2
# HONG KONG                                                                 2
# UNITED STATED                                                             2
# SWEDEN                                                                    2
# DENMARK                                                                   2
# CHINA                                                                     2
# A                                                                         1
# GREECE                                                                    1
# 1                                                                         1
# ATLANTIS                                                                  1
# N AMERICA                                                                 1
# USA! USA! USA!                                                            1
# ICELAND                                                                   1
# UNITED STATSS                                                             1
# EUROPE                                                                    1
# COSTA RICA                                                                1
# MURICA                                                                    1
# USSA                                                                      1
# PITTSBURGH                                                                1
# 35                                                                        1
# USAA                                                                      1
# UNITE STATES                                                              1
# UNHINGED STATES                                                           1
# CAN                                                                       1
# SINGAPORE                                                                 1
# I PRETEND TO BE FROM CANADA, BUT I AM REALLY FROM THE UNITED STATES       1
# UNIED STATES                                                              1
# KOREA                                                                     1
# SUBSCRIBE TO DM4UZ3 ON YOUTUBE                                            1
# NARNIA                                                                    1
# MURRIKA                                                                   1
# 32                                                                        1
# USAUSAUSA                                                                 1
# TRUMPISTAN                                                                1
# UNITED STATEA                                                             1
# EARTH                                                                     1
# SOVIET CANUCKISTAN                                                        1
# UD                                                                        1
# FEAR AND LOATHING                                                         1
# THE UNITED STATES OF AMERICA                                              1
# USAS                                                                      1
# CALIFORNIA                                                                1
# 45                                                                        1
# INDONESIA                                                                 1
# U S                                                                       1
# UNITED SATES                                                              1
# UNITED STAES                                                              1
# UAE                                                                       1
# USA? HARD TO TELL ANYMORE                                                 1
# ENDLAND                                                                   1
# ALASKA                                                                    1
# 46                                                                        1
# NEW JERSEY                                                                1
# CANAE                                                                     1
# U S A                                                                     1
# TAIWAN                                                                    1
# I DON'T KNOW ANYMORE                                                      1
# FINLAND                                                                   1
# SOUTH AFRICA                                                              1
# ENGLAND                                                                   1
# INSANITY LATELY                                                           1
# NORTH CAROLINA                                                            1
# AHEMAMERCA                                                                1
# THE NETHERLANDS                                                           1
# SPAIN                                                                     1
# Name: Q4: COUNTRY, dtype: int64

# %%
cd['Q4: COUNTRY'].replace({"US": x , "'MERICA": x,"UNITED STATES OF AMERICA": x,"U S A": x,"US OF A": x,"UNIED STATES": x,"UNITED STATSS": x}, inplace=True)

# %%
cd['Q4: COUNTRY'].value_counts()
# Out:
# USA                                                                    1933
# CANADA                                                                  213
# UK                                                                       19
# UNITED KINGDOM                                                           14
# GERMANY                                                                  10
# AUSTRALIA                                                                 7
# NETHERLANDS                                                               6
# JAPAN                                                                     5
# SCOTLAND                                                                  5
# AMERICA                                                                   5
# UNITES STATES                                                             4
# MEXICO                                                                    4
# IRELAND                                                                   4
# SWITZERLAND                                                               3
# FRANCE                                                                    3
# UNITED STATE                                                              2
# UNITED STATED                                                             2
# CHINA                                                                     2
# DENMARK                                                                   2
# THE UNITED STATES                                                         2
# HONG KONG                                                                 2
# SWEDEN                                                                    2
# A                                                                         1
# USA! USA! USA!                                                            1
# MURICA                                                                    1
# 1                                                                         1
# ATLANTIS                                                                  1
# ICELAND                                                                   1
# EUROPE                                                                    1
# N AMERICA                                                                 1
# COSTA RICA                                                                1
# USAUSAUSA                                                                 1
# USSA                                                                      1
# PITTSBURGH                                                                1
# 35                                                                        1
# USAA                                                                      1
# UNITE STATES                                                              1
# UNHINGED STATES                                                           1
# CAN                                                                       1
# SINGAPORE                                                                 1
# I PRETEND TO BE FROM CANADA, BUT I AM REALLY FROM THE UNITED STATES       1
# KOREA                                                                     1
# SUBSCRIBE TO DM4UZ3 ON YOUTUBE                                            1
# NARNIA                                                                    1
# MURRIKA                                                                   1
# 32                                                                        1
# GREECE                                                                    1
# TRUMPISTAN                                                                1
# UNITED STATEA                                                             1
# ALASKA                                                                    1
# SOVIET CANUCKISTAN                                                        1
# UD                                                                        1
# THE UNITED STATES OF AMERICA                                              1
# USAS                                                                      1
# CALIFORNIA                                                                1
# 45                                                                        1
# INDONESIA                                                                 1
# U S                                                                       1
# UNITED SATES                                                              1
# FEAR AND LOATHING                                                         1
# UNITED STAES                                                              1
# UAE                                                                       1
# USA? HARD TO TELL ANYMORE                                                 1
# EARTH                                                                     1
# ENDLAND                                                                   1
# 46                                                                        1
# NEW JERSEY                                                                1
# CANAE                                                                     1
# TAIWAN                                                                    1
# I DON'T KNOW ANYMORE                                                      1
# FINLAND                                                                   1
# SOUTH AFRICA                                                              1
# ENGLAND                                                                   1
# INSANITY LATELY                                                           1
# NORTH CAROLINA                                                            1
# AHEMAMERCA                                                                1
# THE NETHERLANDS                                                           1
# SPAIN                                                                     1
# Name: Q4: COUNTRY, dtype: int64

# %%
cd['Q4: COUNTRY'].replace({"N AMERICA": x , "'MERICA": x,"I PRETEND TO BE FROM CANADA, BUT I AM REALLY FROM THE UNITED STATES": x,"UNITED STATEA": x,"MURICA": x,"UNITED STAES": x,"USA! USA! USA!": x,"UNITES STATES":x}, inplace=True)

# %%
cd['Q4: COUNTRY'].unique()
# Out:
# array(['USA', nan, 'CANADA', 'UK', 'UNITED KINGDOM', 'UAE', 'ENGLAND',
#        'MEXICO', 'USAUSAUSA', 'AMERICA', '35', 'FRANCE', 'FINLAND',
#        'UNHINGED STATES', 'THE UNITED STATES', 'NORTH CAROLINA',
#        'NETHERLANDS', 'GERMANY', 'EUROPE', 'EARTH', 'U S', 'COSTA RICA',
#        'THE UNITED STATES OF AMERICA', 'UNITE STATES', '46', 'AUSTRALIA',
#        'INSANITY LATELY', 'GREECE', 'USA? HARD TO TELL ANYMORE', 'USAS',
#        'PITTSBURGH', '45', 'UNITED STATE', '32', 'A', 'CAN', 'CANAE',
#        'TRUMPISTAN', 'IRELAND', 'UNITED SATES', 'KOREA', 'CALIFORNIA',
#        'JAPAN', 'SOUTH AFRICA', 'ICELAND', 'SCOTLAND', 'DENMARK',
#        'UNITED STATED', 'SWITZERLAND', 'AHEMAMERCA', 'UD', 'NEW JERSEY',
#        'INDONESIA', 'THE NETHERLANDS', 'ENDLAND', 'ATLANTIS', 'MURRIKA',
#        'USAA', 'ALASKA', 'SOVIET CANUCKISTAN', 'SINGAPORE', 'USSA',
#        'CHINA', 'TAIWAN', 'HONG KONG', 'SPAIN', 'SWEDEN', 'NARNIA', '1',
#        'SUBSCRIBE TO DM4UZ3 ON YOUTUBE', "I DON'T KNOW ANYMORE",
#        'FEAR AND LOATHING'], dtype=object)

# %%
cd['Q4: COUNTRY'].replace({"AHEMAMERCA": x , "USAUSAUSA": x,"THE UNITED STATES": x,"NORTH CAROLINA": x,"EARTH": x,"UNITE STATES": x,"USA? HARD TO TELL ANYMORE": x,"USAS":x}, inplace=True)
cd['Q4: COUNTRY'].replace({"PITTSBURGH": x , "UNITED STATE": x,"UNITED SATES": x,"UNITED STATED": x,"USSA": x,"USAA": x,"USA? HARD TO TELL ANYMORE": x,"USAS":x}, inplace=True)

# %%
cd['Q4: COUNTRY'].unique()
# Out:
# array(['USA', nan, 'CANADA', 'UK', 'UNITED KINGDOM', 'UAE', 'ENGLAND',
#        'MEXICO', 'AMERICA', '35', 'FRANCE', 'FINLAND', 'UNHINGED STATES',
#        'NETHERLANDS', 'GERMANY', 'EUROPE', 'U S', 'COSTA RICA',
#        'THE UNITED STATES OF AMERICA', '46', 'AUSTRALIA',
#        'INSANITY LATELY', 'GREECE', '45', '32', 'A', 'CAN', 'CANAE',
#        'TRUMPISTAN', 'IRELAND', 'KOREA', 'CALIFORNIA', 'JAPAN',
#        'SOUTH AFRICA', 'ICELAND', 'SCOTLAND', 'DENMARK', 'SWITZERLAND',
#        'UD', 'NEW JERSEY', 'INDONESIA', 'THE NETHERLANDS', 'ENDLAND',
#        'ATLANTIS', 'MURRIKA', 'ALASKA', 'SOVIET CANUCKISTAN', 'SINGAPORE',
#        'CHINA', 'TAIWAN', 'HONG KONG', 'SPAIN', 'SWEDEN', 'NARNIA', '1',
#        'SUBSCRIBE TO DM4UZ3 ON YOUTUBE', "I DON'T KNOW ANYMORE",
#        'FEAR AND LOATHING'], dtype=object)

# %%
cd['Q4: COUNTRY'].replace({"U S": x , "THE UNITED STATES OF AMERICA": x,"SUBSCRIBE TO DM4UZ3 ON YOUTUBE": x,"I DON'T KNOW ANYMORE": x,"FEAR AND LOATHING": x,"MURRIKA":x
        }, inplace=True)

# %%
cd['Q4: COUNTRY'].value_counts()
# Out:
# USA                   1966
# CANADA                 213
# UK                      19
# UNITED KINGDOM          14
# GERMANY                 10
# AUSTRALIA                7
# NETHERLANDS              6
# JAPAN                    5
# SCOTLAND                 5
# AMERICA                  5
# MEXICO                   4
# IRELAND                  4
# SWITZERLAND              3
# FRANCE                   3
# CHINA                    2
# HONG KONG                2
# DENMARK                  2
# SWEDEN                   2
# ALASKA                   1
# GREECE                   1
# 35                       1
# EUROPE                   1
# THE NETHERLANDS          1
# SINGAPORE                1
# ICELAND                  1
# COSTA RICA               1
# ATLANTIS                 1
# KOREA                    1
# UNHINGED STATES          1
# CAN                      1
# NARNIA                   1
# 1                        1
# FINLAND                  1
# TRUMPISTAN               1
# INSANITY LATELY          1
# SOVIET CANUCKISTAN       1
# UD                       1
# CALIFORNIA               1
# 45                       1
# INDONESIA                1
# 32                       1
# UAE                      1
# A                        1
# ENDLAND                  1
# 46                       1
# NEW JERSEY               1
# CANAE                    1
# TAIWAN                   1
# SOUTH AFRICA             1
# ENGLAND                  1
# SPAIN                    1
# Name: Q4: COUNTRY, dtype: int64

# %%
cd['Q4: COUNTRY'].replace({"45": x , "46": x,"32": x,"36": x,"1": x,"A":x,'ALASKA':x,'NEW JERSEY':x,'INSANITY LATELY':x,'UNHINGED STATES':x
        }, inplace=True)

# %%
cd['Q4: COUNTRY'].unique()
# Out:
# array(['USA', nan, 'CANADA', 'UK', 'UNITED KINGDOM', 'UAE', 'ENGLAND',
#        'MEXICO', 'AMERICA', '35', 'FRANCE', 'FINLAND', 'NETHERLANDS',
#        'GERMANY', 'EUROPE', 'COSTA RICA', 'AUSTRALIA', 'GREECE', 'CAN',
#        'CANAE', 'TRUMPISTAN', 'IRELAND', 'KOREA', 'CALIFORNIA', 'JAPAN',
#        'SOUTH AFRICA', 'ICELAND', 'SCOTLAND', 'DENMARK', 'SWITZERLAND',
#        'UD', 'INDONESIA', 'THE NETHERLANDS', 'ENDLAND', 'ATLANTIS',
#        'SOVIET CANUCKISTAN', 'SINGAPORE', 'CHINA', 'TAIWAN', 'HONG KONG',
#        'SPAIN', 'SWEDEN', 'NARNIA'], dtype=object)

# %%
cd['Q4: COUNTRY'].replace({'NARNIA': x ,'AMERICA': x,'CALIFORNIA': x,'NARNIA': x,'UD': x,'35':x
        }, inplace=True)

# %%
cd['Q4: COUNTRY'].unique()
# Out:
# array(['USA', nan, 'CANADA', 'UK', 'UNITED KINGDOM', 'UAE', 'ENGLAND',
#        'MEXICO', 'FRANCE', 'FINLAND', 'NETHERLANDS', 'GERMANY', 'EUROPE',
#        'COSTA RICA', 'AUSTRALIA', 'GREECE', 'CAN', 'CANAE', 'TRUMPISTAN',
#        'IRELAND', 'KOREA', 'JAPAN', 'SOUTH AFRICA', 'ICELAND', 'SCOTLAND',
#        'DENMARK', 'SWITZERLAND', 'INDONESIA', 'THE NETHERLANDS',
#        'ENDLAND', 'ATLANTIS', 'SOVIET CANUCKISTAN', 'SINGAPORE', 'CHINA',
#        'TAIWAN', 'HONG KONG', 'SPAIN', 'SWEDEN'], dtype=object)

# %%
y='CANADA'
z='UK'
cd['Q4: COUNTRY'].replace({'CANAE':y,'CAN':y,'UNITED KINGDOM':z,'ENGLAND':z
        }, inplace=True)

# %%
cd[cd['Q4: COUNTRY']=='EUROPE']
# Out:
#      Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 433     90273991            Yes     Female      10      EUROPE
#
#     Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 433                          America            DESPAIR
#
#     Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 433                                                MEH
#
#     Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 433                           JOY              MEH                      MEH
#
#     Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 433                       DESPAIR              MEH            DESPAIR
#
#     Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 433                DESPAIR               JOY                     JOY
#
#     Q6 | Candy Corn  \
# 433         DESPAIR
#
#     Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 433                                            DESPAIR
#
#     Q6 | Caramellos Q6 | Cash, or other forms of legal tender Q6 | Chardonnay  \
# 433             MEH                                       JOY             JOY
#
#     Q6 | Chick-o-Sticks (we don’t know what that is) Q6 | Chiclets  \
# 433                                              JOY           MEH
#
#     Q6 | Coffee Crisp Q6 | Creepy Religious comics/Chick Tracts  \
# 433               JOY                                   DESPAIR
#
#     Q6 | Dental paraphenalia Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 433                  DESPAIR       MEH            JOY                JOY
#
#     Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 433                          DESPAIR              MEH                   MEH
#
#     Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 433                 JOY                      DESPAIR
#
#     Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 433                          MEH             MEH                MEH
#
#     Q6 | Heath Bar Q6 | Hershey's Dark Chocolate  \
# 433        DESPAIR                           JOY
#
#     Q6 | Hershey’s Milk Chocolate Q6 | Hershey's Kisses  \
# 433                           MEH                   MEH
#
#     Q6 | Hugs (actual physical hugs) Q6 | Jolly Rancher (bad flavor)  \
# 433                          DESPAIR                         DESPAIR
#
#     Q6 | Jolly Ranchers (good flavor) Q6 | JoyJoy (Mit Iodine!)  \
# 433                               JOY                   DESPAIR
#
#     Q6 | Junior Mints Q6 | Senior Mints Q6 | Kale smoothie  \
# 433               JOY               MEH            DESPAIR
#
#     Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy Q6 | LemonHeads  \
# 433                     MEH          JOY             MEH             MEH
#
#     Q6 | Licorice (not black) Q6 | Licorice (yes black) Q6 | Lindt Truffle  \
# 433                       MEH                       JOY                JOY
#
#     Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike Q6 | Milk Duds  \
# 433            MEH       JOY           MEH               MEH        DESPAIR
#
#     Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s Q6 | Blue M&M's  \
# 433            MEH               MEH               JOY             MEH
#
#     Q6 | Red M&M's Q6 | Green Party M&M's Q6 | Independent M&M's  \
# 433            MEH                    MEH                    MEH
#
#     Q6 | Abstained from M&M'ing. Q6 | Minibags of chips Q6 | Mint Kisses  \
# 433                          MEH                DESPAIR              MEH
#
#     Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers Q6 | Nerds  \
# 433              MEH              JOY               JOY        MEH
#
#     Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 433                JOY               MEH    DESPAIR      DESPAIR
#
#     Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 433            MEH                                                JOY
#
#     Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces  \
# 433                             MEH                 JOY
#
#     Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 433                     MEH    DESPAIR
#
#     Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 433                                            DESPAIR         DESPAIR
#
#     Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 433                      JOY                          MEH           JOY
#
#     Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 433                                               JOY               JOY
#
#     Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 433            JOY              MEH           DESPAIR
#
#     Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 433                              DESPAIR         JOY       DESPAIR
#
#     Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 433                                         DESPAIR               DESPAIR
#
#     Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 433                               JOY        DESPAIR       MEH
#
#     Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 433                                                JOY
#
#     Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 433          JOY                       MEH          DESPAIR
#
#     Q6 | Whole Wheat anything Q6 | York Peppermint Patties Q7: JOY OTHER  \
# 433                   DESPAIR                          JOY  Sugar Daddys
#
#     Q8: DESPAIR OTHER Q9: OTHER COMMENTS      Q10: DRESS Q11: DAY  \
# 433    Caramel Onions                NaN  Blue and black   Friday
#
#      Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  Q12: MEDIA [ESPN]  \
# 433                      NaN                   NaN                NaN
#
#      Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 433                 NaN                      NaN

# %%
cd['Q4: COUNTRY'].replace({'EUROPE':x,'ATLANTIS':x}, inplace=True)

# %%
cd['Q4: COUNTRY'].unique()
# Out:
# array(['USA', nan, 'CANADA', 'UK', 'UAE', 'MEXICO', 'FRANCE', 'FINLAND',
#        'NETHERLANDS', 'GERMANY', 'COSTA RICA', 'AUSTRALIA', 'GREECE',
#        'TRUMPISTAN', 'IRELAND', 'KOREA', 'JAPAN', 'SOUTH AFRICA',
#        'ICELAND', 'SCOTLAND', 'DENMARK', 'SWITZERLAND', 'INDONESIA',
#        'THE NETHERLANDS', 'ENDLAND', 'SOVIET CANUCKISTAN', 'SINGAPORE',
#        'CHINA', 'TAIWAN', 'HONG KONG', 'SPAIN', 'SWEDEN'], dtype=object)

# %%
cd.dropna(subset=['Q4: COUNTRY'],inplace=True)

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male      44         USA
# 3        90272840             No       Male      40         USA
# 4        90272841             No       Male      23         USA
# 6        90272853             No       Male      53         USA
# 7        90272854             No       Male      33      CANADA
# ...           ...            ...        ...     ...         ...
# 2455     90314359             No       Male      24         USA
# 2456     90314580             No     Female      33         USA
# 2457     90314634             No     Female      26         USA
# 2458     90314658             No       Male      58         USA
# 2459     90314802             No     Female      66         USA
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 1                                  NM                MEH
# 3                                  or                MEH
# 4                            exton pa                JOY
# 6                           Colorado                 NaN
# 7                             ontario                JOY
# ...                               ...                ...
# 2455                               MD                JOY
# 2456                         New York                MEH
# 2457                        Tennessee                MEH
# 2458                   North Carolina                NaN
# 2459                     Pennsylvania            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   NaN
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 1                              JOY              MEH                  DESPAIR
# 3                              JOY              MEH                      MEH
# 4                              JOY          DESPAIR                      MEH
# 6                              NaN              NaN                      NaN
# 7                              JOY          DESPAIR                  DESPAIR
# ...                            ...              ...                      ...
# 2455                           MEH          DESPAIR                  DESPAIR
# 2456                           JOY              NaN                      NaN
# 2457                           JOY          DESPAIR                      MEH
# 2458                           NaN              NaN                      NaN
# 2459                           JOY          DESPAIR                  DESPAIR
#
#      Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 1                          DESPAIR          DESPAIR            DESPAIR
# 3                          DESPAIR              MEH            DESPAIR
# 4                          DESPAIR              MEH            DESPAIR
# 6                              NaN              NaN                NaN
# 7                              MEH              JOY                MEH
# ...                            ...              ...                ...
# 2455                           MEH              MEH            DESPAIR
# 2456                           NaN              NaN            DESPAIR
# 2457                           JOY          DESPAIR                MEH
# 2458                           NaN              NaN                NaN
# 2459                       DESPAIR          DESPAIR                MEH
#
#      Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 1                   DESPAIR           DESPAIR                     MEH
# 3                   DESPAIR               MEH                     MEH
# 4                   DESPAIR               MEH                     MEH
# 6                       NaN               NaN                     NaN
# 7                       JOY               JOY                     JOY
# ...                     ...               ...                     ...
# 2455                DESPAIR               MEH                 DESPAIR
# 2456                DESPAIR               JOY                     JOY
# 2457                    MEH           DESPAIR                     JOY
# 2458                    NaN               NaN                     NaN
# 2459                DESPAIR               JOY                     MEH
#
#      Q6 | Candy Corn  \
# 1                MEH
# 3            DESPAIR
# 4            DESPAIR
# 6                NaN
# 7                JOY
# ...              ...
# 2455         DESPAIR
# 2456             JOY
# 2457         DESPAIR
# 2458             NaN
# 2459             MEH
#
#      Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   NaN
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                                MEH
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Caramellos Q6 | Cash, or other forms of legal tender  \
# 1                MEH                                       JOY
# 3                MEH                                       JOY
# 4                JOY                                       MEH
# 6                NaN                                       NaN
# 7                JOY                                       JOY
# ...              ...                                       ...
# 2455             JOY                                       JOY
# 2456             JOY                                       JOY
# 2457         DESPAIR                                       JOY
# 2458             NaN                                       NaN
# 2459             MEH                                       JOY
#
#      Q6 | Chardonnay Q6 | Chick-o-Sticks (we don’t know what that is)  \
# 1                MEH                                          DESPAIR
# 3                MEH                                              JOY
# 4                JOY                                          DESPAIR
# 6                NaN                                              NaN
# 7                JOY                                          DESPAIR
# ...              ...                                              ...
# 2455             JOY                                              MEH
# 2456             JOY                                              JOY
# 2457             JOY                                              MEH
# 2458             NaN                                              NaN
# 2459             JOY                                          DESPAIR
#
#      Q6 | Chiclets Q6 | Coffee Crisp  \
# 1          DESPAIR           DESPAIR
# 3              MEH           DESPAIR
# 4          DESPAIR               MEH
# 6              NaN               NaN
# 7              MEH               MEH
# ...            ...               ...
# 2455           JOY               JOY
# 2456       DESPAIR               NaN
# 2457           MEH           DESPAIR
# 2458           NaN               NaN
# 2459           MEH           DESPAIR
#
#      Q6 | Creepy Religious comics/Chick Tracts Q6 | Dental paraphenalia  \
# 1                                      DESPAIR                  DESPAIR
# 3                                      DESPAIR                  DESPAIR
# 4                                      DESPAIR                  DESPAIR
# 6                                          NaN                      NaN
# 7                                      DESPAIR                  DESPAIR
# ...                                        ...                      ...
# 2455                                   DESPAIR                      MEH
# 2456                                   DESPAIR                  DESPAIR
# 2457                                   DESPAIR                  DESPAIR
# 2458                                       NaN                      NaN
# 2459                                   DESPAIR                  DESPAIR
#
#      Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 1          MEH            JOY            DESPAIR
# 3          JOY            JOY                MEH
# 4          MEH            JOY            DESPAIR
# 6          NaN            NaN                NaN
# 7          MEH            MEH                JOY
# ...        ...            ...                ...
# 2455   DESPAIR            JOY                MEH
# 2456   DESPAIR            MEH                NaN
# 2457       MEH            JOY                MEH
# 2458       NaN            NaN                NaN
# 2459       JOY            JOY                MEH
#
#      Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 1                             DESPAIR          DESPAIR               DESPAIR
# 3                                 MEH              JOY                   JOY
# 4                             DESPAIR          DESPAIR                   MEH
# 6                                 NaN              NaN                   NaN
# 7                             DESPAIR          DESPAIR               DESPAIR
# ...                               ...              ...                   ...
# 2455                              JOY          DESPAIR                   JOY
# 2456                              MEH          DESPAIR                   NaN
# 2457                              JOY              JOY               DESPAIR
# 2458                              NaN              NaN                   NaN
# 2459                          DESPAIR              MEH               DESPAIR
#
#      Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 1                    MEH                      DESPAIR
# 3                    MEH                      DESPAIR
# 4                    MEH                      DESPAIR
# 6                    NaN                          NaN
# 7                DESPAIR                      DESPAIR
# ...                  ...                          ...
# 2455                 JOY                          JOY
# 2456             DESPAIR                      DESPAIR
# 2457             DESPAIR                      DESPAIR
# 2458                 NaN                          NaN
# 2459                 JOY                      DESPAIR
#
#      Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 1                             MEH             MEH            DESPAIR
# 3                             JOY             MEH                MEH
# 4                             JOY             MEH            DESPAIR
# 6                             NaN             NaN                NaN
# 7                             JOY         DESPAIR            DESPAIR
# ...                           ...             ...                ...
# 2455                          MEH         DESPAIR                MEH
# 2456                          MEH             MEH            DESPAIR
# 2457                          MEH             MEH            DESPAIR
# 2458                          NaN             NaN                NaN
# 2459                          MEH         DESPAIR            DESPAIR
#
#      Q6 | Heath Bar Q6 | Hershey's Dark Chocolate  \
# 1               MEH                           JOY
# 3           DESPAIR                           MEH
# 4           DESPAIR                           JOY
# 6               NaN                           NaN
# 7           DESPAIR                           JOY
# ...             ...                           ...
# 2455        DESPAIR                           JOY
# 2456            JOY                           MEH
# 2457            MEH                           JOY
# 2458            NaN                           NaN
# 2459        DESPAIR                           JOY
#
#      Q6 | Hershey’s Milk Chocolate Q6 | Hershey's Kisses  \
# 1                              JOY                   MEH
# 3                              MEH                   MEH
# 4                              MEH                   MEH
# 6                              NaN                   NaN
# 7                              MEH                   MEH
# ...                            ...                   ...
# 2455                           MEH                   MEH
# 2456                           JOY                   MEH
# 2457                           JOY                   JOY
# 2458                           NaN                   NaN
# 2459                           JOY                   JOY
#
#      Q6 | Hugs (actual physical hugs) Q6 | Jolly Rancher (bad flavor)  \
# 1                             DESPAIR                         DESPAIR
# 3                                 MEH                             MEH
# 4                             DESPAIR                             MEH
# 6                                 NaN                             NaN
# 7                             DESPAIR                         DESPAIR
# ...                               ...                             ...
# 2455                              JOY                             MEH
# 2456                          DESPAIR                             MEH
# 2457                              MEH                         DESPAIR
# 2458                              NaN                             NaN
# 2459                          DESPAIR                         DESPAIR
#
#      Q6 | Jolly Ranchers (good flavor) Q6 | JoyJoy (Mit Iodine!)  \
# 1                                  MEH                   DESPAIR
# 3                                  MEH                   DESPAIR
# 4                                  JOY                       MEH
# 6                                  NaN                       NaN
# 7                              DESPAIR                   DESPAIR
# ...                                ...                       ...
# 2455                               MEH                       MEH
# 2456                               JOY                       NaN
# 2457                               JOY                   DESPAIR
# 2458                               NaN                       NaN
# 2459                               MEH                   DESPAIR
#
#      Q6 | Junior Mints Q6 | Senior Mints Q6 | Kale smoothie  \
# 1              DESPAIR           DESPAIR            DESPAIR
# 3              DESPAIR           DESPAIR            DESPAIR
# 4                  JOY           DESPAIR            DESPAIR
# 6                  NaN               NaN                NaN
# 7              DESPAIR           DESPAIR            DESPAIR
# ...                ...               ...                ...
# 2455           DESPAIR           DESPAIR                MEH
# 2456               JOY               NaN            DESPAIR
# 2457               JOY               MEH            DESPAIR
# 2458               NaN               NaN                NaN
# 2459               JOY           DESPAIR            DESPAIR
#
#      Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy Q6 | LemonHeads  \
# 1                    DESPAIR          JOY         DESPAIR             MEH
# 3                        MEH          MEH             JOY             JOY
# 4                        JOY          JOY             JOY             JOY
# 6                        NaN          NaN             NaN             NaN
# 7                    DESPAIR          MEH             MEH             JOY
# ...                      ...          ...             ...             ...
# 2455                     JOY          JOY             MEH             MEH
# 2456                     NaN          JOY         DESPAIR         DESPAIR
# 2457                 DESPAIR      DESPAIR             JOY         DESPAIR
# 2458                     NaN          NaN             NaN             NaN
# 2459                 DESPAIR          MEH         DESPAIR         DESPAIR
#
#      Q6 | Licorice (not black) Q6 | Licorice (yes black) Q6 | Lindt Truffle  \
# 1                          MEH                       JOY                MEH
# 3                          MEH                       JOY                JOY
# 4                          MEH                   DESPAIR                JOY
# 6                          NaN                       NaN                NaN
# 7                          MEH                   DESPAIR            DESPAIR
# ...                        ...                       ...                ...
# 2455                       JOY                   DESPAIR                JOY
# 2456                       MEH                   DESPAIR                MEH
# 2457                       MEH                   DESPAIR                JOY
# 2458                       NaN                       NaN                NaN
# 2459                   DESPAIR                   DESPAIR                JOY
#
#      Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike Q6 | Milk Duds  \
# 1           DESPAIR   DESPAIR       DESPAIR               MEH            MEH
# 3           DESPAIR       JOY           MEH               MEH        DESPAIR
# 4               MEH       MEH       DESPAIR               MEH            MEH
# 6               NaN       NaN           NaN               NaN            NaN
# 7               MEH       JOY           JOY               JOY            JOY
# ...             ...       ...           ...               ...            ...
# 2455        DESPAIR       MEH           MEH               MEH            JOY
# 2456            MEH       NaN           NaN           DESPAIR            MEH
# 2457            MEH       JOY       DESPAIR               MEH            JOY
# 2458            NaN       NaN           NaN               NaN            NaN
# 2459        DESPAIR       JOY       DESPAIR               MEH        DESPAIR
#
#      Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s Q6 | Blue M&M's  \
# 1               JOY               JOY               MEH             JOY
# 3               JOY               MEH               JOY             MEH
# 4               JOY               JOY               JOY             JOY
# 6               NaN               NaN               NaN             NaN
# 7               JOY               JOY               JOY             JOY
# ...             ...               ...               ...             ...
# 2455            JOY               MEH               JOY             JOY
# 2456            MEH               JOY               JOY             NaN
# 2457            JOY               JOY           DESPAIR             JOY
# 2458            NaN               NaN               NaN             NaN
# 2459            JOY               JOY               JOY             JOY
#
#      Q6 | Red M&M's Q6 | Green Party M&M's Q6 | Independent M&M's  \
# 1               JOY                    JOY                    JOY
# 3               MEH                    MEH                    MEH
# 4               JOY                    JOY                    JOY
# 6               NaN                    NaN                    NaN
# 7               JOY                    JOY                    MEH
# ...             ...                    ...                    ...
# 2455            MEH                    JOY                    JOY
# 2456            NaN                    NaN                    NaN
# 2457            JOY                    JOY                    JOY
# 2458            NaN                    NaN                    NaN
# 2459            JOY                    JOY                DESPAIR
#
#      Q6 | Abstained from M&M'ing. Q6 | Minibags of chips Q6 | Mint Kisses  \
# 1                         DESPAIR                DESPAIR              MEH
# 3                             MEH                DESPAIR          DESPAIR
# 4                             MEH                DESPAIR              JOY
# 6                             NaN                    NaN              NaN
# 7                         DESPAIR                    JOY          DESPAIR
# ...                           ...                    ...              ...
# 2455                          MEH                    MEH              JOY
# 2456                          NaN                    MEH              JOY
# 2457                      DESPAIR                    JOY              JOY
# 2458                          NaN                    NaN              NaN
# 2459                      DESPAIR                    MEH              MEH
#
#      Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers Q6 | Nerds  \
# 1             DESPAIR          DESPAIR           DESPAIR    DESPAIR
# 3                 MEH              MEH           DESPAIR        MEH
# 4                 JOY              MEH           DESPAIR        JOY
# 6                 NaN              NaN               NaN        NaN
# 7             DESPAIR              MEH               MEH        JOY
# ...               ...              ...               ...        ...
# 2455              JOY              JOY               MEH        MEH
# 2456              NaN              JOY           DESPAIR        JOY
# 2457              JOY          DESPAIR           DESPAIR        MEH
# 2458              NaN              NaN               NaN        NaN
# 2459          DESPAIR              JOY               MEH    DESPAIR
#
#      Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 1                   JOY           DESPAIR    DESPAIR      DESPAIR
# 3                   MEH               MEH    DESPAIR      DESPAIR
# 4                   JOY               JOY        MEH      DESPAIR
# 6                   NaN               NaN        NaN          NaN
# 7                   JOY               MEH    DESPAIR      DESPAIR
# ...                 ...               ...        ...          ...
# 2455                JOY               JOY    DESPAIR      DESPAIR
# 2456                MEH               JOY    DESPAIR      DESPAIR
# 2457            DESPAIR               MEH        MEH          MEH
# 2458                NaN               NaN        NaN          NaN
# 2459                MEH           DESPAIR        MEH      DESPAIR
#
#      Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 1           DESPAIR                                            DESPAIR
# 3           DESPAIR                                            DESPAIR
# 4               JOY                                            DESPAIR
# 6               NaN                                                NaN
# 7           DESPAIR                                            DESPAIR
# ...             ...                                                ...
# 2455            JOY                                                MEH
# 2456            MEH                                            DESPAIR
# 2457            JOY                                                JOY
# 2458            NaN                                                NaN
# 2459        DESPAIR                                            DESPAIR
#
#      Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces  \
# 1                                JOY                 JOY
# 3                                JOY                 MEH
# 4                                JOY                 JOY
# 6                                NaN                 NaN
# 7                                JOY                 JOY
# ...                              ...                 ...
# 2455                             JOY                 JOY
# 2456                             JOY                 JOY
# 2457                             JOY                 MEH
# 2458                             NaN                 NaN
# 2459                             MEH             DESPAIR
#
#      Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 1                    DESPAIR        JOY
# 3                        MEH        MEH
# 4                        MEH        JOY
# 6                        NaN        NaN
# 7                        NaN        JOY
# ...                      ...        ...
# 2455                     JOY        JOY
# 2456                     NaN        MEH
# 2457                     MEH        JOY
# 2458                     NaN        NaN
# 2459                 DESPAIR    DESPAIR
#
#      Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 1                                               DESPAIR         DESPAIR
# 3                                               DESPAIR         DESPAIR
# 4                                                   NaN             JOY
# 6                                                   NaN             NaN
# 7                                               DESPAIR             JOY
# ...                                                 ...             ...
# 2455                                                JOY             MEH
# 2456                                            DESPAIR             JOY
# 2457                                            DESPAIR         DESPAIR
# 2458                                                NaN             NaN
# 2459                                            DESPAIR         DESPAIR
#
#      Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 1                     DESPAIR                      DESPAIR           MEH
# 3                     DESPAIR                          MEH           JOY
# 4                         JOY                      DESPAIR           NaN
# 6                         NaN                          NaN           NaN
# 7                         MEH                          JOY           MEH
# ...                       ...                          ...           ...
# 2455                  DESPAIR                      DESPAIR           JOY
# 2456                  DESPAIR                          NaN           JOY
# 2457                      JOY                          MEH       DESPAIR
# 2458                      NaN                          NaN           NaN
# 2459                      MEH                      DESPAIR           JOY
#
#      Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 1                                              DESPAIR           DESPAIR
# 3                                                  MEH           DESPAIR
# 4                                                  MEH           DESPAIR
# 6                                                  NaN               NaN
# 7                                                  JOY           DESPAIR
# ...                                                ...               ...
# 2455                                               JOY               JOY
# 2456                                               MEH               NaN
# 2457                                           DESPAIR           DESPAIR
# 2458                                               NaN               NaN
# 2459                                               JOY           DESPAIR
#
#      Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 1               MEH          DESPAIR               MEH
# 3               MEH              MEH               JOY
# 4               JOY              JOY               MEH
# 6               NaN              NaN               NaN
# 7               MEH              JOY               JOY
# ...             ...              ...               ...
# 2455            JOY              MEH               JOY
# 2456            MEH              MEH               MEH
# 2457        DESPAIR              JOY           DESPAIR
# 2458            NaN              NaN               NaN
# 2459            MEH              MEH           DESPAIR
#
#      Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 1                                 DESPAIR     DESPAIR       DESPAIR
# 3                                     MEH         JOY           MEH
# 4                                 DESPAIR         MEH       DESPAIR
# 6                                     NaN         NaN           NaN
# 7                                     MEH         MEH       DESPAIR
# ...                                   ...         ...           ...
# 2455                              DESPAIR         MEH           JOY
# 2456                                  NaN         JOY       DESPAIR
# 2457                              DESPAIR         MEH           MEH
# 2458                                  NaN         NaN           NaN
# 2459                              DESPAIR     DESPAIR       DESPAIR
#
#      Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 1                                            DESPAIR                   JOY
# 3                                            DESPAIR               DESPAIR
# 4                                            DESPAIR                   JOY
# 6                                                NaN                   NaN
# 7                                            DESPAIR                   JOY
# ...                                              ...                   ...
# 2455                                         DESPAIR                   MEH
# 2456                                         DESPAIR                   MEH
# 2457                                         DESPAIR                   JOY
# 2458                                             NaN                   NaN
# 2459                                         DESPAIR                   JOY
#
#      Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 1                                  JOY        DESPAIR       JOY
# 3                                  JOY            MEH       JOY
# 4                                  JOY        DESPAIR       JOY
# 6                                  NaN            NaN       NaN
# 7                                  MEH        DESPAIR       JOY
# ...                                ...            ...       ...
# 2455                               MEH            JOY       JOY
# 2456                               MEH        DESPAIR       JOY
# 2457                               JOY            MEH       MEH
# 2458                               NaN            NaN       NaN
# 2459                               MEH        DESPAIR   DESPAIR
#
#      Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                                   MEH
# 6                                                   NaN
# 7                                                   JOY
# ...                                                 ...
# 2455                                                MEH
# 2456                                                NaN
# 2457                                                MEH
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 1         DESPAIR                   DESPAIR          DESPAIR
# 3             JOY                       JOY          DESPAIR
# 4             JOY                       JOY          DESPAIR
# 6             NaN                       NaN              NaN
# 7             MEH                   DESPAIR          DESPAIR
# ...           ...                       ...              ...
# 2455          JOY                   DESPAIR              MEH
# 2456          NaN                       JOY          DESPAIR
# 2457          JOY                       MEH          DESPAIR
# 2458          NaN                       NaN              NaN
# 2459          JOY                   DESPAIR              MEH
#
#      Q6 | Whole Wheat anything Q6 | York Peppermint Patties  \
# 1                      DESPAIR                      DESPAIR
# 3                      DESPAIR                      DESPAIR
# 4                      DESPAIR                          JOY
# 6                          NaN                          NaN
# 7                      DESPAIR                      DESPAIR
# ...                        ...                          ...
# 2455                   DESPAIR                          MEH
# 2456                       MEH                          JOY
# 2457                   DESPAIR                          MEH
# 2458                       NaN                          NaN
# 2459                   DESPAIR                          JOY
#
#                                           Q7: JOY OTHER  \
# 1                                                Mounds
# 3     Reese's crispy crunchy bars, 5th avenue bars, ...
# 4                                                   NaN
# 6                                                   NaN
# 7     using my elbows to get in front of the little ...
# ...                                                 ...
# 2455                                             Mounds
# 2456                                                NaN
# 2457  Tiny bottles of maple syrup as given out by Cr...
# 2458                                                NaN
# 2459                                                NaN
#
#                                       Q8: DESPAIR OTHER  \
# 1                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 6                                                   NaN
# 7     when the little kids get the big chocolate bar...
# ...                                                 ...
# 2455                                   Fruit Stripe Gum
# 2456                                             Capers
# 2457                                                NaN
# 2458                                                NaN
# 2459                                                NaN
#
#                                      Q9: OTHER COMMENTS      Q10: DRESS  \
# 1     Bottom line is Twix is really the only candy w...  White and gold
# 3                                Raisins can go to hell  White and gold
# 4                                                   NaN  White and gold
# 6                                                   NaN             NaN
# 7           first person to give out cans of beer, wins  Blue and black
# ...                                                 ...             ...
# 2455                                                NaN  White and gold
# 2456                                                NaN  Blue and black
# 2457                                                NaN  Blue and black
# 2458                                                NaN             NaN
# 2459  You hit all my chocolate highlights, and broug...  White and gold
#
#      Q11: DAY  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# 1      Sunday                      NaN                   1.0
# 3      Sunday                      NaN                   1.0
# 4      Friday                      NaN                   1.0
# 6         NaN                      NaN                   NaN
# 7      Friday                      NaN                   1.0
# ...       ...                      ...                   ...
# 2455   Friday                      NaN                   NaN
# 2456   Friday                      NaN                   1.0
# 2457   Friday                      NaN                   1.0
# 2458      NaN                      NaN                   NaN
# 2459   Sunday                      1.0                   NaN
#
#       Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 1                   NaN                 NaN                 (84, 25)
# 3                   NaN                 NaN                 (75, 23)
# 4                   NaN                 NaN                 (70, 10)
# 6                   NaN                 NaN                      NaN
# 7                   NaN                 NaN                  (55, 5)
# ...                 ...                 ...                      ...
# 2455                NaN                 NaN                      NaN
# 2456                NaN                 NaN                 (70, 26)
# 2457                NaN                 NaN                 (67, 35)
# 2458                NaN                 NaN                      NaN
# 2459                NaN                 NaN                 (19, 26)
#
# [2305 rows x 119 columns]

# %%
cd['Q3: AGE'].unique()
# Out:
# array(['44', '40', '23', '53', '33', '56', '64', '43', '37', '59', '48',
#        '54', '36', '45', '49', '25', '34', '35', '38', '58', '50', '47',
#        '16', '52', '63', '41', '27', '61', '46', '42', '62', '29', '39',
#        '32', '31', '28', '69', '67', '22', '26', '51', '70', '24', '18',
#        nan, '19', 'Old enough', '57', '60', '66', '12', '30', 'Many',
#        '65', '55', '72', '?', '21', '11', 'no', '9', '68', '20', '6',
#        '10', '71', '90', '13', '45-55', '312', '99', '7', 'hahahahaha',
#        '88', '39.4', '74', '102', 'older than dirt', '17', '15', '8',
#        '75', '5u', 'Enough', 'See question 2', '24-50', '14', 'Over 50',
#        '76', '100', '1000', 'sixty-nine', '46 Halloweens.', 'ancient',
#        '77', 'OLD', 'old', '73', '70 1/2', '1', 'MY NAME JEFF', '4',
#        '59 on the day after Halloween', 'old enough', 'your mom',
#        'I can remember when Java was a cool new language', '60+'],
#       dtype=object)

# %%
import random
random.seed()
cd['Q3: AGE'].replace({'sixty-nine':'69','70 1/2':'70','46 Halloweens.':'46','59 on the day after Halloween':'59','39.4':'39',
'45-55':str(np.random.randint(45, 55)),'Over 50':str(np.random.randint(51, 80)),'60+':str(np.random.randint(61, 80))   }, inplace=True)

# %%
cd['Q3: AGE'] = pd.to_numeric(cd['Q3: AGE'], errors='coerce')
cd=cd[(cd['Q3: AGE']<100 )& (cd['Q3: AGE']>9)]

# %%
cd['Q3: AGE'].mean()
# Out:
# 42.236654804270465

# %%
cd.fillna(np.random.randint(int(cd['Q3: AGE'].mean()-2*cd['Q3: AGE'].std()),int( cd['Q3: AGE'].mean()+2*cd['Q3: AGE'].std())),inplace=True)
# Out:
# C:\Users\Laptop Shop\anaconda3\lib\site-packages\pandas\core\frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER  Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male     44.0         USA
# 3        90272840             No       Male     40.0         USA
# 4        90272841             No       Male     23.0         USA
# 6        90272853             No       Male     53.0         USA
# 7        90272854             No       Male     33.0      CANADA
# ...           ...            ...        ...      ...         ...
# 2455     90314359             No       Male     24.0         USA
# 2456     90314580             No     Female     33.0         USA
# 2457     90314634             No     Female     26.0         USA
# 2458     90314658             No       Male     58.0         USA
# 2459     90314802             No     Female     66.0         USA
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 1                                  NM                MEH
# 3                                  or                MEH
# 4                            exton pa                JOY
# 6                           Colorado                  41
# 7                             ontario                JOY
# ...                               ...                ...
# 2455                               MD                JOY
# 2456                         New York                MEH
# 2457                        Tennessee                MEH
# 2458                   North Carolina                 41
# 2459                     Pennsylvania            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                    41
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                 41
# 2459                                            DESPAIR
#
#      Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 1                              JOY              MEH                  DESPAIR
# 3                              JOY              MEH                      MEH
# 4                              JOY          DESPAIR                      MEH
# 6                               41               41                       41
# 7                              JOY          DESPAIR                  DESPAIR
# ...                            ...              ...                      ...
# 2455                           MEH          DESPAIR                  DESPAIR
# 2456                           JOY               41                       41
# 2457                           JOY          DESPAIR                      MEH
# 2458                            41               41                       41
# 2459                           JOY          DESPAIR                  DESPAIR
#
#      Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 1                          DESPAIR          DESPAIR            DESPAIR
# 3                          DESPAIR              MEH            DESPAIR
# 4                          DESPAIR              MEH            DESPAIR
# 6                               41               41                 41
# 7                              MEH              JOY                MEH
# ...                            ...              ...                ...
# 2455                           MEH              MEH            DESPAIR
# 2456                            41               41            DESPAIR
# 2457                           JOY          DESPAIR                MEH
# 2458                            41               41                 41
# 2459                       DESPAIR          DESPAIR                MEH
#
#      Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 1                   DESPAIR           DESPAIR                     MEH
# 3                   DESPAIR               MEH                     MEH
# 4                   DESPAIR               MEH                     MEH
# 6                        41                41                      41
# 7                       JOY               JOY                     JOY
# ...                     ...               ...                     ...
# 2455                DESPAIR               MEH                 DESPAIR
# 2456                DESPAIR               JOY                     JOY
# 2457                    MEH           DESPAIR                     JOY
# 2458                     41                41                      41
# 2459                DESPAIR               JOY                     MEH
#
#      Q6 | Candy Corn  \
# 1                MEH
# 3            DESPAIR
# 4            DESPAIR
# 6                 41
# 7                JOY
# ...              ...
# 2455         DESPAIR
# 2456             JOY
# 2457         DESPAIR
# 2458              41
# 2459             MEH
#
#      Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                    41
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                                MEH
# 2458                                                 41
# 2459                                            DESPAIR
#
#      Q6 | Caramellos Q6 | Cash, or other forms of legal tender  \
# 1                MEH                                       JOY
# 3                MEH                                       JOY
# 4                JOY                                       MEH
# 6                 41                                        41
# 7                JOY                                       JOY
# ...              ...                                       ...
# 2455             JOY                                       JOY
# 2456             JOY                                       JOY
# 2457         DESPAIR                                       JOY
# 2458              41                                        41
# 2459             MEH                                       JOY
#
#      Q6 | Chardonnay Q6 | Chick-o-Sticks (we don’t know what that is)  \
# 1                MEH                                          DESPAIR
# 3                MEH                                              JOY
# 4                JOY                                          DESPAIR
# 6                 41                                               41
# 7                JOY                                          DESPAIR
# ...              ...                                              ...
# 2455             JOY                                              MEH
# 2456             JOY                                              JOY
# 2457             JOY                                              MEH
# 2458              41                                               41
# 2459             JOY                                          DESPAIR
#
#      Q6 | Chiclets Q6 | Coffee Crisp  \
# 1          DESPAIR           DESPAIR
# 3              MEH           DESPAIR
# 4          DESPAIR               MEH
# 6               41                41
# 7              MEH               MEH
# ...            ...               ...
# 2455           JOY               JOY
# 2456       DESPAIR                41
# 2457           MEH           DESPAIR
# 2458            41                41
# 2459           MEH           DESPAIR
#
#      Q6 | Creepy Religious comics/Chick Tracts Q6 | Dental paraphenalia  \
# 1                                      DESPAIR                  DESPAIR
# 3                                      DESPAIR                  DESPAIR
# 4                                      DESPAIR                  DESPAIR
# 6                                           41                       41
# 7                                      DESPAIR                  DESPAIR
# ...                                        ...                      ...
# 2455                                   DESPAIR                      MEH
# 2456                                   DESPAIR                  DESPAIR
# 2457                                   DESPAIR                  DESPAIR
# 2458                                        41                       41
# 2459                                   DESPAIR                  DESPAIR
#
#      Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 1          MEH            JOY            DESPAIR
# 3          JOY            JOY                MEH
# 4          MEH            JOY            DESPAIR
# 6           41             41                 41
# 7          MEH            MEH                JOY
# ...        ...            ...                ...
# 2455   DESPAIR            JOY                MEH
# 2456   DESPAIR            MEH                 41
# 2457       MEH            JOY                MEH
# 2458        41             41                 41
# 2459       JOY            JOY                MEH
#
#      Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 1                             DESPAIR          DESPAIR               DESPAIR
# 3                                 MEH              JOY                   JOY
# 4                             DESPAIR          DESPAIR                   MEH
# 6                                  41               41                    41
# 7                             DESPAIR          DESPAIR               DESPAIR
# ...                               ...              ...                   ...
# 2455                              JOY          DESPAIR                   JOY
# 2456                              MEH          DESPAIR                    41
# 2457                              JOY              JOY               DESPAIR
# 2458                               41               41                    41
# 2459                          DESPAIR              MEH               DESPAIR
#
#      Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 1                    MEH                      DESPAIR
# 3                    MEH                      DESPAIR
# 4                    MEH                      DESPAIR
# 6                     41                           41
# 7                DESPAIR                      DESPAIR
# ...                  ...                          ...
# 2455                 JOY                          JOY
# 2456             DESPAIR                      DESPAIR
# 2457             DESPAIR                      DESPAIR
# 2458                  41                           41
# 2459                 JOY                      DESPAIR
#
#      Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 1                             MEH             MEH            DESPAIR
# 3                             JOY             MEH                MEH
# 4                             JOY             MEH            DESPAIR
# 6                              41              41                 41
# 7                             JOY         DESPAIR            DESPAIR
# ...                           ...             ...                ...
# 2455                          MEH         DESPAIR                MEH
# 2456                          MEH             MEH            DESPAIR
# 2457                          MEH             MEH            DESPAIR
# 2458                           41              41                 41
# 2459                          MEH         DESPAIR            DESPAIR
#
#      Q6 | Heath Bar Q6 | Hershey's Dark Chocolate  \
# 1               MEH                           JOY
# 3           DESPAIR                           MEH
# 4           DESPAIR                           JOY
# 6                41                            41
# 7           DESPAIR                           JOY
# ...             ...                           ...
# 2455        DESPAIR                           JOY
# 2456            JOY                           MEH
# 2457            MEH                           JOY
# 2458             41                            41
# 2459        DESPAIR                           JOY
#
#      Q6 | Hershey’s Milk Chocolate Q6 | Hershey's Kisses  \
# 1                              JOY                   MEH
# 3                              MEH                   MEH
# 4                              MEH                   MEH
# 6                               41                    41
# 7                              MEH                   MEH
# ...                            ...                   ...
# 2455                           MEH                   MEH
# 2456                           JOY                   MEH
# 2457                           JOY                   JOY
# 2458                            41                    41
# 2459                           JOY                   JOY
#
#      Q6 | Hugs (actual physical hugs) Q6 | Jolly Rancher (bad flavor)  \
# 1                             DESPAIR                         DESPAIR
# 3                                 MEH                             MEH
# 4                             DESPAIR                             MEH
# 6                                  41                              41
# 7                             DESPAIR                         DESPAIR
# ...                               ...                             ...
# 2455                              JOY                             MEH
# 2456                          DESPAIR                             MEH
# 2457                              MEH                         DESPAIR
# 2458                               41                              41
# 2459                          DESPAIR                         DESPAIR
#
#      Q6 | Jolly Ranchers (good flavor) Q6 | JoyJoy (Mit Iodine!)  \
# 1                                  MEH                   DESPAIR
# 3                                  MEH                   DESPAIR
# 4                                  JOY                       MEH
# 6                                   41                        41
# 7                              DESPAIR                   DESPAIR
# ...                                ...                       ...
# 2455                               MEH                       MEH
# 2456                               JOY                        41
# 2457                               JOY                   DESPAIR
# 2458                                41                        41
# 2459                               MEH                   DESPAIR
#
#      Q6 | Junior Mints Q6 | Senior Mints Q6 | Kale smoothie  \
# 1              DESPAIR           DESPAIR            DESPAIR
# 3              DESPAIR           DESPAIR            DESPAIR
# 4                  JOY           DESPAIR            DESPAIR
# 6                   41                41                 41
# 7              DESPAIR           DESPAIR            DESPAIR
# ...                ...               ...                ...
# 2455           DESPAIR           DESPAIR                MEH
# 2456               JOY                41            DESPAIR
# 2457               JOY               MEH            DESPAIR
# 2458                41                41                 41
# 2459               JOY           DESPAIR            DESPAIR
#
#      Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy Q6 | LemonHeads  \
# 1                    DESPAIR          JOY         DESPAIR             MEH
# 3                        MEH          MEH             JOY             JOY
# 4                        JOY          JOY             JOY             JOY
# 6                         41           41              41              41
# 7                    DESPAIR          MEH             MEH             JOY
# ...                      ...          ...             ...             ...
# 2455                     JOY          JOY             MEH             MEH
# 2456                      41          JOY         DESPAIR         DESPAIR
# 2457                 DESPAIR      DESPAIR             JOY         DESPAIR
# 2458                      41           41              41              41
# 2459                 DESPAIR          MEH         DESPAIR         DESPAIR
#
#      Q6 | Licorice (not black) Q6 | Licorice (yes black) Q6 | Lindt Truffle  \
# 1                          MEH                       JOY                MEH
# 3                          MEH                       JOY                JOY
# 4                          MEH                   DESPAIR                JOY
# 6                           41                        41                 41
# 7                          MEH                   DESPAIR            DESPAIR
# ...                        ...                       ...                ...
# 2455                       JOY                   DESPAIR                JOY
# 2456                       MEH                   DESPAIR                MEH
# 2457                       MEH                   DESPAIR                JOY
# 2458                        41                        41                 41
# 2459                   DESPAIR                   DESPAIR                JOY
#
#      Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike Q6 | Milk Duds  \
# 1           DESPAIR   DESPAIR       DESPAIR               MEH            MEH
# 3           DESPAIR       JOY           MEH               MEH        DESPAIR
# 4               MEH       MEH       DESPAIR               MEH            MEH
# 6                41        41            41                41             41
# 7               MEH       JOY           JOY               JOY            JOY
# ...             ...       ...           ...               ...            ...
# 2455        DESPAIR       MEH           MEH               MEH            JOY
# 2456            MEH        41            41           DESPAIR            MEH
# 2457            MEH       JOY       DESPAIR               MEH            JOY
# 2458             41        41            41                41             41
# 2459        DESPAIR       JOY       DESPAIR               MEH        DESPAIR
#
#      Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s Q6 | Blue M&M's  \
# 1               JOY               JOY               MEH             JOY
# 3               JOY               MEH               JOY             MEH
# 4               JOY               JOY               JOY             JOY
# 6                41                41                41              41
# 7               JOY               JOY               JOY             JOY
# ...             ...               ...               ...             ...
# 2455            JOY               MEH               JOY             JOY
# 2456            MEH               JOY               JOY              41
# 2457            JOY               JOY           DESPAIR             JOY
# 2458             41                41                41              41
# 2459            JOY               JOY               JOY             JOY
#
#      Q6 | Red M&M's Q6 | Green Party M&M's Q6 | Independent M&M's  \
# 1               JOY                    JOY                    JOY
# 3               MEH                    MEH                    MEH
# 4               JOY                    JOY                    JOY
# 6                41                     41                     41
# 7               JOY                    JOY                    MEH
# ...             ...                    ...                    ...
# 2455            MEH                    JOY                    JOY
# 2456             41                     41                     41
# 2457            JOY                    JOY                    JOY
# 2458             41                     41                     41
# 2459            JOY                    JOY                DESPAIR
#
#      Q6 | Abstained from M&M'ing. Q6 | Minibags of chips Q6 | Mint Kisses  \
# 1                         DESPAIR                DESPAIR              MEH
# 3                             MEH                DESPAIR          DESPAIR
# 4                             MEH                DESPAIR              JOY
# 6                              41                     41               41
# 7                         DESPAIR                    JOY          DESPAIR
# ...                           ...                    ...              ...
# 2455                          MEH                    MEH              JOY
# 2456                           41                    MEH              JOY
# 2457                      DESPAIR                    JOY              JOY
# 2458                           41                     41               41
# 2459                      DESPAIR                    MEH              MEH
#
#      Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers Q6 | Nerds  \
# 1             DESPAIR          DESPAIR           DESPAIR    DESPAIR
# 3                 MEH              MEH           DESPAIR        MEH
# 4                 JOY              MEH           DESPAIR        JOY
# 6                  41               41                41         41
# 7             DESPAIR              MEH               MEH        JOY
# ...               ...              ...               ...        ...
# 2455              JOY              JOY               MEH        MEH
# 2456               41              JOY           DESPAIR        JOY
# 2457              JOY          DESPAIR           DESPAIR        MEH
# 2458               41               41                41         41
# 2459          DESPAIR              JOY               MEH    DESPAIR
#
#      Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 1                   JOY           DESPAIR    DESPAIR      DESPAIR
# 3                   MEH               MEH    DESPAIR      DESPAIR
# 4                   JOY               JOY        MEH      DESPAIR
# 6                    41                41         41           41
# 7                   JOY               MEH    DESPAIR      DESPAIR
# ...                 ...               ...        ...          ...
# 2455                JOY               JOY    DESPAIR      DESPAIR
# 2456                MEH               JOY    DESPAIR      DESPAIR
# 2457            DESPAIR               MEH        MEH          MEH
# 2458                 41                41         41           41
# 2459                MEH           DESPAIR        MEH      DESPAIR
#
#      Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 1           DESPAIR                                            DESPAIR
# 3           DESPAIR                                            DESPAIR
# 4               JOY                                            DESPAIR
# 6                41                                                 41
# 7           DESPAIR                                            DESPAIR
# ...             ...                                                ...
# 2455            JOY                                                MEH
# 2456            MEH                                            DESPAIR
# 2457            JOY                                                JOY
# 2458             41                                                 41
# 2459        DESPAIR                                            DESPAIR
#
#      Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces  \
# 1                                JOY                 JOY
# 3                                JOY                 MEH
# 4                                JOY                 JOY
# 6                                 41                  41
# 7                                JOY                 JOY
# ...                              ...                 ...
# 2455                             JOY                 JOY
# 2456                             JOY                 JOY
# 2457                             JOY                 MEH
# 2458                              41                  41
# 2459                             MEH             DESPAIR
#
#      Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 1                    DESPAIR        JOY
# 3                        MEH        MEH
# 4                        MEH        JOY
# 6                         41         41
# 7                         41        JOY
# ...                      ...        ...
# 2455                     JOY        JOY
# 2456                      41        MEH
# 2457                     MEH        JOY
# 2458                      41         41
# 2459                 DESPAIR    DESPAIR
#
#      Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 1                                               DESPAIR         DESPAIR
# 3                                               DESPAIR         DESPAIR
# 4                                                    41             JOY
# 6                                                    41              41
# 7                                               DESPAIR             JOY
# ...                                                 ...             ...
# 2455                                                JOY             MEH
# 2456                                            DESPAIR             JOY
# 2457                                            DESPAIR         DESPAIR
# 2458                                                 41              41
# 2459                                            DESPAIR         DESPAIR
#
#      Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 1                     DESPAIR                      DESPAIR           MEH
# 3                     DESPAIR                          MEH           JOY
# 4                         JOY                      DESPAIR            41
# 6                          41                           41            41
# 7                         MEH                          JOY           MEH
# ...                       ...                          ...           ...
# 2455                  DESPAIR                      DESPAIR           JOY
# 2456                  DESPAIR                           41           JOY
# 2457                      JOY                          MEH       DESPAIR
# 2458                       41                           41            41
# 2459                      MEH                      DESPAIR           JOY
#
#      Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 1                                              DESPAIR           DESPAIR
# 3                                                  MEH           DESPAIR
# 4                                                  MEH           DESPAIR
# 6                                                   41                41
# 7                                                  JOY           DESPAIR
# ...                                                ...               ...
# 2455                                               JOY               JOY
# 2456                                               MEH                41
# 2457                                           DESPAIR           DESPAIR
# 2458                                                41                41
# 2459                                               JOY           DESPAIR
#
#      Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 1               MEH          DESPAIR               MEH
# 3               MEH              MEH               JOY
# 4               JOY              JOY               MEH
# 6                41               41                41
# 7               MEH              JOY               JOY
# ...             ...              ...               ...
# 2455            JOY              MEH               JOY
# 2456            MEH              MEH               MEH
# 2457        DESPAIR              JOY           DESPAIR
# 2458             41               41                41
# 2459            MEH              MEH           DESPAIR
#
#      Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 1                                 DESPAIR     DESPAIR       DESPAIR
# 3                                     MEH         JOY           MEH
# 4                                 DESPAIR         MEH       DESPAIR
# 6                                      41          41            41
# 7                                     MEH         MEH       DESPAIR
# ...                                   ...         ...           ...
# 2455                              DESPAIR         MEH           JOY
# 2456                                   41         JOY       DESPAIR
# 2457                              DESPAIR         MEH           MEH
# 2458                                   41          41            41
# 2459                              DESPAIR     DESPAIR       DESPAIR
#
#      Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 1                                            DESPAIR                   JOY
# 3                                            DESPAIR               DESPAIR
# 4                                            DESPAIR                   JOY
# 6                                                 41                    41
# 7                                            DESPAIR                   JOY
# ...                                              ...                   ...
# 2455                                         DESPAIR                   MEH
# 2456                                         DESPAIR                   MEH
# 2457                                         DESPAIR                   JOY
# 2458                                              41                    41
# 2459                                         DESPAIR                   JOY
#
#      Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 1                                  JOY        DESPAIR       JOY
# 3                                  JOY            MEH       JOY
# 4                                  JOY        DESPAIR       JOY
# 6                                   41             41        41
# 7                                  MEH        DESPAIR       JOY
# ...                                ...            ...       ...
# 2455                               MEH            JOY       JOY
# 2456                               MEH        DESPAIR       JOY
# 2457                               JOY            MEH       MEH
# 2458                                41             41        41
# 2459                               MEH        DESPAIR   DESPAIR
#
#      Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                                   MEH
# 6                                                    41
# 7                                                   JOY
# ...                                                 ...
# 2455                                                MEH
# 2456                                                 41
# 2457                                                MEH
# 2458                                                 41
# 2459                                            DESPAIR
#
#      Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 1         DESPAIR                   DESPAIR          DESPAIR
# 3             JOY                       JOY          DESPAIR
# 4             JOY                       JOY          DESPAIR
# 6              41                        41               41
# 7             MEH                   DESPAIR          DESPAIR
# ...           ...                       ...              ...
# 2455          JOY                   DESPAIR              MEH
# 2456           41                       JOY          DESPAIR
# 2457          JOY                       MEH          DESPAIR
# 2458           41                        41               41
# 2459          JOY                   DESPAIR              MEH
#
#      Q6 | Whole Wheat anything Q6 | York Peppermint Patties  \
# 1                      DESPAIR                      DESPAIR
# 3                      DESPAIR                      DESPAIR
# 4                      DESPAIR                          JOY
# 6                           41                           41
# 7                      DESPAIR                      DESPAIR
# ...                        ...                          ...
# 2455                   DESPAIR                          MEH
# 2456                       MEH                          JOY
# 2457                   DESPAIR                          MEH
# 2458                        41                           41
# 2459                   DESPAIR                          JOY
#
#                                           Q7: JOY OTHER  \
# 1                                                Mounds
# 3     Reese's crispy crunchy bars, 5th avenue bars, ...
# 4                                                    41
# 6                                                    41
# 7     using my elbows to get in front of the little ...
# ...                                                 ...
# 2455                                             Mounds
# 2456                                                 41
# 2457  Tiny bottles of maple syrup as given out by Cr...
# 2458                                                 41
# 2459                                                 41
#
#                                       Q8: DESPAIR OTHER  \
# 1                                                    41
# 3                                                    41
# 4                                                    41
# 6                                                    41
# 7     when the little kids get the big chocolate bar...
# ...                                                 ...
# 2455                                   Fruit Stripe Gum
# 2456                                             Capers
# 2457                                                 41
# 2458                                                 41
# 2459                                                 41
#
#                                      Q9: OTHER COMMENTS      Q10: DRESS  \
# 1     Bottom line is Twix is really the only candy w...  White and gold
# 3                                Raisins can go to hell  White and gold
# 4                                                    41  White and gold
# 6                                                    41              41
# 7           first person to give out cans of beer, wins  Blue and black
# ...                                                 ...             ...
# 2455                                                 41  White and gold
# 2456                                                 41  Blue and black
# 2457                                                 41  Blue and black
# 2458                                                 41              41
# 2459  You hit all my chocolate highlights, and broug...  White and gold
#
#      Q11: DAY  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# 1      Sunday                     41.0                   1.0
# 3      Sunday                     41.0                   1.0
# 4      Friday                     41.0                   1.0
# 6          41                     41.0                  41.0
# 7      Friday                     41.0                   1.0
# ...       ...                      ...                   ...
# 2455   Friday                     41.0                  41.0
# 2456   Friday                     41.0                   1.0
# 2457   Friday                     41.0                   1.0
# 2458       41                     41.0                  41.0
# 2459   Sunday                      1.0                  41.0
#
#       Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 1                  41.0                41.0                 (84, 25)
# 3                  41.0                41.0                 (75, 23)
# 4                  41.0                41.0                 (70, 10)
# 6                  41.0                41.0                       41
# 7                  41.0                41.0                  (55, 5)
# ...                 ...                 ...                      ...
# 2455               41.0                41.0                       41
# 2456               41.0                41.0                 (70, 26)
# 2457               41.0                41.0                 (67, 35)
# 2458               41.0                41.0                       41
# 2459               41.0                41.0                 (19, 26)
#
# [2248 rows x 119 columns]

# %%
cd['Q3: AGE'].unique()
# Out:
# array([44., 40., 23., 53., 33., 56., 64., 43., 37., 59., 48., 54., 36.,
#        45., 49., 25., 34., 35., 38., 58., 50., 47., 16., 52., 63., 41.,
#        27., 61., 46., 42., 62., 29., 39., 32., 31., 28., 69., 67., 22.,
#        26., 51., 70., 24., 18., 19., 57., 60., 66., 12., 30., 65., 55.,
#        72., 21., 11., 68., 20., 10., 71., 90., 13., 99., 88., 74., 17.,
#        15., 75., 14., 76., 77., 73.])

# %%
cd['Q2: GENDER'].value_counts()
# Out:
# Male                  1360
# Female                 802
# I'd rather not say      60
# Other                   26
# Name: Q2: GENDER, dtype: int64

# %%
cd['Q2: GENDER'].replace({'I\'d rather not say': 'Male' ,'Other':'Male'}, inplace=True)
# Out:
# C:\Users\Laptop Shop\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
cd['Q2: GENDER'].value_counts()
# Out:
# Male      1446
# Female     802
# Name: Q2: GENDER, dtype: int64

# %%
cd['Q6 | Kit Kat'].value_counts()
# Out:
# JOY        1346
# 41          586
# MEH         268
# DESPAIR      48
# Name: Q6 | Kit Kat, dtype: int64

# %%
for i in cd:
    print(cd[i].value_counts())
# Out:
# 90273795    1
# 90274480    1
# 90296809    1
# 90280029    1
# 90292907    1
#            ..
# 90275191    1
# 90273142    1
# 90273140    1
# 90273138    1
# 90277887    1
# Name: Internal ID, Length: 2248, dtype: int64
# No     1962
# Yes     286
# Name: Q1: GOING OUT?, dtype: int64
# Male      1446
# Female     802
# Name: Q2: GENDER, dtype: int64
# 40.0    89
# 37.0    87
# 34.0    85
# 43.0    81
# 42.0    76
# 36.0    76
# 35.0    75
# 38.0    73
# 44.0    73
# 33.0    73
# 45.0    72
# 41.0    71
# 39.0    69
# 32.0    68
# 50.0    66
# 49.0    65
# 48.0    62
# 47.0    59
# 30.0    58
# 53.0    56
# 46.0    55
# 52.0    50
# 56.0    46
# 27.0    43
# 31.0    42
# 51.0    41
# 58.0    34
# 28.0    33
# 54.0    32
# 60.0    31
# 55.0    31
# 29.0    26
# 59.0    25
# 57.0    24
# 26.0    23
# 63.0    20
# 62.0    20
# 61.0    18
# 25.0    18
# 64.0    17
# 24.0    15
# 21.0    14
# 20.0    12
# 22.0    11
# 18.0    10
# 65.0    10
# 66.0     9
# 23.0     8
# 15.0     8
# 12.0     7
# 70.0     7
# 68.0     7
# 11.0     7
# 72.0     6
# 13.0     6
# 67.0     6
# 71.0     6
# 69.0     5
# 73.0     4
# 16.0     4
# 17.0     4
# 10.0     3
# 19.0     3
# 75.0     3
# 76.0     2
# 90.0     2
# 14.0     2
# 77.0     1
# 88.0     1
# 74.0     1
# 99.0     1
# Name: Q3: AGE, dtype: int64
# USA                   1937
# CANADA                 209
# UK                      33
# GERMANY                 10
# AUSTRALIA                6
# NETHERLANDS              6
# JAPAN                    5
# SCOTLAND                 5
# IRELAND                  4
# MEXICO                   4
# FRANCE                   3
# SWITZERLAND              3
# DENMARK                  2
# CHINA                    2
# HONG KONG                2
# SWEDEN                   2
# TAIWAN                   1
# FINLAND                  1
# SOUTH AFRICA             1
# SINGAPORE                1
# TRUMPISTAN               1
# INDONESIA                1
# SPAIN                    1
# THE NETHERLANDS          1
# GREECE                   1
# ICELAND                  1
# COSTA RICA               1
# UAE                      1
# SOVIET CANUCKISTAN       1
# KOREA                    1
# ENDLAND                  1
# Name: Q4: COUNTRY, dtype: int64
# California                        123
# CA                                 84
# Texas                              57
# Ontario                            52
# Illinois                           52
#                                  ...
# California, USA                     1
# Massachusetts, Plymouth county      1
# New York, New York                  1
# Ontario,  Canada                    1
# ont                                 1
# Name: Q5: STATE, PROVINCE, COUNTY, ETC, Length: 489, dtype: int64
# JOY        816
# MEH        701
# 41         653
# DESPAIR     78
# Name: Q6 | 100 Grand Bar, dtype: int64
# DESPAIR    1012
# 41          641
# MEH         430
# JOY         165
# Name: Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes), dtype: int64
# JOY        1453
# 41          585
# MEH         195
# DESPAIR      15
# Name: Q6 | Any full-sized candy bar, dtype: int64
# 41         850
# DESPAIR    736
# MEH        579
# JOY         83
# Name: Q6 | Black Jacks, dtype: int64
# 41         879
# MEH        807
# DESPAIR    458
# JOY        104
# Name: Q6 | Bonkers (the candy), dtype: int64
# 41         894
# MEH        668
# DESPAIR    507
# JOY        179
# Name: Q6 | Bonkers (the board game), dtype: int64
# 41         668
# MEH        629
# DESPAIR    520
# JOY        431
# Name: Q6 | Bottle Caps, dtype: int64
# DESPAIR    1105
# 41          597
# MEH         444
# JOY         102
# Name: Q6 | Box'o'Raisins, dtype: int64
# DESPAIR    1516
# 41          615
# MEH          98
# JOY          19
# Name: Q6 | Broken glow stick, dtype: int64
# JOY        1094
# 41          593
# MEH         434
# DESPAIR     127
# Name: Q6 | Butterfinger, dtype: int64
# JOY        759
# 41         594
# MEH        527
# DESPAIR    368
# Name: Q6 | Cadbury Creme Eggs, dtype: int64
# DESPAIR    692
# 41         590
# MEH        520
# JOY        446
# Name: Q6 | Candy Corn, dtype: int64
# DESPAIR    1231
# 41          599
# MEH         384
# JOY          34
# Name: Q6 | Candy that is clearly just the stuff given out for free at restaurants, dtype: int64
# JOY        900
# 41         656
# MEH        544
# DESPAIR    148
# Name: Q6 | Caramellos, dtype: int64
# JOY        1346
# 41          591
# MEH         252
# DESPAIR      59
# Name: Q6 | Cash, or other forms of legal tender, dtype: int64
# JOY        972
# 41         647
# MEH        336
# DESPAIR    293
# Name: Q6 | Chardonnay, dtype: int64
# 41         836
# DESPAIR    593
# MEH        535
# JOY        284
# Name: Q6 | Chick-o-Sticks (we don’t know what that is), dtype: int64
# DESPAIR    710
# MEH        692
# 41         620
# JOY        226
# Name: Q6 | Chiclets, dtype: int64
# 41         757
# MEH        554
# DESPAIR    502
# JOY        435
# Name: Q6 | Coffee Crisp, dtype: int64
# DESPAIR    1308
# 41          614
# JOY         231
# MEH          95
# Name: Q6 | Creepy Religious comics/Chick Tracts, dtype: int64
# DESPAIR    1334
# 41          601
# MEH         232
# JOY          81
# Name: Q6 | Dental paraphenalia, dtype: int64
# 41         631
# DESPAIR    620
# MEH        617
# JOY        380
# Name: Q6 | Dots, dtype: int64
# JOY        1100
# 41          609
# MEH         444
# DESPAIR      95
# Name: Q6 | Dove Bars, dtype: int64
# 41         723
# DESPAIR    631
# MEH        522
# JOY        372
# Name: Q6 | Fuzzy Peaches, dtype: int64
# DESPAIR    1090
# 41          636
# MEH         369
# JOY         153
# Name: Q6 | Generic Brand Acetaminophen, dtype: int64
# MEH        660
# 41         607
# JOY        562
# DESPAIR    419
# Name: Q6 | Glow sticks, dtype: int64
# 41         776
# MEH        660
# DESPAIR    428
# JOY        384
# Name: Q6 | Goo Goo Clusters, dtype: int64
# DESPAIR    694
# 41         641
# MEH        538
# JOY        375
# Name: Q6 | Good N' Plenty, dtype: int64
# DESPAIR    1361
# 41          623
# MEH         224
# JOY          40
# Name: Q6 | Gum from baseball cards, dtype: int64
# JOY        699
# 41         605
# MEH        554
# DESPAIR    390
# Name: Q6 | Gummy Bears straight up, dtype: int64
# MEH        849
# 41         605
# DESPAIR    543
# JOY        251
# Name: Q6 | Hard Candy, dtype: int64
# DESPAIR    797
# MEH        645
# 41         603
# JOY        203
# Name: Q6 | Healthy Fruit, dtype: int64
# JOY        1001
# 41          619
# MEH         432
# DESPAIR     196
# Name: Q6 | Heath Bar, dtype: int64
# JOY        1030
# 41          585
# MEH         468
# DESPAIR     165
# Name: Q6 | Hershey's Dark Chocolate, dtype: int64
# JOY        837
# MEH        624
# 41         584
# DESPAIR    203
# Name: Q6 | Hershey’s Milk Chocolate, dtype: int64
# JOY        777
# MEH        681
# 41         590
# DESPAIR    200
# Name: Q6 | Hershey's Kisses, dtype: int64
# DESPAIR    827
# 41         620
# JOY        403
# MEH        398
# Name: Q6 | Hugs (actual physical hugs), dtype: int64
# DESPAIR    985
# 41         602
# MEH        571
# JOY         90
# Name: Q6 | Jolly Rancher (bad flavor), dtype: int64
# JOY        689
# 41         606
# MEH        602
# DESPAIR    351
# Name: Q6 | Jolly Ranchers (good flavor), dtype: int64
# 41         909
# DESPAIR    890
# MEH        382
# JOY         67
# Name: Q6 | JoyJoy (Mit Iodine!), dtype: int64
# JOY        956
# 41         604
# MEH        461
# DESPAIR    227
# Name: Q6 | Junior Mints, dtype: int64
# 41         836
# DESPAIR    835
# MEH        439
# JOY        138
# Name: Q6 | Senior Mints, dtype: int64
# DESPAIR    1341
# 41          649
# MEH         159
# JOY          99
# Name: Q6 | Kale smoothie, dtype: int64
# 41         833
# DESPAIR    535
# JOY        472
# MEH        408
# Name: Q6 | Kinder Happy Hippo, dtype: int64
# JOY        1346
# 41          586
# MEH         268
# DESPAIR      48
# Name: Q6 | Kit Kat, dtype: int64
# MEH        677
# 41         637
# DESPAIR    512
# JOY        422
# Name: Q6 | LaffyTaffy, dtype: int64
# MEH        651
# 41         632
# JOY        617
# DESPAIR    348
# Name: Q6 | LemonHeads, dtype: int64
# MEH        664
# 41         594
# JOY        517
# DESPAIR    473
# Name: Q6 | Licorice (not black), dtype: int64
# DESPAIR    846
# 41         594
# JOY        501
# MEH        307
# Name: Q6 | Licorice (yes black), dtype: int64
# JOY        1190
# 41          626
# MEH         346
# DESPAIR      86
# Name: Q6 | Lindt Truffle, dtype: int64
# MEH        864
# 41         600
# DESPAIR    449
# JOY        335
# Name: Q6 | Lollipops, dtype: int64
# JOY        945
# 41         631
# MEH        555
# DESPAIR    117
# Name: Q6 | Mars, dtype: int64
# 41         909
# MEH        665
# DESPAIR    538
# JOY        136
# Name: Q6 | Maynards, dtype: int64
# 41         631
# MEH        603
# DESPAIR    514
# JOY        500
# Name: Q6 | Mike and Ike, dtype: int64
# JOY        815
# 41         605
# MEH        599
# DESPAIR    229
# Name: Q6 | Milk Duds, dtype: int64
# JOY        1100
# 41          600
# MEH         451
# DESPAIR      97
# Name: Q6 | Milky Way, dtype: int64
# JOY        1041
# 41          586
# MEH         553
# DESPAIR      68
# Name: Q6 | Regular M&Ms, dtype: int64
# JOY        1202
# 41          584
# MEH         350
# DESPAIR     112
# Name: Q6 | Peanut M&M’s, dtype: int64
# JOY        949
# 41         635
# MEH        553
# DESPAIR    111
# Name: Q6 | Blue M&M's, dtype: int64
# JOY        931
# 41         637
# MEH        566
# DESPAIR    114
# Name: Q6 | Red M&M's, dtype: int64
# JOY        905
# 41         669
# MEH        551
# DESPAIR    123
# Name: Q6 | Green Party M&M's, dtype: int64
# 41         715
# JOY        702
# MEH        591
# DESPAIR    240
# Name: Q6 | Independent M&M's, dtype: int64
# 41         833
# DESPAIR    649
# MEH        566
# JOY        200
# Name: Q6 | Abstained from M&M'ing., dtype: int64
# MEH        710
# 41         631
# JOY        499
# DESPAIR    408
# Name: Q6 | Minibags of chips, dtype: int64
# 41         682
# MEH        601
# JOY        576
# DESPAIR    389
# Name: Q6 | Mint Kisses, dtype: int64
# JOY        846
# 41         711
# DESPAIR    374
# MEH        317
# Name: Q6 | Mint Juleps, dtype: int64
# JOY        800
# 41         645
# MEH        595
# DESPAIR    208
# Name: Q6 | Mr. Goodbar, dtype: int64
# DESPAIR    747
# 41         649
# MEH        522
# JOY        330
# Name: Q6 | Necco Wafers, dtype: int64
# JOY        717
# 41         629
# MEH        567
# DESPAIR    335
# Name: Q6 | Nerds, dtype: int64
# JOY        1104
# 41          605
# MEH         448
# DESPAIR      91
# Name: Q6 | Nestle Crunch, dtype: int64
# 41         708
# MEH        681
# DESPAIR    522
# JOY        337
# Name: Q6 | Now'n'Laters, dtype: int64
# DESPAIR    1007
# 41          618
# MEH         404
# JOY         219
# Name: Q6 | Peeps, dtype: int64
# DESPAIR    1006
# 41          615
# MEH         460
# JOY         167
# Name: Q6 | Pencils, dtype: int64
# 41         628
# MEH        603
# DESPAIR    514
# JOY        503
# Name: Q6 | Pixy Stix, dtype: int64
# DESPAIR    1378
# 41          657
# MEH         129
# JOY          84
# Name: Q6 | Real Housewives of Orange County Season 9 Blue-Ray, dtype: int64
# JOY        1396
# 41          592
# MEH         174
# DESPAIR      86
# Name: Q6 | Reese’s Peanut Butter Cups, dtype: int64
# JOY        1061
# 41          603
# MEH         429
# DESPAIR     155
# Name: Q6 | Reese's Pieces, dtype: int64
# 41         902
# MEH        665
# DESPAIR    446
# JOY        235
# Name: Q6 | Reggie Jackson Bar, dtype: int64
# JOY        1075
# 41          623
# MEH         422
# DESPAIR     128
# Name: Q6 | Rolos, dtype: int64
# DESPAIR    1067
# 41          678
# MEH         303
# JOY         200
# Name: Q6 | Sandwich-sized bags filled with BooBerry Crunch, dtype: int64
# JOY        775
# 41         613
# MEH        563
# DESPAIR    297
# Name: Q6 | Skittles, dtype: int64
# JOY        680
# 41         628
# MEH        540
# DESPAIR    400
# Name: Q6 | Smarties (American), dtype: int64
# 41         795
# MEH        569
# JOY        495
# DESPAIR    389
# Name: Q6 | Smarties (Commonwealth), dtype: int64
# JOY        1301
# 41          601
# MEH         272
# DESPAIR      74
# Name: Q6 | Snickers, dtype: int64
# JOY        717
# 41         640
# DESPAIR    473
# MEH        418
# Name: Q6 | Sourpatch Kids (i.e. abominations of nature), dtype: int64
# DESPAIR    1059
# 41          775
# MEH         291
# JOY         123
# Name: Q6 | Spotted Dick, dtype: int64
# JOY        800
# 41         600
# MEH        571
# DESPAIR    277
# Name: Q6 | Starburst, dtype: int64
# JOY        729
# 41         615
# MEH        565
# DESPAIR    339
# Name: Q6 | Sweet Tarts, dtype: int64
# JOY        708
# 41         618
# MEH        506
# DESPAIR    416
# Name: Q6 | Swedish Fish, dtype: int64
# 41         892
# DESPAIR    706
# MEH        508
# JOY        142
# Name: Q6 | Sweetums (a friend to diabetes), dtype: int64
# 41         810
# MEH        571
# JOY        546
# DESPAIR    321
# Name: Q6 | Take 5, dtype: int64
# DESPAIR    697
# MEH        677
# 41         623
# JOY        251
# Name: Q6 | Tic Tacs, dtype: int64
# DESPAIR    1164
# 41          642
# MEH         267
# JOY         175
# Name: Q6 | Those odd marshmallow circus peanut things, dtype: int64
# JOY        981
# 41         615
# MEH        486
# DESPAIR    166
# Name: Q6 | Three Musketeers, dtype: int64
# JOY        1231
# 41          613
# MEH         328
# DESPAIR      76
# Name: Q6 | Tolberone something or other, dtype: int64
# DESPAIR    778
# MEH        647
# 41         614
# JOY        209
# Name: Q6 | Trail Mix, dtype: int64
# JOY        1322
# 41          599
# MEH         264
# DESPAIR      63
# Name: Q6 | Twix, dtype: int64
# DESPAIR    1059
# 41          695
# MEH         275
# JOY         219
# Name: Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein, dtype: int64
# 41         694
# JOY        666
# DESPAIR    661
# MEH        227
# Name: Q6 | Vicodin, dtype: int64
# JOY        789
# 41         725
# MEH        477
# DESPAIR    257
# Name: Q6 | Whatchamacallit Bars, dtype: int64
# DESPAIR    1357
# 41          662
# MEH         191
# JOY          38
# Name: Q6 | White Bread, dtype: int64
# DESPAIR    1205
# 41          650
# MEH         286
# JOY         107
# Name: Q6 | Whole Wheat anything, dtype: int64
# JOY        1035
# 41          613
# MEH         388
# DESPAIR     212
# Name: Q6 | York Peppermint Patties, dtype: int64
# 41                                                                                                                      1396
# Almond Joy                                                                                                                10
# Beer                                                                                                                      10
# beer                                                                                                                       3
# Mounds, Almond Joy                                                                                                         3
#                                                                                                                         ...
# Lady Godiva chocolates, Belgian chocolates, Bourbon Balls                                                                  1
# Safety suckers. I don't know what it is about the flavoring used for those loop-sticked suckers, but they are great!       1
# Math and sciences, technology, the girl I like (with out her boy friend), soccer, running.                                 1
# Kinder Surprise! Charleston chew                                                                                           1
# Junior Mints, Thin Mints                                                                                                   1
# Name: Q7: JOY OTHER, Length: 810, dtype: int64
# 41                                                                                               1577
# Trump                                                                                               7
# Tootsie Rolls                                                                                       3
# Popcorn balls                                                                                       3
# Almond Joy, Mounds                                                                                  3
#                                                                                                  ...
# Whining kids                                                                                        1
# tootsie rolls, off brand candy                                                                      1
# Crappy colored pencils or crayons                                                                   1
# Heroin                                                                                              1
# Anything with gluten (Celiac) Cheap nasty chocolate (e.g. pretty much anything mass produced)       1
# Name: Q8: DESPAIR OTHER, Length: 640, dtype: int64
# 41                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1885
# The moment I realized you expected me to evaluate what might be over 100 items I stopped. Follow this link to see a better approach to evaluating a large list of items: http://walthickey.com/2017/10/18/whats-the-best-halloween-candy/  It's essentially random pairwise comparison. Allourideas.org provides a similar platform but allows users too add their own items. Good luck!                                                                                                                   1
# Nobody goes trick or treating to get anything healthy. Just don't answer the door then, dentists.                                                                                                                                                                                                                                                                                                                                                                                                          1
# scoring a bag full of reeses=winning the halloween lottery.  reeses for the win.                                                                                                                                                                                                                                                                                                                                                                                                                           1
# Seriously. Mounds are the fucking worst. Except those peanutbutter and jelly cup things they tried, years and years back. Does anyone remember those? What the fuck were they thinking? Jelly and chocolate? I mean, really?                                                                                                                                                                                                                                                                               1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# Bottom line is Twix is really the only candy worth eating.                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# Chocolate>hard candy: Because I'm old but not that old. Brands names usually > generic: Could be cultural conditioning, could be they're actually better. Unclear at this point. Bigger > smaller: because duh. Homemade = nope! Unless Baker = familiar human I love these entries. You guys make it easy to get though the list. PS. Dislike of sour patch kids = demerits :) PPS I'm old AF and haven't gone trick or treating in years. I just buy or make what I want. The one joy of adulting.       1
# Please assume any selection I have made that is different in recipe in the UK to the US/Canada refers to the version available in the UK - I know you lot across the pond have strange ideas about sweets - HFCS, et al.  "Dove Bar" means soap to me - a short Google later informs me that it is an ice cream bar, but I cannot shake the thought of eating a bar of soap.  Why have Black Jacks in the list but not it's better (but still not great) sibling chew Fruit Salad?                         1
# Many of the entries on this survey make me very very concerned.                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Wouldn't it be something if people gave out fried chicken on Halloween?                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# Name: Q9: OTHER COMMENTS, Length: 364, dtype: int64
# White and gold    1019
# 41                 650
# Blue and black     579
# Name: Q10: DRESS, dtype: int64
# Friday    1019
# 41         631
# Sunday     598
# Name: Q11: DAY, dtype: int64
# 41.0    2167
# 1.0       81
# Name: Q12: MEDIA [Daily Dish], dtype: int64
# 1.0     1272
# 41.0     976
# Name: Q12: MEDIA [Science], dtype: int64
# 41.0    2155
# 1.0       93
# Name: Q12: MEDIA [ESPN], dtype: int64
# 41.0    2189
# 1.0       59
# Name: Q12: MEDIA [Yahoo], dtype: int64
# 41          752
# (77, 24)      8
# (73, 27)      7
# (76, 24)      7
# (73, 26)      7
#            ...
# (63, 23)      1
# (22, 22)      1
# (72, 75)      1
# (87, 22)      1
# (60, 6)       1
# Name: Click Coordinates (x, y), Length: 910, dtype: int64

# %%
cd.drop(['Q5: STATE, PROVINCE, COUNTY, ETC','Q7: JOY OTHER','Q8: DESPAIR OTHER','Q9: OTHER COMMENTS'],axis=1,inplace=True)
# Out:
# C:\Users\Laptop Shop\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER  Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male     44.0         USA
# 3        90272840             No       Male     40.0         USA
# 4        90272841             No       Male     23.0         USA
# 6        90272853             No       Male     53.0         USA
# 7        90272854             No       Male     33.0      CANADA
# ...           ...            ...        ...      ...         ...
# 2455     90314359             No       Male     24.0         USA
# 2456     90314580             No     Female     33.0         USA
# 2457     90314634             No     Female     26.0         USA
# 2458     90314658             No       Male     58.0         USA
# 2459     90314802             No     Female     66.0         USA
#
#      Q6 | 100 Grand Bar  \
# 1                   MEH
# 3                   MEH
# 4                   JOY
# 6                    41
# 7                   JOY
# ...                 ...
# 2455                JOY
# 2456                MEH
# 2457                MEH
# 2458                 41
# 2459            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                    41
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                 41
# 2459                                            DESPAIR
#
#      Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 1                              JOY              MEH                  DESPAIR
# 3                              JOY              MEH                      MEH
# 4                              JOY          DESPAIR                      MEH
# 6                               41               41                       41
# 7                              JOY          DESPAIR                  DESPAIR
# ...                            ...              ...                      ...
# 2455                           MEH          DESPAIR                  DESPAIR
# 2456                           JOY               41                       41
# 2457                           JOY          DESPAIR                      MEH
# 2458                            41               41                       41
# 2459                           JOY          DESPAIR                  DESPAIR
#
#      Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 1                          DESPAIR          DESPAIR            DESPAIR
# 3                          DESPAIR              MEH            DESPAIR
# 4                          DESPAIR              MEH            DESPAIR
# 6                               41               41                 41
# 7                              MEH              JOY                MEH
# ...                            ...              ...                ...
# 2455                           MEH              MEH            DESPAIR
# 2456                            41               41            DESPAIR
# 2457                           JOY          DESPAIR                MEH
# 2458                            41               41                 41
# 2459                       DESPAIR          DESPAIR                MEH
#
#      Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 1                   DESPAIR           DESPAIR                     MEH
# 3                   DESPAIR               MEH                     MEH
# 4                   DESPAIR               MEH                     MEH
# 6                        41                41                      41
# 7                       JOY               JOY                     JOY
# ...                     ...               ...                     ...
# 2455                DESPAIR               MEH                 DESPAIR
# 2456                DESPAIR               JOY                     JOY
# 2457                    MEH           DESPAIR                     JOY
# 2458                     41                41                      41
# 2459                DESPAIR               JOY                     MEH
#
#      Q6 | Candy Corn  \
# 1                MEH
# 3            DESPAIR
# 4            DESPAIR
# 6                 41
# 7                JOY
# ...              ...
# 2455         DESPAIR
# 2456             JOY
# 2457         DESPAIR
# 2458              41
# 2459             MEH
#
#      Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                    41
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                                MEH
# 2458                                                 41
# 2459                                            DESPAIR
#
#      Q6 | Caramellos Q6 | Cash, or other forms of legal tender  \
# 1                MEH                                       JOY
# 3                MEH                                       JOY
# 4                JOY                                       MEH
# 6                 41                                        41
# 7                JOY                                       JOY
# ...              ...                                       ...
# 2455             JOY                                       JOY
# 2456             JOY                                       JOY
# 2457         DESPAIR                                       JOY
# 2458              41                                        41
# 2459             MEH                                       JOY
#
#      Q6 | Chardonnay Q6 | Chick-o-Sticks (we don’t know what that is)  \
# 1                MEH                                          DESPAIR
# 3                MEH                                              JOY
# 4                JOY                                          DESPAIR
# 6                 41                                               41
# 7                JOY                                          DESPAIR
# ...              ...                                              ...
# 2455             JOY                                              MEH
# 2456             JOY                                              JOY
# 2457             JOY                                              MEH
# 2458              41                                               41
# 2459             JOY                                          DESPAIR
#
#      Q6 | Chiclets Q6 | Coffee Crisp  \
# 1          DESPAIR           DESPAIR
# 3              MEH           DESPAIR
# 4          DESPAIR               MEH
# 6               41                41
# 7              MEH               MEH
# ...            ...               ...
# 2455           JOY               JOY
# 2456       DESPAIR                41
# 2457           MEH           DESPAIR
# 2458            41                41
# 2459           MEH           DESPAIR
#
#      Q6 | Creepy Religious comics/Chick Tracts Q6 | Dental paraphenalia  \
# 1                                      DESPAIR                  DESPAIR
# 3                                      DESPAIR                  DESPAIR
# 4                                      DESPAIR                  DESPAIR
# 6                                           41                       41
# 7                                      DESPAIR                  DESPAIR
# ...                                        ...                      ...
# 2455                                   DESPAIR                      MEH
# 2456                                   DESPAIR                  DESPAIR
# 2457                                   DESPAIR                  DESPAIR
# 2458                                        41                       41
# 2459                                   DESPAIR                  DESPAIR
#
#      Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 1          MEH            JOY            DESPAIR
# 3          JOY            JOY                MEH
# 4          MEH            JOY            DESPAIR
# 6           41             41                 41
# 7          MEH            MEH                JOY
# ...        ...            ...                ...
# 2455   DESPAIR            JOY                MEH
# 2456   DESPAIR            MEH                 41
# 2457       MEH            JOY                MEH
# 2458        41             41                 41
# 2459       JOY            JOY                MEH
#
#      Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 1                             DESPAIR          DESPAIR               DESPAIR
# 3                                 MEH              JOY                   JOY
# 4                             DESPAIR          DESPAIR                   MEH
# 6                                  41               41                    41
# 7                             DESPAIR          DESPAIR               DESPAIR
# ...                               ...              ...                   ...
# 2455                              JOY          DESPAIR                   JOY
# 2456                              MEH          DESPAIR                    41
# 2457                              JOY              JOY               DESPAIR
# 2458                               41               41                    41
# 2459                          DESPAIR              MEH               DESPAIR
#
#      Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 1                    MEH                      DESPAIR
# 3                    MEH                      DESPAIR
# 4                    MEH                      DESPAIR
# 6                     41                           41
# 7                DESPAIR                      DESPAIR
# ...                  ...                          ...
# 2455                 JOY                          JOY
# 2456             DESPAIR                      DESPAIR
# 2457             DESPAIR                      DESPAIR
# 2458                  41                           41
# 2459                 JOY                      DESPAIR
#
#      Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 1                             MEH             MEH            DESPAIR
# 3                             JOY             MEH                MEH
# 4                             JOY             MEH            DESPAIR
# 6                              41              41                 41
# 7                             JOY         DESPAIR            DESPAIR
# ...                           ...             ...                ...
# 2455                          MEH         DESPAIR                MEH
# 2456                          MEH             MEH            DESPAIR
# 2457                          MEH             MEH            DESPAIR
# 2458                           41              41                 41
# 2459                          MEH         DESPAIR            DESPAIR
#
#      Q6 | Heath Bar Q6 | Hershey's Dark Chocolate  \
# 1               MEH                           JOY
# 3           DESPAIR                           MEH
# 4           DESPAIR                           JOY
# 6                41                            41
# 7           DESPAIR                           JOY
# ...             ...                           ...
# 2455        DESPAIR                           JOY
# 2456            JOY                           MEH
# 2457            MEH                           JOY
# 2458             41                            41
# 2459        DESPAIR                           JOY
#
#      Q6 | Hershey’s Milk Chocolate Q6 | Hershey's Kisses  \
# 1                              JOY                   MEH
# 3                              MEH                   MEH
# 4                              MEH                   MEH
# 6                               41                    41
# 7                              MEH                   MEH
# ...                            ...                   ...
# 2455                           MEH                   MEH
# 2456                           JOY                   MEH
# 2457                           JOY                   JOY
# 2458                            41                    41
# 2459                           JOY                   JOY
#
#      Q6 | Hugs (actual physical hugs) Q6 | Jolly Rancher (bad flavor)  \
# 1                             DESPAIR                         DESPAIR
# 3                                 MEH                             MEH
# 4                             DESPAIR                             MEH
# 6                                  41                              41
# 7                             DESPAIR                         DESPAIR
# ...                               ...                             ...
# 2455                              JOY                             MEH
# 2456                          DESPAIR                             MEH
# 2457                              MEH                         DESPAIR
# 2458                               41                              41
# 2459                          DESPAIR                         DESPAIR
#
#      Q6 | Jolly Ranchers (good flavor) Q6 | JoyJoy (Mit Iodine!)  \
# 1                                  MEH                   DESPAIR
# 3                                  MEH                   DESPAIR
# 4                                  JOY                       MEH
# 6                                   41                        41
# 7                              DESPAIR                   DESPAIR
# ...                                ...                       ...
# 2455                               MEH                       MEH
# 2456                               JOY                        41
# 2457                               JOY                   DESPAIR
# 2458                                41                        41
# 2459                               MEH                   DESPAIR
#
#      Q6 | Junior Mints Q6 | Senior Mints Q6 | Kale smoothie  \
# 1              DESPAIR           DESPAIR            DESPAIR
# 3              DESPAIR           DESPAIR            DESPAIR
# 4                  JOY           DESPAIR            DESPAIR
# 6                   41                41                 41
# 7              DESPAIR           DESPAIR            DESPAIR
# ...                ...               ...                ...
# 2455           DESPAIR           DESPAIR                MEH
# 2456               JOY                41            DESPAIR
# 2457               JOY               MEH            DESPAIR
# 2458                41                41                 41
# 2459               JOY           DESPAIR            DESPAIR
#
#      Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy Q6 | LemonHeads  \
# 1                    DESPAIR          JOY         DESPAIR             MEH
# 3                        MEH          MEH             JOY             JOY
# 4                        JOY          JOY             JOY             JOY
# 6                         41           41              41              41
# 7                    DESPAIR          MEH             MEH             JOY
# ...                      ...          ...             ...             ...
# 2455                     JOY          JOY             MEH             MEH
# 2456                      41          JOY         DESPAIR         DESPAIR
# 2457                 DESPAIR      DESPAIR             JOY         DESPAIR
# 2458                      41           41              41              41
# 2459                 DESPAIR          MEH         DESPAIR         DESPAIR
#
#      Q6 | Licorice (not black) Q6 | Licorice (yes black) Q6 | Lindt Truffle  \
# 1                          MEH                       JOY                MEH
# 3                          MEH                       JOY                JOY
# 4                          MEH                   DESPAIR                JOY
# 6                           41                        41                 41
# 7                          MEH                   DESPAIR            DESPAIR
# ...                        ...                       ...                ...
# 2455                       JOY                   DESPAIR                JOY
# 2456                       MEH                   DESPAIR                MEH
# 2457                       MEH                   DESPAIR                JOY
# 2458                        41                        41                 41
# 2459                   DESPAIR                   DESPAIR                JOY
#
#      Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike Q6 | Milk Duds  \
# 1           DESPAIR   DESPAIR       DESPAIR               MEH            MEH
# 3           DESPAIR       JOY           MEH               MEH        DESPAIR
# 4               MEH       MEH       DESPAIR               MEH            MEH
# 6                41        41            41                41             41
# 7               MEH       JOY           JOY               JOY            JOY
# ...             ...       ...           ...               ...            ...
# 2455        DESPAIR       MEH           MEH               MEH            JOY
# 2456            MEH        41            41           DESPAIR            MEH
# 2457            MEH       JOY       DESPAIR               MEH            JOY
# 2458             41        41            41                41             41
# 2459        DESPAIR       JOY       DESPAIR               MEH        DESPAIR
#
#      Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s Q6 | Blue M&M's  \
# 1               JOY               JOY               MEH             JOY
# 3               JOY               MEH               JOY             MEH
# 4               JOY               JOY               JOY             JOY
# 6                41                41                41              41
# 7               JOY               JOY               JOY             JOY
# ...             ...               ...               ...             ...
# 2455            JOY               MEH               JOY             JOY
# 2456            MEH               JOY               JOY              41
# 2457            JOY               JOY           DESPAIR             JOY
# 2458             41                41                41              41
# 2459            JOY               JOY               JOY             JOY
#
#      Q6 | Red M&M's Q6 | Green Party M&M's Q6 | Independent M&M's  \
# 1               JOY                    JOY                    JOY
# 3               MEH                    MEH                    MEH
# 4               JOY                    JOY                    JOY
# 6                41                     41                     41
# 7               JOY                    JOY                    MEH
# ...             ...                    ...                    ...
# 2455            MEH                    JOY                    JOY
# 2456             41                     41                     41
# 2457            JOY                    JOY                    JOY
# 2458             41                     41                     41
# 2459            JOY                    JOY                DESPAIR
#
#      Q6 | Abstained from M&M'ing. Q6 | Minibags of chips Q6 | Mint Kisses  \
# 1                         DESPAIR                DESPAIR              MEH
# 3                             MEH                DESPAIR          DESPAIR
# 4                             MEH                DESPAIR              JOY
# 6                              41                     41               41
# 7                         DESPAIR                    JOY          DESPAIR
# ...                           ...                    ...              ...
# 2455                          MEH                    MEH              JOY
# 2456                           41                    MEH              JOY
# 2457                      DESPAIR                    JOY              JOY
# 2458                           41                     41               41
# 2459                      DESPAIR                    MEH              MEH
#
#      Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers Q6 | Nerds  \
# 1             DESPAIR          DESPAIR           DESPAIR    DESPAIR
# 3                 MEH              MEH           DESPAIR        MEH
# 4                 JOY              MEH           DESPAIR        JOY
# 6                  41               41                41         41
# 7             DESPAIR              MEH               MEH        JOY
# ...               ...              ...               ...        ...
# 2455              JOY              JOY               MEH        MEH
# 2456               41              JOY           DESPAIR        JOY
# 2457              JOY          DESPAIR           DESPAIR        MEH
# 2458               41               41                41         41
# 2459          DESPAIR              JOY               MEH    DESPAIR
#
#      Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 1                   JOY           DESPAIR    DESPAIR      DESPAIR
# 3                   MEH               MEH    DESPAIR      DESPAIR
# 4                   JOY               JOY        MEH      DESPAIR
# 6                    41                41         41           41
# 7                   JOY               MEH    DESPAIR      DESPAIR
# ...                 ...               ...        ...          ...
# 2455                JOY               JOY    DESPAIR      DESPAIR
# 2456                MEH               JOY    DESPAIR      DESPAIR
# 2457            DESPAIR               MEH        MEH          MEH
# 2458                 41                41         41           41
# 2459                MEH           DESPAIR        MEH      DESPAIR
#
#      Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 1           DESPAIR                                            DESPAIR
# 3           DESPAIR                                            DESPAIR
# 4               JOY                                            DESPAIR
# 6                41                                                 41
# 7           DESPAIR                                            DESPAIR
# ...             ...                                                ...
# 2455            JOY                                                MEH
# 2456            MEH                                            DESPAIR
# 2457            JOY                                                JOY
# 2458             41                                                 41
# 2459        DESPAIR                                            DESPAIR
#
#      Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces  \
# 1                                JOY                 JOY
# 3                                JOY                 MEH
# 4                                JOY                 JOY
# 6                                 41                  41
# 7                                JOY                 JOY
# ...                              ...                 ...
# 2455                             JOY                 JOY
# 2456                             JOY                 JOY
# 2457                             JOY                 MEH
# 2458                              41                  41
# 2459                             MEH             DESPAIR
#
#      Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 1                    DESPAIR        JOY
# 3                        MEH        MEH
# 4                        MEH        JOY
# 6                         41         41
# 7                         41        JOY
# ...                      ...        ...
# 2455                     JOY        JOY
# 2456                      41        MEH
# 2457                     MEH        JOY
# 2458                      41         41
# 2459                 DESPAIR    DESPAIR
#
#      Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 1                                               DESPAIR         DESPAIR
# 3                                               DESPAIR         DESPAIR
# 4                                                    41             JOY
# 6                                                    41              41
# 7                                               DESPAIR             JOY
# ...                                                 ...             ...
# 2455                                                JOY             MEH
# 2456                                            DESPAIR             JOY
# 2457                                            DESPAIR         DESPAIR
# 2458                                                 41              41
# 2459                                            DESPAIR         DESPAIR
#
#      Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 1                     DESPAIR                      DESPAIR           MEH
# 3                     DESPAIR                          MEH           JOY
# 4                         JOY                      DESPAIR            41
# 6                          41                           41            41
# 7                         MEH                          JOY           MEH
# ...                       ...                          ...           ...
# 2455                  DESPAIR                      DESPAIR           JOY
# 2456                  DESPAIR                           41           JOY
# 2457                      JOY                          MEH       DESPAIR
# 2458                       41                           41            41
# 2459                      MEH                      DESPAIR           JOY
#
#      Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 1                                              DESPAIR           DESPAIR
# 3                                                  MEH           DESPAIR
# 4                                                  MEH           DESPAIR
# 6                                                   41                41
# 7                                                  JOY           DESPAIR
# ...                                                ...               ...
# 2455                                               JOY               JOY
# 2456                                               MEH                41
# 2457                                           DESPAIR           DESPAIR
# 2458                                                41                41
# 2459                                               JOY           DESPAIR
#
#      Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 1               MEH          DESPAIR               MEH
# 3               MEH              MEH               JOY
# 4               JOY              JOY               MEH
# 6                41               41                41
# 7               MEH              JOY               JOY
# ...             ...              ...               ...
# 2455            JOY              MEH               JOY
# 2456            MEH              MEH               MEH
# 2457        DESPAIR              JOY           DESPAIR
# 2458             41               41                41
# 2459            MEH              MEH           DESPAIR
#
#      Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 1                                 DESPAIR     DESPAIR       DESPAIR
# 3                                     MEH         JOY           MEH
# 4                                 DESPAIR         MEH       DESPAIR
# 6                                      41          41            41
# 7                                     MEH         MEH       DESPAIR
# ...                                   ...         ...           ...
# 2455                              DESPAIR         MEH           JOY
# 2456                                   41         JOY       DESPAIR
# 2457                              DESPAIR         MEH           MEH
# 2458                                   41          41            41
# 2459                              DESPAIR     DESPAIR       DESPAIR
#
#      Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 1                                            DESPAIR                   JOY
# 3                                            DESPAIR               DESPAIR
# 4                                            DESPAIR                   JOY
# 6                                                 41                    41
# 7                                            DESPAIR                   JOY
# ...                                              ...                   ...
# 2455                                         DESPAIR                   MEH
# 2456                                         DESPAIR                   MEH
# 2457                                         DESPAIR                   JOY
# 2458                                              41                    41
# 2459                                         DESPAIR                   JOY
#
#      Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 1                                  JOY        DESPAIR       JOY
# 3                                  JOY            MEH       JOY
# 4                                  JOY        DESPAIR       JOY
# 6                                   41             41        41
# 7                                  MEH        DESPAIR       JOY
# ...                                ...            ...       ...
# 2455                               MEH            JOY       JOY
# 2456                               MEH        DESPAIR       JOY
# 2457                               JOY            MEH       MEH
# 2458                                41             41        41
# 2459                               MEH        DESPAIR   DESPAIR
#
#      Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                                   MEH
# 6                                                    41
# 7                                                   JOY
# ...                                                 ...
# 2455                                                MEH
# 2456                                                 41
# 2457                                                MEH
# 2458                                                 41
# 2459                                            DESPAIR
#
#      Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 1         DESPAIR                   DESPAIR          DESPAIR
# 3             JOY                       JOY          DESPAIR
# 4             JOY                       JOY          DESPAIR
# 6              41                        41               41
# 7             MEH                   DESPAIR          DESPAIR
# ...           ...                       ...              ...
# 2455          JOY                   DESPAIR              MEH
# 2456           41                       JOY          DESPAIR
# 2457          JOY                       MEH          DESPAIR
# 2458           41                        41               41
# 2459          JOY                   DESPAIR              MEH
#
#      Q6 | Whole Wheat anything Q6 | York Peppermint Patties      Q10: DRESS  \
# 1                      DESPAIR                      DESPAIR  White and gold
# 3                      DESPAIR                      DESPAIR  White and gold
# 4                      DESPAIR                          JOY  White and gold
# 6                           41                           41              41
# 7                      DESPAIR                      DESPAIR  Blue and black
# ...                        ...                          ...             ...
# 2455                   DESPAIR                          MEH  White and gold
# 2456                       MEH                          JOY  Blue and black
# 2457                   DESPAIR                          MEH  Blue and black
# 2458                        41                           41              41
# 2459                   DESPAIR                          JOY  White and gold
#
#      Q11: DAY  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# 1      Sunday                     41.0                   1.0
# 3      Sunday                     41.0                   1.0
# 4      Friday                     41.0                   1.0
# 6          41                     41.0                  41.0
# 7      Friday                     41.0                   1.0
# ...       ...                      ...                   ...
# 2455   Friday                     41.0                  41.0
# 2456   Friday                     41.0                   1.0
# 2457   Friday                     41.0                   1.0
# 2458       41                     41.0                  41.0
# 2459   Sunday                      1.0                  41.0
#
#       Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 1                  41.0                41.0                 (84, 25)
# 3                  41.0                41.0                 (75, 23)
# 4                  41.0                41.0                 (70, 10)
# 6                  41.0                41.0                       41
# 7                  41.0                41.0                  (55, 5)
# ...                 ...                 ...                      ...
# 2455               41.0                41.0                       41
# 2456               41.0                41.0                 (70, 26)
# 2457               41.0                41.0                 (67, 35)
# 2458               41.0                41.0                       41
# 2459               41.0                41.0                 (19, 26)
#
# [2248 rows x 115 columns]

# %%
cd6=cd.loc[:,'Q6 | 100 Grand Bar':'Q6 | York Peppermint Patties']

# %%
for i in cd6:
         cd6[i]=cd6[i].str.strip()

# %%
cd6
# Out:
#      Q6 | 100 Grand Bar  \
# 1                   MEH
# 3                   MEH
# 4                   JOY
# 6                   NaN
# 7                   JOY
# ...                 ...
# 2455                JOY
# 2456                MEH
# 2457                MEH
# 2458                NaN
# 2459            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   NaN
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 1                              JOY              MEH                  DESPAIR
# 3                              JOY              MEH                      MEH
# 4                              JOY          DESPAIR                      MEH
# 6                              NaN              NaN                      NaN
# 7                              JOY          DESPAIR                  DESPAIR
# ...                            ...              ...                      ...
# 2455                           MEH          DESPAIR                  DESPAIR
# 2456                           JOY              NaN                      NaN
# 2457                           JOY          DESPAIR                      MEH
# 2458                           NaN              NaN                      NaN
# 2459                           JOY          DESPAIR                  DESPAIR
#
#      Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 1                          DESPAIR          DESPAIR            DESPAIR
# 3                          DESPAIR              MEH            DESPAIR
# 4                          DESPAIR              MEH            DESPAIR
# 6                              NaN              NaN                NaN
# 7                              MEH              JOY                MEH
# ...                            ...              ...                ...
# 2455                           MEH              MEH            DESPAIR
# 2456                           NaN              NaN            DESPAIR
# 2457                           JOY          DESPAIR                MEH
# 2458                           NaN              NaN                NaN
# 2459                       DESPAIR          DESPAIR                MEH
#
#      Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 1                   DESPAIR           DESPAIR                     MEH
# 3                   DESPAIR               MEH                     MEH
# 4                   DESPAIR               MEH                     MEH
# 6                       NaN               NaN                     NaN
# 7                       JOY               JOY                     JOY
# ...                     ...               ...                     ...
# 2455                DESPAIR               MEH                 DESPAIR
# 2456                DESPAIR               JOY                     JOY
# 2457                    MEH           DESPAIR                     JOY
# 2458                    NaN               NaN                     NaN
# 2459                DESPAIR               JOY                     MEH
#
#      Q6 | Candy Corn  \
# 1                MEH
# 3            DESPAIR
# 4            DESPAIR
# 6                NaN
# 7                JOY
# ...              ...
# 2455         DESPAIR
# 2456             JOY
# 2457         DESPAIR
# 2458             NaN
# 2459             MEH
#
#      Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   NaN
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                                MEH
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Caramellos Q6 | Cash, or other forms of legal tender  \
# 1                MEH                                       JOY
# 3                MEH                                       JOY
# 4                JOY                                       MEH
# 6                NaN                                       NaN
# 7                JOY                                       JOY
# ...              ...                                       ...
# 2455             JOY                                       JOY
# 2456             JOY                                       JOY
# 2457         DESPAIR                                       JOY
# 2458             NaN                                       NaN
# 2459             MEH                                       JOY
#
#      Q6 | Chardonnay Q6 | Chick-o-Sticks (we don’t know what that is)  \
# 1                MEH                                          DESPAIR
# 3                MEH                                              JOY
# 4                JOY                                          DESPAIR
# 6                NaN                                              NaN
# 7                JOY                                          DESPAIR
# ...              ...                                              ...
# 2455             JOY                                              MEH
# 2456             JOY                                              JOY
# 2457             JOY                                              MEH
# 2458             NaN                                              NaN
# 2459             JOY                                          DESPAIR
#
#      Q6 | Chiclets Q6 | Coffee Crisp  \
# 1          DESPAIR           DESPAIR
# 3              MEH           DESPAIR
# 4          DESPAIR               MEH
# 6              NaN               NaN
# 7              MEH               MEH
# ...            ...               ...
# 2455           JOY               JOY
# 2456       DESPAIR               NaN
# 2457           MEH           DESPAIR
# 2458           NaN               NaN
# 2459           MEH           DESPAIR
#
#      Q6 | Creepy Religious comics/Chick Tracts Q6 | Dental paraphenalia  \
# 1                                      DESPAIR                  DESPAIR
# 3                                      DESPAIR                  DESPAIR
# 4                                      DESPAIR                  DESPAIR
# 6                                          NaN                      NaN
# 7                                      DESPAIR                  DESPAIR
# ...                                        ...                      ...
# 2455                                   DESPAIR                      MEH
# 2456                                   DESPAIR                  DESPAIR
# 2457                                   DESPAIR                  DESPAIR
# 2458                                       NaN                      NaN
# 2459                                   DESPAIR                  DESPAIR
#
#      Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 1          MEH            JOY            DESPAIR
# 3          JOY            JOY                MEH
# 4          MEH            JOY            DESPAIR
# 6          NaN            NaN                NaN
# 7          MEH            MEH                JOY
# ...        ...            ...                ...
# 2455   DESPAIR            JOY                MEH
# 2456   DESPAIR            MEH                NaN
# 2457       MEH            JOY                MEH
# 2458       NaN            NaN                NaN
# 2459       JOY            JOY                MEH
#
#      Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 1                             DESPAIR          DESPAIR               DESPAIR
# 3                                 MEH              JOY                   JOY
# 4                             DESPAIR          DESPAIR                   MEH
# 6                                 NaN              NaN                   NaN
# 7                             DESPAIR          DESPAIR               DESPAIR
# ...                               ...              ...                   ...
# 2455                              JOY          DESPAIR                   JOY
# 2456                              MEH          DESPAIR                   NaN
# 2457                              JOY              JOY               DESPAIR
# 2458                              NaN              NaN                   NaN
# 2459                          DESPAIR              MEH               DESPAIR
#
#      Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 1                    MEH                      DESPAIR
# 3                    MEH                      DESPAIR
# 4                    MEH                      DESPAIR
# 6                    NaN                          NaN
# 7                DESPAIR                      DESPAIR
# ...                  ...                          ...
# 2455                 JOY                          JOY
# 2456             DESPAIR                      DESPAIR
# 2457             DESPAIR                      DESPAIR
# 2458                 NaN                          NaN
# 2459                 JOY                      DESPAIR
#
#      Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 1                             MEH             MEH            DESPAIR
# 3                             JOY             MEH                MEH
# 4                             JOY             MEH            DESPAIR
# 6                             NaN             NaN                NaN
# 7                             JOY         DESPAIR            DESPAIR
# ...                           ...             ...                ...
# 2455                          MEH         DESPAIR                MEH
# 2456                          MEH             MEH            DESPAIR
# 2457                          MEH             MEH            DESPAIR
# 2458                          NaN             NaN                NaN
# 2459                          MEH         DESPAIR            DESPAIR
#
#      Q6 | Heath Bar Q6 | Hershey's Dark Chocolate  \
# 1               MEH                           JOY
# 3           DESPAIR                           MEH
# 4           DESPAIR                           JOY
# 6               NaN                           NaN
# 7           DESPAIR                           JOY
# ...             ...                           ...
# 2455        DESPAIR                           JOY
# 2456            JOY                           MEH
# 2457            MEH                           JOY
# 2458            NaN                           NaN
# 2459        DESPAIR                           JOY
#
#      Q6 | Hershey’s Milk Chocolate Q6 | Hershey's Kisses  \
# 1                              JOY                   MEH
# 3                              MEH                   MEH
# 4                              MEH                   MEH
# 6                              NaN                   NaN
# 7                              MEH                   MEH
# ...                            ...                   ...
# 2455                           MEH                   MEH
# 2456                           JOY                   MEH
# 2457                           JOY                   JOY
# 2458                           NaN                   NaN
# 2459                           JOY                   JOY
#
#      Q6 | Hugs (actual physical hugs) Q6 | Jolly Rancher (bad flavor)  \
# 1                             DESPAIR                         DESPAIR
# 3                                 MEH                             MEH
# 4                             DESPAIR                             MEH
# 6                                 NaN                             NaN
# 7                             DESPAIR                         DESPAIR
# ...                               ...                             ...
# 2455                              JOY                             MEH
# 2456                          DESPAIR                             MEH
# 2457                              MEH                         DESPAIR
# 2458                              NaN                             NaN
# 2459                          DESPAIR                         DESPAIR
#
#      Q6 | Jolly Ranchers (good flavor) Q6 | JoyJoy (Mit Iodine!)  \
# 1                                  MEH                   DESPAIR
# 3                                  MEH                   DESPAIR
# 4                                  JOY                       MEH
# 6                                  NaN                       NaN
# 7                              DESPAIR                   DESPAIR
# ...                                ...                       ...
# 2455                               MEH                       MEH
# 2456                               JOY                       NaN
# 2457                               JOY                   DESPAIR
# 2458                               NaN                       NaN
# 2459                               MEH                   DESPAIR
#
#      Q6 | Junior Mints Q6 | Senior Mints Q6 | Kale smoothie  \
# 1              DESPAIR           DESPAIR            DESPAIR
# 3              DESPAIR           DESPAIR            DESPAIR
# 4                  JOY           DESPAIR            DESPAIR
# 6                  NaN               NaN                NaN
# 7              DESPAIR           DESPAIR            DESPAIR
# ...                ...               ...                ...
# 2455           DESPAIR           DESPAIR                MEH
# 2456               JOY               NaN            DESPAIR
# 2457               JOY               MEH            DESPAIR
# 2458               NaN               NaN                NaN
# 2459               JOY           DESPAIR            DESPAIR
#
#      Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy Q6 | LemonHeads  \
# 1                    DESPAIR          JOY         DESPAIR             MEH
# 3                        MEH          MEH             JOY             JOY
# 4                        JOY          JOY             JOY             JOY
# 6                        NaN          NaN             NaN             NaN
# 7                    DESPAIR          MEH             MEH             JOY
# ...                      ...          ...             ...             ...
# 2455                     JOY          JOY             MEH             MEH
# 2456                     NaN          JOY         DESPAIR         DESPAIR
# 2457                 DESPAIR      DESPAIR             JOY         DESPAIR
# 2458                     NaN          NaN             NaN             NaN
# 2459                 DESPAIR          MEH         DESPAIR         DESPAIR
#
#      Q6 | Licorice (not black) Q6 | Licorice (yes black) Q6 | Lindt Truffle  \
# 1                          MEH                       JOY                MEH
# 3                          MEH                       JOY                JOY
# 4                          MEH                   DESPAIR                JOY
# 6                          NaN                       NaN                NaN
# 7                          MEH                   DESPAIR            DESPAIR
# ...                        ...                       ...                ...
# 2455                       JOY                   DESPAIR                JOY
# 2456                       MEH                   DESPAIR                MEH
# 2457                       MEH                   DESPAIR                JOY
# 2458                       NaN                       NaN                NaN
# 2459                   DESPAIR                   DESPAIR                JOY
#
#      Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike Q6 | Milk Duds  \
# 1           DESPAIR   DESPAIR       DESPAIR               MEH            MEH
# 3           DESPAIR       JOY           MEH               MEH        DESPAIR
# 4               MEH       MEH       DESPAIR               MEH            MEH
# 6               NaN       NaN           NaN               NaN            NaN
# 7               MEH       JOY           JOY               JOY            JOY
# ...             ...       ...           ...               ...            ...
# 2455        DESPAIR       MEH           MEH               MEH            JOY
# 2456            MEH       NaN           NaN           DESPAIR            MEH
# 2457            MEH       JOY       DESPAIR               MEH            JOY
# 2458            NaN       NaN           NaN               NaN            NaN
# 2459        DESPAIR       JOY       DESPAIR               MEH        DESPAIR
#
#      Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s Q6 | Blue M&M's  \
# 1               JOY               JOY               MEH             JOY
# 3               JOY               MEH               JOY             MEH
# 4               JOY               JOY               JOY             JOY
# 6               NaN               NaN               NaN             NaN
# 7               JOY               JOY               JOY             JOY
# ...             ...               ...               ...             ...
# 2455            JOY               MEH               JOY             JOY
# 2456            MEH               JOY               JOY             NaN
# 2457            JOY               JOY           DESPAIR             JOY
# 2458            NaN               NaN               NaN             NaN
# 2459            JOY               JOY               JOY             JOY
#
#      Q6 | Red M&M's Q6 | Green Party M&M's Q6 | Independent M&M's  \
# 1               JOY                    JOY                    JOY
# 3               MEH                    MEH                    MEH
# 4               JOY                    JOY                    JOY
# 6               NaN                    NaN                    NaN
# 7               JOY                    JOY                    MEH
# ...             ...                    ...                    ...
# 2455            MEH                    JOY                    JOY
# 2456            NaN                    NaN                    NaN
# 2457            JOY                    JOY                    JOY
# 2458            NaN                    NaN                    NaN
# 2459            JOY                    JOY                DESPAIR
#
#      Q6 | Abstained from M&M'ing. Q6 | Minibags of chips Q6 | Mint Kisses  \
# 1                         DESPAIR                DESPAIR              MEH
# 3                             MEH                DESPAIR          DESPAIR
# 4                             MEH                DESPAIR              JOY
# 6                             NaN                    NaN              NaN
# 7                         DESPAIR                    JOY          DESPAIR
# ...                           ...                    ...              ...
# 2455                          MEH                    MEH              JOY
# 2456                          NaN                    MEH              JOY
# 2457                      DESPAIR                    JOY              JOY
# 2458                          NaN                    NaN              NaN
# 2459                      DESPAIR                    MEH              MEH
#
#      Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers Q6 | Nerds  \
# 1             DESPAIR          DESPAIR           DESPAIR    DESPAIR
# 3                 MEH              MEH           DESPAIR        MEH
# 4                 JOY              MEH           DESPAIR        JOY
# 6                 NaN              NaN               NaN        NaN
# 7             DESPAIR              MEH               MEH        JOY
# ...               ...              ...               ...        ...
# 2455              JOY              JOY               MEH        MEH
# 2456              NaN              JOY           DESPAIR        JOY
# 2457              JOY          DESPAIR           DESPAIR        MEH
# 2458              NaN              NaN               NaN        NaN
# 2459          DESPAIR              JOY               MEH    DESPAIR
#
#      Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 1                   JOY           DESPAIR    DESPAIR      DESPAIR
# 3                   MEH               MEH    DESPAIR      DESPAIR
# 4                   JOY               JOY        MEH      DESPAIR
# 6                   NaN               NaN        NaN          NaN
# 7                   JOY               MEH    DESPAIR      DESPAIR
# ...                 ...               ...        ...          ...
# 2455                JOY               JOY    DESPAIR      DESPAIR
# 2456                MEH               JOY    DESPAIR      DESPAIR
# 2457            DESPAIR               MEH        MEH          MEH
# 2458                NaN               NaN        NaN          NaN
# 2459                MEH           DESPAIR        MEH      DESPAIR
#
#      Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 1           DESPAIR                                            DESPAIR
# 3           DESPAIR                                            DESPAIR
# 4               JOY                                            DESPAIR
# 6               NaN                                                NaN
# 7           DESPAIR                                            DESPAIR
# ...             ...                                                ...
# 2455            JOY                                                MEH
# 2456            MEH                                            DESPAIR
# 2457            JOY                                                JOY
# 2458            NaN                                                NaN
# 2459        DESPAIR                                            DESPAIR
#
#      Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces  \
# 1                                JOY                 JOY
# 3                                JOY                 MEH
# 4                                JOY                 JOY
# 6                                NaN                 NaN
# 7                                JOY                 JOY
# ...                              ...                 ...
# 2455                             JOY                 JOY
# 2456                             JOY                 JOY
# 2457                             JOY                 MEH
# 2458                             NaN                 NaN
# 2459                             MEH             DESPAIR
#
#      Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 1                    DESPAIR        JOY
# 3                        MEH        MEH
# 4                        MEH        JOY
# 6                        NaN        NaN
# 7                        NaN        JOY
# ...                      ...        ...
# 2455                     JOY        JOY
# 2456                     NaN        MEH
# 2457                     MEH        JOY
# 2458                     NaN        NaN
# 2459                 DESPAIR    DESPAIR
#
#      Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 1                                               DESPAIR         DESPAIR
# 3                                               DESPAIR         DESPAIR
# 4                                                   NaN             JOY
# 6                                                   NaN             NaN
# 7                                               DESPAIR             JOY
# ...                                                 ...             ...
# 2455                                                JOY             MEH
# 2456                                            DESPAIR             JOY
# 2457                                            DESPAIR         DESPAIR
# 2458                                                NaN             NaN
# 2459                                            DESPAIR         DESPAIR
#
#      Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 1                     DESPAIR                      DESPAIR           MEH
# 3                     DESPAIR                          MEH           JOY
# 4                         JOY                      DESPAIR           NaN
# 6                         NaN                          NaN           NaN
# 7                         MEH                          JOY           MEH
# ...                       ...                          ...           ...
# 2455                  DESPAIR                      DESPAIR           JOY
# 2456                  DESPAIR                          NaN           JOY
# 2457                      JOY                          MEH       DESPAIR
# 2458                      NaN                          NaN           NaN
# 2459                      MEH                      DESPAIR           JOY
#
#      Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 1                                              DESPAIR           DESPAIR
# 3                                                  MEH           DESPAIR
# 4                                                  MEH           DESPAIR
# 6                                                  NaN               NaN
# 7                                                  JOY           DESPAIR
# ...                                                ...               ...
# 2455                                               JOY               JOY
# 2456                                               MEH               NaN
# 2457                                           DESPAIR           DESPAIR
# 2458                                               NaN               NaN
# 2459                                               JOY           DESPAIR
#
#      Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 1               MEH          DESPAIR               MEH
# 3               MEH              MEH               JOY
# 4               JOY              JOY               MEH
# 6               NaN              NaN               NaN
# 7               MEH              JOY               JOY
# ...             ...              ...               ...
# 2455            JOY              MEH               JOY
# 2456            MEH              MEH               MEH
# 2457        DESPAIR              JOY           DESPAIR
# 2458            NaN              NaN               NaN
# 2459            MEH              MEH           DESPAIR
#
#      Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 1                                 DESPAIR     DESPAIR       DESPAIR
# 3                                     MEH         JOY           MEH
# 4                                 DESPAIR         MEH       DESPAIR
# 6                                     NaN         NaN           NaN
# 7                                     MEH         MEH       DESPAIR
# ...                                   ...         ...           ...
# 2455                              DESPAIR         MEH           JOY
# 2456                                  NaN         JOY       DESPAIR
# 2457                              DESPAIR         MEH           MEH
# 2458                                  NaN         NaN           NaN
# 2459                              DESPAIR     DESPAIR       DESPAIR
#
#      Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 1                                            DESPAIR                   JOY
# 3                                            DESPAIR               DESPAIR
# 4                                            DESPAIR                   JOY
# 6                                                NaN                   NaN
# 7                                            DESPAIR                   JOY
# ...                                              ...                   ...
# 2455                                         DESPAIR                   MEH
# 2456                                         DESPAIR                   MEH
# 2457                                         DESPAIR                   JOY
# 2458                                             NaN                   NaN
# 2459                                         DESPAIR                   JOY
#
#      Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 1                                  JOY        DESPAIR       JOY
# 3                                  JOY            MEH       JOY
# 4                                  JOY        DESPAIR       JOY
# 6                                  NaN            NaN       NaN
# 7                                  MEH        DESPAIR       JOY
# ...                                ...            ...       ...
# 2455                               MEH            JOY       JOY
# 2456                               MEH        DESPAIR       JOY
# 2457                               JOY            MEH       MEH
# 2458                               NaN            NaN       NaN
# 2459                               MEH        DESPAIR   DESPAIR
#
#      Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                                   MEH
# 6                                                   NaN
# 7                                                   JOY
# ...                                                 ...
# 2455                                                MEH
# 2456                                                NaN
# 2457                                                MEH
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 1         DESPAIR                   DESPAIR          DESPAIR
# 3             JOY                       JOY          DESPAIR
# 4             JOY                       JOY          DESPAIR
# 6             NaN                       NaN              NaN
# 7             MEH                   DESPAIR          DESPAIR
# ...           ...                       ...              ...
# 2455          JOY                   DESPAIR              MEH
# 2456          NaN                       JOY          DESPAIR
# 2457          JOY                       MEH          DESPAIR
# 2458          NaN                       NaN              NaN
# 2459          JOY                   DESPAIR              MEH
#
#      Q6 | Whole Wheat anything Q6 | York Peppermint Patties
# 1                      DESPAIR                      DESPAIR
# 3                      DESPAIR                      DESPAIR
# 4                      DESPAIR                          JOY
# 6                          NaN                          NaN
# 7                      DESPAIR                      DESPAIR
# ...                        ...                          ...
# 2455                   DESPAIR                          MEH
# 2456                       MEH                          JOY
# 2457                   DESPAIR                          MEH
# 2458                       NaN                          NaN
# 2459                   DESPAIR                          JOY
#
# [2248 rows x 103 columns]

# %%
for i in cd6:
     cd6[i].fillna('MEH',inplace=True)
cd6
# Out:
#      Q6 | 100 Grand Bar  \
# 1                   MEH
# 3                   MEH
# 4                   JOY
# 6                   MEH
# 7                   JOY
# ...                 ...
# 2455                JOY
# 2456                MEH
# 2457                MEH
# 2458                MEH
# 2459            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   MEH
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                MEH
# 2459                                            DESPAIR
#
#      Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 1                              JOY              MEH                  DESPAIR
# 3                              JOY              MEH                      MEH
# 4                              JOY          DESPAIR                      MEH
# 6                              MEH              MEH                      MEH
# 7                              JOY          DESPAIR                  DESPAIR
# ...                            ...              ...                      ...
# 2455                           MEH          DESPAIR                  DESPAIR
# 2456                           JOY              MEH                      MEH
# 2457                           JOY          DESPAIR                      MEH
# 2458                           MEH              MEH                      MEH
# 2459                           JOY          DESPAIR                  DESPAIR
#
#      Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 1                          DESPAIR          DESPAIR            DESPAIR
# 3                          DESPAIR              MEH            DESPAIR
# 4                          DESPAIR              MEH            DESPAIR
# 6                              MEH              MEH                MEH
# 7                              MEH              JOY                MEH
# ...                            ...              ...                ...
# 2455                           MEH              MEH            DESPAIR
# 2456                           MEH              MEH            DESPAIR
# 2457                           JOY          DESPAIR                MEH
# 2458                           MEH              MEH                MEH
# 2459                       DESPAIR          DESPAIR                MEH
#
#      Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 1                   DESPAIR           DESPAIR                     MEH
# 3                   DESPAIR               MEH                     MEH
# 4                   DESPAIR               MEH                     MEH
# 6                       MEH               MEH                     MEH
# 7                       JOY               JOY                     JOY
# ...                     ...               ...                     ...
# 2455                DESPAIR               MEH                 DESPAIR
# 2456                DESPAIR               JOY                     JOY
# 2457                    MEH           DESPAIR                     JOY
# 2458                    MEH               MEH                     MEH
# 2459                DESPAIR               JOY                     MEH
#
#      Q6 | Candy Corn  \
# 1                MEH
# 3            DESPAIR
# 4            DESPAIR
# 6                MEH
# 7                JOY
# ...              ...
# 2455         DESPAIR
# 2456             JOY
# 2457         DESPAIR
# 2458             MEH
# 2459             MEH
#
#      Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   MEH
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                                MEH
# 2458                                                MEH
# 2459                                            DESPAIR
#
#      Q6 | Caramellos Q6 | Cash, or other forms of legal tender  \
# 1                MEH                                       JOY
# 3                MEH                                       JOY
# 4                JOY                                       MEH
# 6                MEH                                       MEH
# 7                JOY                                       JOY
# ...              ...                                       ...
# 2455             JOY                                       JOY
# 2456             JOY                                       JOY
# 2457         DESPAIR                                       JOY
# 2458             MEH                                       MEH
# 2459             MEH                                       JOY
#
#      Q6 | Chardonnay Q6 | Chick-o-Sticks (we don’t know what that is)  \
# 1                MEH                                          DESPAIR
# 3                MEH                                              JOY
# 4                JOY                                          DESPAIR
# 6                MEH                                              MEH
# 7                JOY                                          DESPAIR
# ...              ...                                              ...
# 2455             JOY                                              MEH
# 2456             JOY                                              JOY
# 2457             JOY                                              MEH
# 2458             MEH                                              MEH
# 2459             JOY                                          DESPAIR
#
#      Q6 | Chiclets Q6 | Coffee Crisp  \
# 1          DESPAIR           DESPAIR
# 3              MEH           DESPAIR
# 4          DESPAIR               MEH
# 6              MEH               MEH
# 7              MEH               MEH
# ...            ...               ...
# 2455           JOY               JOY
# 2456       DESPAIR               MEH
# 2457           MEH           DESPAIR
# 2458           MEH               MEH
# 2459           MEH           DESPAIR
#
#      Q6 | Creepy Religious comics/Chick Tracts Q6 | Dental paraphenalia  \
# 1                                      DESPAIR                  DESPAIR
# 3                                      DESPAIR                  DESPAIR
# 4                                      DESPAIR                  DESPAIR
# 6                                          MEH                      MEH
# 7                                      DESPAIR                  DESPAIR
# ...                                        ...                      ...
# 2455                                   DESPAIR                      MEH
# 2456                                   DESPAIR                  DESPAIR
# 2457                                   DESPAIR                  DESPAIR
# 2458                                       MEH                      MEH
# 2459                                   DESPAIR                  DESPAIR
#
#      Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 1          MEH            JOY            DESPAIR
# 3          JOY            JOY                MEH
# 4          MEH            JOY            DESPAIR
# 6          MEH            MEH                MEH
# 7          MEH            MEH                JOY
# ...        ...            ...                ...
# 2455   DESPAIR            JOY                MEH
# 2456   DESPAIR            MEH                MEH
# 2457       MEH            JOY                MEH
# 2458       MEH            MEH                MEH
# 2459       JOY            JOY                MEH
#
#      Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 1                             DESPAIR          DESPAIR               DESPAIR
# 3                                 MEH              JOY                   JOY
# 4                             DESPAIR          DESPAIR                   MEH
# 6                                 MEH              MEH                   MEH
# 7                             DESPAIR          DESPAIR               DESPAIR
# ...                               ...              ...                   ...
# 2455                              JOY          DESPAIR                   JOY
# 2456                              MEH          DESPAIR                   MEH
# 2457                              JOY              JOY               DESPAIR
# 2458                              MEH              MEH                   MEH
# 2459                          DESPAIR              MEH               DESPAIR
#
#      Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 1                    MEH                      DESPAIR
# 3                    MEH                      DESPAIR
# 4                    MEH                      DESPAIR
# 6                    MEH                          MEH
# 7                DESPAIR                      DESPAIR
# ...                  ...                          ...
# 2455                 JOY                          JOY
# 2456             DESPAIR                      DESPAIR
# 2457             DESPAIR                      DESPAIR
# 2458                 MEH                          MEH
# 2459                 JOY                      DESPAIR
#
#      Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 1                             MEH             MEH            DESPAIR
# 3                             JOY             MEH                MEH
# 4                             JOY             MEH            DESPAIR
# 6                             MEH             MEH                MEH
# 7                             JOY         DESPAIR            DESPAIR
# ...                           ...             ...                ...
# 2455                          MEH         DESPAIR                MEH
# 2456                          MEH             MEH            DESPAIR
# 2457                          MEH             MEH            DESPAIR
# 2458                          MEH             MEH                MEH
# 2459                          MEH         DESPAIR            DESPAIR
#
#      Q6 | Heath Bar Q6 | Hershey's Dark Chocolate  \
# 1               MEH                           JOY
# 3           DESPAIR                           MEH
# 4           DESPAIR                           JOY
# 6               MEH                           MEH
# 7           DESPAIR                           JOY
# ...             ...                           ...
# 2455        DESPAIR                           JOY
# 2456            JOY                           MEH
# 2457            MEH                           JOY
# 2458            MEH                           MEH
# 2459        DESPAIR                           JOY
#
#      Q6 | Hershey’s Milk Chocolate Q6 | Hershey's Kisses  \
# 1                              JOY                   MEH
# 3                              MEH                   MEH
# 4                              MEH                   MEH
# 6                              MEH                   MEH
# 7                              MEH                   MEH
# ...                            ...                   ...
# 2455                           MEH                   MEH
# 2456                           JOY                   MEH
# 2457                           JOY                   JOY
# 2458                           MEH                   MEH
# 2459                           JOY                   JOY
#
#      Q6 | Hugs (actual physical hugs) Q6 | Jolly Rancher (bad flavor)  \
# 1                             DESPAIR                         DESPAIR
# 3                                 MEH                             MEH
# 4                             DESPAIR                             MEH
# 6                                 MEH                             MEH
# 7                             DESPAIR                         DESPAIR
# ...                               ...                             ...
# 2455                              JOY                             MEH
# 2456                          DESPAIR                             MEH
# 2457                              MEH                         DESPAIR
# 2458                              MEH                             MEH
# 2459                          DESPAIR                         DESPAIR
#
#      Q6 | Jolly Ranchers (good flavor) Q6 | JoyJoy (Mit Iodine!)  \
# 1                                  MEH                   DESPAIR
# 3                                  MEH                   DESPAIR
# 4                                  JOY                       MEH
# 6                                  MEH                       MEH
# 7                              DESPAIR                   DESPAIR
# ...                                ...                       ...
# 2455                               MEH                       MEH
# 2456                               JOY                       MEH
# 2457                               JOY                   DESPAIR
# 2458                               MEH                       MEH
# 2459                               MEH                   DESPAIR
#
#      Q6 | Junior Mints Q6 | Senior Mints Q6 | Kale smoothie  \
# 1              DESPAIR           DESPAIR            DESPAIR
# 3              DESPAIR           DESPAIR            DESPAIR
# 4                  JOY           DESPAIR            DESPAIR
# 6                  MEH               MEH                MEH
# 7              DESPAIR           DESPAIR            DESPAIR
# ...                ...               ...                ...
# 2455           DESPAIR           DESPAIR                MEH
# 2456               JOY               MEH            DESPAIR
# 2457               JOY               MEH            DESPAIR
# 2458               MEH               MEH                MEH
# 2459               JOY           DESPAIR            DESPAIR
#
#      Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy Q6 | LemonHeads  \
# 1                    DESPAIR          JOY         DESPAIR             MEH
# 3                        MEH          MEH             JOY             JOY
# 4                        JOY          JOY             JOY             JOY
# 6                        MEH          MEH             MEH             MEH
# 7                    DESPAIR          MEH             MEH             JOY
# ...                      ...          ...             ...             ...
# 2455                     JOY          JOY             MEH             MEH
# 2456                     MEH          JOY         DESPAIR         DESPAIR
# 2457                 DESPAIR      DESPAIR             JOY         DESPAIR
# 2458                     MEH          MEH             MEH             MEH
# 2459                 DESPAIR          MEH         DESPAIR         DESPAIR
#
#      Q6 | Licorice (not black) Q6 | Licorice (yes black) Q6 | Lindt Truffle  \
# 1                          MEH                       JOY                MEH
# 3                          MEH                       JOY                JOY
# 4                          MEH                   DESPAIR                JOY
# 6                          MEH                       MEH                MEH
# 7                          MEH                   DESPAIR            DESPAIR
# ...                        ...                       ...                ...
# 2455                       JOY                   DESPAIR                JOY
# 2456                       MEH                   DESPAIR                MEH
# 2457                       MEH                   DESPAIR                JOY
# 2458                       MEH                       MEH                MEH
# 2459                   DESPAIR                   DESPAIR                JOY
#
#      Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike Q6 | Milk Duds  \
# 1           DESPAIR   DESPAIR       DESPAIR               MEH            MEH
# 3           DESPAIR       JOY           MEH               MEH        DESPAIR
# 4               MEH       MEH       DESPAIR               MEH            MEH
# 6               MEH       MEH           MEH               MEH            MEH
# 7               MEH       JOY           JOY               JOY            JOY
# ...             ...       ...           ...               ...            ...
# 2455        DESPAIR       MEH           MEH               MEH            JOY
# 2456            MEH       MEH           MEH           DESPAIR            MEH
# 2457            MEH       JOY       DESPAIR               MEH            JOY
# 2458            MEH       MEH           MEH               MEH            MEH
# 2459        DESPAIR       JOY       DESPAIR               MEH        DESPAIR
#
#      Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s Q6 | Blue M&M's  \
# 1               JOY               JOY               MEH             JOY
# 3               JOY               MEH               JOY             MEH
# 4               JOY               JOY               JOY             JOY
# 6               MEH               MEH               MEH             MEH
# 7               JOY               JOY               JOY             JOY
# ...             ...               ...               ...             ...
# 2455            JOY               MEH               JOY             JOY
# 2456            MEH               JOY               JOY             MEH
# 2457            JOY               JOY           DESPAIR             JOY
# 2458            MEH               MEH               MEH             MEH
# 2459            JOY               JOY               JOY             JOY
#
#      Q6 | Red M&M's Q6 | Green Party M&M's Q6 | Independent M&M's  \
# 1               JOY                    JOY                    JOY
# 3               MEH                    MEH                    MEH
# 4               JOY                    JOY                    JOY
# 6               MEH                    MEH                    MEH
# 7               JOY                    JOY                    MEH
# ...             ...                    ...                    ...
# 2455            MEH                    JOY                    JOY
# 2456            MEH                    MEH                    MEH
# 2457            JOY                    JOY                    JOY
# 2458            MEH                    MEH                    MEH
# 2459            JOY                    JOY                DESPAIR
#
#      Q6 | Abstained from M&M'ing. Q6 | Minibags of chips Q6 | Mint Kisses  \
# 1                         DESPAIR                DESPAIR              MEH
# 3                             MEH                DESPAIR          DESPAIR
# 4                             MEH                DESPAIR              JOY
# 6                             MEH                    MEH              MEH
# 7                         DESPAIR                    JOY          DESPAIR
# ...                           ...                    ...              ...
# 2455                          MEH                    MEH              JOY
# 2456                          MEH                    MEH              JOY
# 2457                      DESPAIR                    JOY              JOY
# 2458                          MEH                    MEH              MEH
# 2459                      DESPAIR                    MEH              MEH
#
#      Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers Q6 | Nerds  \
# 1             DESPAIR          DESPAIR           DESPAIR    DESPAIR
# 3                 MEH              MEH           DESPAIR        MEH
# 4                 JOY              MEH           DESPAIR        JOY
# 6                 MEH              MEH               MEH        MEH
# 7             DESPAIR              MEH               MEH        JOY
# ...               ...              ...               ...        ...
# 2455              JOY              JOY               MEH        MEH
# 2456              MEH              JOY           DESPAIR        JOY
# 2457              JOY          DESPAIR           DESPAIR        MEH
# 2458              MEH              MEH               MEH        MEH
# 2459          DESPAIR              JOY               MEH    DESPAIR
#
#      Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 1                   JOY           DESPAIR    DESPAIR      DESPAIR
# 3                   MEH               MEH    DESPAIR      DESPAIR
# 4                   JOY               JOY        MEH      DESPAIR
# 6                   MEH               MEH        MEH          MEH
# 7                   JOY               MEH    DESPAIR      DESPAIR
# ...                 ...               ...        ...          ...
# 2455                JOY               JOY    DESPAIR      DESPAIR
# 2456                MEH               JOY    DESPAIR      DESPAIR
# 2457            DESPAIR               MEH        MEH          MEH
# 2458                MEH               MEH        MEH          MEH
# 2459                MEH           DESPAIR        MEH      DESPAIR
#
#      Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 1           DESPAIR                                            DESPAIR
# 3           DESPAIR                                            DESPAIR
# 4               JOY                                            DESPAIR
# 6               MEH                                                MEH
# 7           DESPAIR                                            DESPAIR
# ...             ...                                                ...
# 2455            JOY                                                MEH
# 2456            MEH                                            DESPAIR
# 2457            JOY                                                JOY
# 2458            MEH                                                MEH
# 2459        DESPAIR                                            DESPAIR
#
#      Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces  \
# 1                                JOY                 JOY
# 3                                JOY                 MEH
# 4                                JOY                 JOY
# 6                                MEH                 MEH
# 7                                JOY                 JOY
# ...                              ...                 ...
# 2455                             JOY                 JOY
# 2456                             JOY                 JOY
# 2457                             JOY                 MEH
# 2458                             MEH                 MEH
# 2459                             MEH             DESPAIR
#
#      Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 1                    DESPAIR        JOY
# 3                        MEH        MEH
# 4                        MEH        JOY
# 6                        MEH        MEH
# 7                        MEH        JOY
# ...                      ...        ...
# 2455                     JOY        JOY
# 2456                     MEH        MEH
# 2457                     MEH        JOY
# 2458                     MEH        MEH
# 2459                 DESPAIR    DESPAIR
#
#      Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 1                                               DESPAIR         DESPAIR
# 3                                               DESPAIR         DESPAIR
# 4                                                   MEH             JOY
# 6                                                   MEH             MEH
# 7                                               DESPAIR             JOY
# ...                                                 ...             ...
# 2455                                                JOY             MEH
# 2456                                            DESPAIR             JOY
# 2457                                            DESPAIR         DESPAIR
# 2458                                                MEH             MEH
# 2459                                            DESPAIR         DESPAIR
#
#      Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 1                     DESPAIR                      DESPAIR           MEH
# 3                     DESPAIR                          MEH           JOY
# 4                         JOY                      DESPAIR           MEH
# 6                         MEH                          MEH           MEH
# 7                         MEH                          JOY           MEH
# ...                       ...                          ...           ...
# 2455                  DESPAIR                      DESPAIR           JOY
# 2456                  DESPAIR                          MEH           JOY
# 2457                      JOY                          MEH       DESPAIR
# 2458                      MEH                          MEH           MEH
# 2459                      MEH                      DESPAIR           JOY
#
#      Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 1                                              DESPAIR           DESPAIR
# 3                                                  MEH           DESPAIR
# 4                                                  MEH           DESPAIR
# 6                                                  MEH               MEH
# 7                                                  JOY           DESPAIR
# ...                                                ...               ...
# 2455                                               JOY               JOY
# 2456                                               MEH               MEH
# 2457                                           DESPAIR           DESPAIR
# 2458                                               MEH               MEH
# 2459                                               JOY           DESPAIR
#
#      Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 1               MEH          DESPAIR               MEH
# 3               MEH              MEH               JOY
# 4               JOY              JOY               MEH
# 6               MEH              MEH               MEH
# 7               MEH              JOY               JOY
# ...             ...              ...               ...
# 2455            JOY              MEH               JOY
# 2456            MEH              MEH               MEH
# 2457        DESPAIR              JOY           DESPAIR
# 2458            MEH              MEH               MEH
# 2459            MEH              MEH           DESPAIR
#
#      Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 1                                 DESPAIR     DESPAIR       DESPAIR
# 3                                     MEH         JOY           MEH
# 4                                 DESPAIR         MEH       DESPAIR
# 6                                     MEH         MEH           MEH
# 7                                     MEH         MEH       DESPAIR
# ...                                   ...         ...           ...
# 2455                              DESPAIR         MEH           JOY
# 2456                                  MEH         JOY       DESPAIR
# 2457                              DESPAIR         MEH           MEH
# 2458                                  MEH         MEH           MEH
# 2459                              DESPAIR     DESPAIR       DESPAIR
#
#      Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 1                                            DESPAIR                   JOY
# 3                                            DESPAIR               DESPAIR
# 4                                            DESPAIR                   JOY
# 6                                                MEH                   MEH
# 7                                            DESPAIR                   JOY
# ...                                              ...                   ...
# 2455                                         DESPAIR                   MEH
# 2456                                         DESPAIR                   MEH
# 2457                                         DESPAIR                   JOY
# 2458                                             MEH                   MEH
# 2459                                         DESPAIR                   JOY
#
#      Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 1                                  JOY        DESPAIR       JOY
# 3                                  JOY            MEH       JOY
# 4                                  JOY        DESPAIR       JOY
# 6                                  MEH            MEH       MEH
# 7                                  MEH        DESPAIR       JOY
# ...                                ...            ...       ...
# 2455                               MEH            JOY       JOY
# 2456                               MEH        DESPAIR       JOY
# 2457                               JOY            MEH       MEH
# 2458                               MEH            MEH       MEH
# 2459                               MEH        DESPAIR   DESPAIR
#
#      Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                                   MEH
# 6                                                   MEH
# 7                                                   JOY
# ...                                                 ...
# 2455                                                MEH
# 2456                                                MEH
# 2457                                                MEH
# 2458                                                MEH
# 2459                                            DESPAIR
#
#      Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 1         DESPAIR                   DESPAIR          DESPAIR
# 3             JOY                       JOY          DESPAIR
# 4             JOY                       JOY          DESPAIR
# 6             MEH                       MEH              MEH
# 7             MEH                   DESPAIR          DESPAIR
# ...           ...                       ...              ...
# 2455          JOY                   DESPAIR              MEH
# 2456          MEH                       JOY          DESPAIR
# 2457          JOY                       MEH          DESPAIR
# 2458          MEH                       MEH              MEH
# 2459          JOY                   DESPAIR              MEH
#
#      Q6 | Whole Wheat anything Q6 | York Peppermint Patties
# 1                      DESPAIR                      DESPAIR
# 3                      DESPAIR                      DESPAIR
# 4                      DESPAIR                          JOY
# 6                          MEH                          MEH
# 7                      DESPAIR                      DESPAIR
# ...                        ...                          ...
# 2455                   DESPAIR                          MEH
# 2456                       MEH                          JOY
# 2457                   DESPAIR                          MEH
# 2458                       MEH                          MEH
# 2459                   DESPAIR                          JOY
#
# [2248 rows x 103 columns]

# %%
cd.loc[:,'Q6 | 100 Grand Bar':'Q6 | York Peppermint Patties']=cd6
# Out:
# C:\Users\Laptop Shop\anaconda3\lib\site-packages\pandas\core\indexing.py:1787: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER  Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male     44.0         USA
# 3        90272840             No       Male     40.0         USA
# 4        90272841             No       Male     23.0         USA
# 6        90272853             No       Male     53.0         USA
# 7        90272854             No       Male     33.0      CANADA
# ...           ...            ...        ...      ...         ...
# 2455     90314359             No       Male     24.0         USA
# 2456     90314580             No     Female     33.0         USA
# 2457     90314634             No     Female     26.0         USA
# 2458     90314658             No       Male     58.0         USA
# 2459     90314802             No     Female     66.0         USA
#
#      Q6 | 100 Grand Bar  \
# 1                   MEH
# 3                   MEH
# 4                   JOY
# 6                   MEH
# 7                   JOY
# ...                 ...
# 2455                JOY
# 2456                MEH
# 2457                MEH
# 2458                MEH
# 2459            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   MEH
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                MEH
# 2459                                            DESPAIR
#
#      Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 1                              JOY              MEH                  DESPAIR
# 3                              JOY              MEH                      MEH
# 4                              JOY          DESPAIR                      MEH
# 6                              MEH              MEH                      MEH
# 7                              JOY          DESPAIR                  DESPAIR
# ...                            ...              ...                      ...
# 2455                           MEH          DESPAIR                  DESPAIR
# 2456                           JOY              MEH                      MEH
# 2457                           JOY          DESPAIR                      MEH
# 2458                           MEH              MEH                      MEH
# 2459                           JOY          DESPAIR                  DESPAIR
#
#      Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 1                          DESPAIR          DESPAIR            DESPAIR
# 3                          DESPAIR              MEH            DESPAIR
# 4                          DESPAIR              MEH            DESPAIR
# 6                              MEH              MEH                MEH
# 7                              MEH              JOY                MEH
# ...                            ...              ...                ...
# 2455                           MEH              MEH            DESPAIR
# 2456                           MEH              MEH            DESPAIR
# 2457                           JOY          DESPAIR                MEH
# 2458                           MEH              MEH                MEH
# 2459                       DESPAIR          DESPAIR                MEH
#
#      Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 1                   DESPAIR           DESPAIR                     MEH
# 3                   DESPAIR               MEH                     MEH
# 4                   DESPAIR               MEH                     MEH
# 6                       MEH               MEH                     MEH
# 7                       JOY               JOY                     JOY
# ...                     ...               ...                     ...
# 2455                DESPAIR               MEH                 DESPAIR
# 2456                DESPAIR               JOY                     JOY
# 2457                    MEH           DESPAIR                     JOY
# 2458                    MEH               MEH                     MEH
# 2459                DESPAIR               JOY                     MEH
#
#      Q6 | Candy Corn  \
# 1                MEH
# 3            DESPAIR
# 4            DESPAIR
# 6                MEH
# 7                JOY
# ...              ...
# 2455         DESPAIR
# 2456             JOY
# 2457         DESPAIR
# 2458             MEH
# 2459             MEH
#
#      Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   MEH
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                                MEH
# 2458                                                MEH
# 2459                                            DESPAIR
#
#      Q6 | Caramellos Q6 | Cash, or other forms of legal tender  \
# 1                MEH                                       JOY
# 3                MEH                                       JOY
# 4                JOY                                       MEH
# 6                MEH                                       MEH
# 7                JOY                                       JOY
# ...              ...                                       ...
# 2455             JOY                                       JOY
# 2456             JOY                                       JOY
# 2457         DESPAIR                                       JOY
# 2458             MEH                                       MEH
# 2459             MEH                                       JOY
#
#      Q6 | Chardonnay Q6 | Chick-o-Sticks (we don’t know what that is)  \
# 1                MEH                                          DESPAIR
# 3                MEH                                              JOY
# 4                JOY                                          DESPAIR
# 6                MEH                                              MEH
# 7                JOY                                          DESPAIR
# ...              ...                                              ...
# 2455             JOY                                              MEH
# 2456             JOY                                              JOY
# 2457             JOY                                              MEH
# 2458             MEH                                              MEH
# 2459             JOY                                          DESPAIR
#
#      Q6 | Chiclets Q6 | Coffee Crisp  \
# 1          DESPAIR           DESPAIR
# 3              MEH           DESPAIR
# 4          DESPAIR               MEH
# 6              MEH               MEH
# 7              MEH               MEH
# ...            ...               ...
# 2455           JOY               JOY
# 2456       DESPAIR               MEH
# 2457           MEH           DESPAIR
# 2458           MEH               MEH
# 2459           MEH           DESPAIR
#
#      Q6 | Creepy Religious comics/Chick Tracts Q6 | Dental paraphenalia  \
# 1                                      DESPAIR                  DESPAIR
# 3                                      DESPAIR                  DESPAIR
# 4                                      DESPAIR                  DESPAIR
# 6                                          MEH                      MEH
# 7                                      DESPAIR                  DESPAIR
# ...                                        ...                      ...
# 2455                                   DESPAIR                      MEH
# 2456                                   DESPAIR                  DESPAIR
# 2457                                   DESPAIR                  DESPAIR
# 2458                                       MEH                      MEH
# 2459                                   DESPAIR                  DESPAIR
#
#      Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 1          MEH            JOY            DESPAIR
# 3          JOY            JOY                MEH
# 4          MEH            JOY            DESPAIR
# 6          MEH            MEH                MEH
# 7          MEH            MEH                JOY
# ...        ...            ...                ...
# 2455   DESPAIR            JOY                MEH
# 2456   DESPAIR            MEH                MEH
# 2457       MEH            JOY                MEH
# 2458       MEH            MEH                MEH
# 2459       JOY            JOY                MEH
#
#      Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 1                             DESPAIR          DESPAIR               DESPAIR
# 3                                 MEH              JOY                   JOY
# 4                             DESPAIR          DESPAIR                   MEH
# 6                                 MEH              MEH                   MEH
# 7                             DESPAIR          DESPAIR               DESPAIR
# ...                               ...              ...                   ...
# 2455                              JOY          DESPAIR                   JOY
# 2456                              MEH          DESPAIR                   MEH
# 2457                              JOY              JOY               DESPAIR
# 2458                              MEH              MEH                   MEH
# 2459                          DESPAIR              MEH               DESPAIR
#
#      Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 1                    MEH                      DESPAIR
# 3                    MEH                      DESPAIR
# 4                    MEH                      DESPAIR
# 6                    MEH                          MEH
# 7                DESPAIR                      DESPAIR
# ...                  ...                          ...
# 2455                 JOY                          JOY
# 2456             DESPAIR                      DESPAIR
# 2457             DESPAIR                      DESPAIR
# 2458                 MEH                          MEH
# 2459                 JOY                      DESPAIR
#
#      Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 1                             MEH             MEH            DESPAIR
# 3                             JOY             MEH                MEH
# 4                             JOY             MEH            DESPAIR
# 6                             MEH             MEH                MEH
# 7                             JOY         DESPAIR            DESPAIR
# ...                           ...             ...                ...
# 2455                          MEH         DESPAIR                MEH
# 2456                          MEH             MEH            DESPAIR
# 2457                          MEH             MEH            DESPAIR
# 2458                          MEH             MEH                MEH
# 2459                          MEH         DESPAIR            DESPAIR
#
#      Q6 | Heath Bar Q6 | Hershey's Dark Chocolate  \
# 1               MEH                           JOY
# 3           DESPAIR                           MEH
# 4           DESPAIR                           JOY
# 6               MEH                           MEH
# 7           DESPAIR                           JOY
# ...             ...                           ...
# 2455        DESPAIR                           JOY
# 2456            JOY                           MEH
# 2457            MEH                           JOY
# 2458            MEH                           MEH
# 2459        DESPAIR                           JOY
#
#      Q6 | Hershey’s Milk Chocolate Q6 | Hershey's Kisses  \
# 1                              JOY                   MEH
# 3                              MEH                   MEH
# 4                              MEH                   MEH
# 6                              MEH                   MEH
# 7                              MEH                   MEH
# ...                            ...                   ...
# 2455                           MEH                   MEH
# 2456                           JOY                   MEH
# 2457                           JOY                   JOY
# 2458                           MEH                   MEH
# 2459                           JOY                   JOY
#
#      Q6 | Hugs (actual physical hugs) Q6 | Jolly Rancher (bad flavor)  \
# 1                             DESPAIR                         DESPAIR
# 3                                 MEH                             MEH
# 4                             DESPAIR                             MEH
# 6                                 MEH                             MEH
# 7                             DESPAIR                         DESPAIR
# ...                               ...                             ...
# 2455                              JOY                             MEH
# 2456                          DESPAIR                             MEH
# 2457                              MEH                         DESPAIR
# 2458                              MEH                             MEH
# 2459                          DESPAIR                         DESPAIR
#
#      Q6 | Jolly Ranchers (good flavor) Q6 | JoyJoy (Mit Iodine!)  \
# 1                                  MEH                   DESPAIR
# 3                                  MEH                   DESPAIR
# 4                                  JOY                       MEH
# 6                                  MEH                       MEH
# 7                              DESPAIR                   DESPAIR
# ...                                ...                       ...
# 2455                               MEH                       MEH
# 2456                               JOY                       MEH
# 2457                               JOY                   DESPAIR
# 2458                               MEH                       MEH
# 2459                               MEH                   DESPAIR
#
#      Q6 | Junior Mints Q6 | Senior Mints Q6 | Kale smoothie  \
# 1              DESPAIR           DESPAIR            DESPAIR
# 3              DESPAIR           DESPAIR            DESPAIR
# 4                  JOY           DESPAIR            DESPAIR
# 6                  MEH               MEH                MEH
# 7              DESPAIR           DESPAIR            DESPAIR
# ...                ...               ...                ...
# 2455           DESPAIR           DESPAIR                MEH
# 2456               JOY               MEH            DESPAIR
# 2457               JOY               MEH            DESPAIR
# 2458               MEH               MEH                MEH
# 2459               JOY           DESPAIR            DESPAIR
#
#      Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy Q6 | LemonHeads  \
# 1                    DESPAIR          JOY         DESPAIR             MEH
# 3                        MEH          MEH             JOY             JOY
# 4                        JOY          JOY             JOY             JOY
# 6                        MEH          MEH             MEH             MEH
# 7                    DESPAIR          MEH             MEH             JOY
# ...                      ...          ...             ...             ...
# 2455                     JOY          JOY             MEH             MEH
# 2456                     MEH          JOY         DESPAIR         DESPAIR
# 2457                 DESPAIR      DESPAIR             JOY         DESPAIR
# 2458                     MEH          MEH             MEH             MEH
# 2459                 DESPAIR          MEH         DESPAIR         DESPAIR
#
#      Q6 | Licorice (not black) Q6 | Licorice (yes black) Q6 | Lindt Truffle  \
# 1                          MEH                       JOY                MEH
# 3                          MEH                       JOY                JOY
# 4                          MEH                   DESPAIR                JOY
# 6                          MEH                       MEH                MEH
# 7                          MEH                   DESPAIR            DESPAIR
# ...                        ...                       ...                ...
# 2455                       JOY                   DESPAIR                JOY
# 2456                       MEH                   DESPAIR                MEH
# 2457                       MEH                   DESPAIR                JOY
# 2458                       MEH                       MEH                MEH
# 2459                   DESPAIR                   DESPAIR                JOY
#
#      Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike Q6 | Milk Duds  \
# 1           DESPAIR   DESPAIR       DESPAIR               MEH            MEH
# 3           DESPAIR       JOY           MEH               MEH        DESPAIR
# 4               MEH       MEH       DESPAIR               MEH            MEH
# 6               MEH       MEH           MEH               MEH            MEH
# 7               MEH       JOY           JOY               JOY            JOY
# ...             ...       ...           ...               ...            ...
# 2455        DESPAIR       MEH           MEH               MEH            JOY
# 2456            MEH       MEH           MEH           DESPAIR            MEH
# 2457            MEH       JOY       DESPAIR               MEH            JOY
# 2458            MEH       MEH           MEH               MEH            MEH
# 2459        DESPAIR       JOY       DESPAIR               MEH        DESPAIR
#
#      Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s Q6 | Blue M&M's  \
# 1               JOY               JOY               MEH             JOY
# 3               JOY               MEH               JOY             MEH
# 4               JOY               JOY               JOY             JOY
# 6               MEH               MEH               MEH             MEH
# 7               JOY               JOY               JOY             JOY
# ...             ...               ...               ...             ...
# 2455            JOY               MEH               JOY             JOY
# 2456            MEH               JOY               JOY             MEH
# 2457            JOY               JOY           DESPAIR             JOY
# 2458            MEH               MEH               MEH             MEH
# 2459            JOY               JOY               JOY             JOY
#
#      Q6 | Red M&M's Q6 | Green Party M&M's Q6 | Independent M&M's  \
# 1               JOY                    JOY                    JOY
# 3               MEH                    MEH                    MEH
# 4               JOY                    JOY                    JOY
# 6               MEH                    MEH                    MEH
# 7               JOY                    JOY                    MEH
# ...             ...                    ...                    ...
# 2455            MEH                    JOY                    JOY
# 2456            MEH                    MEH                    MEH
# 2457            JOY                    JOY                    JOY
# 2458            MEH                    MEH                    MEH
# 2459            JOY                    JOY                DESPAIR
#
#      Q6 | Abstained from M&M'ing. Q6 | Minibags of chips Q6 | Mint Kisses  \
# 1                         DESPAIR                DESPAIR              MEH
# 3                             MEH                DESPAIR          DESPAIR
# 4                             MEH                DESPAIR              JOY
# 6                             MEH                    MEH              MEH
# 7                         DESPAIR                    JOY          DESPAIR
# ...                           ...                    ...              ...
# 2455                          MEH                    MEH              JOY
# 2456                          MEH                    MEH              JOY
# 2457                      DESPAIR                    JOY              JOY
# 2458                          MEH                    MEH              MEH
# 2459                      DESPAIR                    MEH              MEH
#
#      Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers Q6 | Nerds  \
# 1             DESPAIR          DESPAIR           DESPAIR    DESPAIR
# 3                 MEH              MEH           DESPAIR        MEH
# 4                 JOY              MEH           DESPAIR        JOY
# 6                 MEH              MEH               MEH        MEH
# 7             DESPAIR              MEH               MEH        JOY
# ...               ...              ...               ...        ...
# 2455              JOY              JOY               MEH        MEH
# 2456              MEH              JOY           DESPAIR        JOY
# 2457              JOY          DESPAIR           DESPAIR        MEH
# 2458              MEH              MEH               MEH        MEH
# 2459          DESPAIR              JOY               MEH    DESPAIR
#
#      Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 1                   JOY           DESPAIR    DESPAIR      DESPAIR
# 3                   MEH               MEH    DESPAIR      DESPAIR
# 4                   JOY               JOY        MEH      DESPAIR
# 6                   MEH               MEH        MEH          MEH
# 7                   JOY               MEH    DESPAIR      DESPAIR
# ...                 ...               ...        ...          ...
# 2455                JOY               JOY    DESPAIR      DESPAIR
# 2456                MEH               JOY    DESPAIR      DESPAIR
# 2457            DESPAIR               MEH        MEH          MEH
# 2458                MEH               MEH        MEH          MEH
# 2459                MEH           DESPAIR        MEH      DESPAIR
#
#      Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 1           DESPAIR                                            DESPAIR
# 3           DESPAIR                                            DESPAIR
# 4               JOY                                            DESPAIR
# 6               MEH                                                MEH
# 7           DESPAIR                                            DESPAIR
# ...             ...                                                ...
# 2455            JOY                                                MEH
# 2456            MEH                                            DESPAIR
# 2457            JOY                                                JOY
# 2458            MEH                                                MEH
# 2459        DESPAIR                                            DESPAIR
#
#      Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces  \
# 1                                JOY                 JOY
# 3                                JOY                 MEH
# 4                                JOY                 JOY
# 6                                MEH                 MEH
# 7                                JOY                 JOY
# ...                              ...                 ...
# 2455                             JOY                 JOY
# 2456                             JOY                 JOY
# 2457                             JOY                 MEH
# 2458                             MEH                 MEH
# 2459                             MEH             DESPAIR
#
#      Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 1                    DESPAIR        JOY
# 3                        MEH        MEH
# 4                        MEH        JOY
# 6                        MEH        MEH
# 7                        MEH        JOY
# ...                      ...        ...
# 2455                     JOY        JOY
# 2456                     MEH        MEH
# 2457                     MEH        JOY
# 2458                     MEH        MEH
# 2459                 DESPAIR    DESPAIR
#
#      Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 1                                               DESPAIR         DESPAIR
# 3                                               DESPAIR         DESPAIR
# 4                                                   MEH             JOY
# 6                                                   MEH             MEH
# 7                                               DESPAIR             JOY
# ...                                                 ...             ...
# 2455                                                JOY             MEH
# 2456                                            DESPAIR             JOY
# 2457                                            DESPAIR         DESPAIR
# 2458                                                MEH             MEH
# 2459                                            DESPAIR         DESPAIR
#
#      Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 1                     DESPAIR                      DESPAIR           MEH
# 3                     DESPAIR                          MEH           JOY
# 4                         JOY                      DESPAIR           MEH
# 6                         MEH                          MEH           MEH
# 7                         MEH                          JOY           MEH
# ...                       ...                          ...           ...
# 2455                  DESPAIR                      DESPAIR           JOY
# 2456                  DESPAIR                          MEH           JOY
# 2457                      JOY                          MEH       DESPAIR
# 2458                      MEH                          MEH           MEH
# 2459                      MEH                      DESPAIR           JOY
#
#      Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 1                                              DESPAIR           DESPAIR
# 3                                                  MEH           DESPAIR
# 4                                                  MEH           DESPAIR
# 6                                                  MEH               MEH
# 7                                                  JOY           DESPAIR
# ...                                                ...               ...
# 2455                                               JOY               JOY
# 2456                                               MEH               MEH
# 2457                                           DESPAIR           DESPAIR
# 2458                                               MEH               MEH
# 2459                                               JOY           DESPAIR
#
#      Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 1               MEH          DESPAIR               MEH
# 3               MEH              MEH               JOY
# 4               JOY              JOY               MEH
# 6               MEH              MEH               MEH
# 7               MEH              JOY               JOY
# ...             ...              ...               ...
# 2455            JOY              MEH               JOY
# 2456            MEH              MEH               MEH
# 2457        DESPAIR              JOY           DESPAIR
# 2458            MEH              MEH               MEH
# 2459            MEH              MEH           DESPAIR
#
#      Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 1                                 DESPAIR     DESPAIR       DESPAIR
# 3                                     MEH         JOY           MEH
# 4                                 DESPAIR         MEH       DESPAIR
# 6                                     MEH         MEH           MEH
# 7                                     MEH         MEH       DESPAIR
# ...                                   ...         ...           ...
# 2455                              DESPAIR         MEH           JOY
# 2456                                  MEH         JOY       DESPAIR
# 2457                              DESPAIR         MEH           MEH
# 2458                                  MEH         MEH           MEH
# 2459                              DESPAIR     DESPAIR       DESPAIR
#
#      Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 1                                            DESPAIR                   JOY
# 3                                            DESPAIR               DESPAIR
# 4                                            DESPAIR                   JOY
# 6                                                MEH                   MEH
# 7                                            DESPAIR                   JOY
# ...                                              ...                   ...
# 2455                                         DESPAIR                   MEH
# 2456                                         DESPAIR                   MEH
# 2457                                         DESPAIR                   JOY
# 2458                                             MEH                   MEH
# 2459                                         DESPAIR                   JOY
#
#      Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 1                                  JOY        DESPAIR       JOY
# 3                                  JOY            MEH       JOY
# 4                                  JOY        DESPAIR       JOY
# 6                                  MEH            MEH       MEH
# 7                                  MEH        DESPAIR       JOY
# ...                                ...            ...       ...
# 2455                               MEH            JOY       JOY
# 2456                               MEH        DESPAIR       JOY
# 2457                               JOY            MEH       MEH
# 2458                               MEH            MEH       MEH
# 2459                               MEH        DESPAIR   DESPAIR
#
#      Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                                   MEH
# 6                                                   MEH
# 7                                                   JOY
# ...                                                 ...
# 2455                                                MEH
# 2456                                                MEH
# 2457                                                MEH
# 2458                                                MEH
# 2459                                            DESPAIR
#
#      Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 1         DESPAIR                   DESPAIR          DESPAIR
# 3             JOY                       JOY          DESPAIR
# 4             JOY                       JOY          DESPAIR
# 6             MEH                       MEH              MEH
# 7             MEH                   DESPAIR          DESPAIR
# ...           ...                       ...              ...
# 2455          JOY                   DESPAIR              MEH
# 2456          MEH                       JOY          DESPAIR
# 2457          JOY                       MEH          DESPAIR
# 2458          MEH                       MEH              MEH
# 2459          JOY                   DESPAIR              MEH
#
#      Q6 | Whole Wheat anything Q6 | York Peppermint Patties      Q10: DRESS  \
# 1                      DESPAIR                      DESPAIR  White and gold
# 3                      DESPAIR                      DESPAIR  White and gold
# 4                      DESPAIR                          JOY  White and gold
# 6                          MEH                          MEH              41
# 7                      DESPAIR                      DESPAIR  Blue and black
# ...                        ...                          ...             ...
# 2455                   DESPAIR                          MEH  White and gold
# 2456                       MEH                          JOY  Blue and black
# 2457                   DESPAIR                          MEH  Blue and black
# 2458                       MEH                          MEH              41
# 2459                   DESPAIR                          JOY  White and gold
#
#      Q11: DAY  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# 1      Sunday                     41.0                   1.0
# 3      Sunday                     41.0                   1.0
# 4      Friday                     41.0                   1.0
# 6          41                     41.0                  41.0
# 7      Friday                     41.0                   1.0
# ...       ...                      ...                   ...
# 2455   Friday                     41.0                  41.0
# 2456   Friday                     41.0                   1.0
# 2457   Friday                     41.0                   1.0
# 2458       41                     41.0                  41.0
# 2459   Sunday                      1.0                  41.0
#
#       Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 1                  41.0                41.0                 (84, 25)
# 3                  41.0                41.0                 (75, 23)
# 4                  41.0                41.0                 (70, 10)
# 6                  41.0                41.0                       41
# 7                  41.0                41.0                  (55, 5)
# ...                 ...                 ...                      ...
# 2455               41.0                41.0                       41
# 2456               41.0                41.0                 (70, 26)
# 2457               41.0                41.0                 (67, 35)
# 2458               41.0                41.0                       41
# 2459               41.0                41.0                 (19, 26)
#
# [2248 rows x 115 columns]

# %%
cd.loc[:,'Q10: DRESS']=cd.loc[:,'Q10: DRESS'].str.strip()
cd['Q10: DRESS'].fillna(cd['Q10: DRESS'].mode()[0],inplace=True)
# Out:
# C:\Users\Laptop Shop\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# C:\Users\Laptop Shop\anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
cd.loc[:,'Q11: DAY']=cd.loc[:,'Q11: DAY'].str.strip()
cd['Q11: DAY'].fillna(cd['Q11: DAY'].mode()[0],inplace=True)

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER  Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male     44.0         USA
# 3        90272840             No       Male     40.0         USA
# 4        90272841             No       Male     23.0         USA
# 6        90272853             No       Male     53.0         USA
# 7        90272854             No       Male     33.0      CANADA
# ...           ...            ...        ...      ...         ...
# 2455     90314359             No       Male     24.0         USA
# 2456     90314580             No     Female     33.0         USA
# 2457     90314634             No     Female     26.0         USA
# 2458     90314658             No       Male     58.0         USA
# 2459     90314802             No     Female     66.0         USA
#
#      Q6 | 100 Grand Bar  \
# 1                   MEH
# 3                   MEH
# 4                   JOY
# 6                   MEH
# 7                   JOY
# ...                 ...
# 2455                JOY
# 2456                MEH
# 2457                MEH
# 2458                MEH
# 2459            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   MEH
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                MEH
# 2459                                            DESPAIR
#
#      Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 1                              JOY              MEH                  DESPAIR
# 3                              JOY              MEH                      MEH
# 4                              JOY          DESPAIR                      MEH
# 6                              MEH              MEH                      MEH
# 7                              JOY          DESPAIR                  DESPAIR
# ...                            ...              ...                      ...
# 2455                           MEH          DESPAIR                  DESPAIR
# 2456                           JOY              MEH                      MEH
# 2457                           JOY          DESPAIR                      MEH
# 2458                           MEH              MEH                      MEH
# 2459                           JOY          DESPAIR                  DESPAIR
#
#      Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 1                          DESPAIR          DESPAIR            DESPAIR
# 3                          DESPAIR              MEH            DESPAIR
# 4                          DESPAIR              MEH            DESPAIR
# 6                              MEH              MEH                MEH
# 7                              MEH              JOY                MEH
# ...                            ...              ...                ...
# 2455                           MEH              MEH            DESPAIR
# 2456                           MEH              MEH            DESPAIR
# 2457                           JOY          DESPAIR                MEH
# 2458                           MEH              MEH                MEH
# 2459                       DESPAIR          DESPAIR                MEH
#
#      Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 1                   DESPAIR           DESPAIR                     MEH
# 3                   DESPAIR               MEH                     MEH
# 4                   DESPAIR               MEH                     MEH
# 6                       MEH               MEH                     MEH
# 7                       JOY               JOY                     JOY
# ...                     ...               ...                     ...
# 2455                DESPAIR               MEH                 DESPAIR
# 2456                DESPAIR               JOY                     JOY
# 2457                    MEH           DESPAIR                     JOY
# 2458                    MEH               MEH                     MEH
# 2459                DESPAIR               JOY                     MEH
#
#      Q6 | Candy Corn  \
# 1                MEH
# 3            DESPAIR
# 4            DESPAIR
# 6                MEH
# 7                JOY
# ...              ...
# 2455         DESPAIR
# 2456             JOY
# 2457         DESPAIR
# 2458             MEH
# 2459             MEH
#
#      Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   MEH
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                                MEH
# 2458                                                MEH
# 2459                                            DESPAIR
#
#      Q6 | Caramellos Q6 | Cash, or other forms of legal tender  \
# 1                MEH                                       JOY
# 3                MEH                                       JOY
# 4                JOY                                       MEH
# 6                MEH                                       MEH
# 7                JOY                                       JOY
# ...              ...                                       ...
# 2455             JOY                                       JOY
# 2456             JOY                                       JOY
# 2457         DESPAIR                                       JOY
# 2458             MEH                                       MEH
# 2459             MEH                                       JOY
#
#      Q6 | Chardonnay Q6 | Chick-o-Sticks (we don’t know what that is)  \
# 1                MEH                                          DESPAIR
# 3                MEH                                              JOY
# 4                JOY                                          DESPAIR
# 6                MEH                                              MEH
# 7                JOY                                          DESPAIR
# ...              ...                                              ...
# 2455             JOY                                              MEH
# 2456             JOY                                              JOY
# 2457             JOY                                              MEH
# 2458             MEH                                              MEH
# 2459             JOY                                          DESPAIR
#
#      Q6 | Chiclets Q6 | Coffee Crisp  \
# 1          DESPAIR           DESPAIR
# 3              MEH           DESPAIR
# 4          DESPAIR               MEH
# 6              MEH               MEH
# 7              MEH               MEH
# ...            ...               ...
# 2455           JOY               JOY
# 2456       DESPAIR               MEH
# 2457           MEH           DESPAIR
# 2458           MEH               MEH
# 2459           MEH           DESPAIR
#
#      Q6 | Creepy Religious comics/Chick Tracts Q6 | Dental paraphenalia  \
# 1                                      DESPAIR                  DESPAIR
# 3                                      DESPAIR                  DESPAIR
# 4                                      DESPAIR                  DESPAIR
# 6                                          MEH                      MEH
# 7                                      DESPAIR                  DESPAIR
# ...                                        ...                      ...
# 2455                                   DESPAIR                      MEH
# 2456                                   DESPAIR                  DESPAIR
# 2457                                   DESPAIR                  DESPAIR
# 2458                                       MEH                      MEH
# 2459                                   DESPAIR                  DESPAIR
#
#      Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 1          MEH            JOY            DESPAIR
# 3          JOY            JOY                MEH
# 4          MEH            JOY            DESPAIR
# 6          MEH            MEH                MEH
# 7          MEH            MEH                JOY
# ...        ...            ...                ...
# 2455   DESPAIR            JOY                MEH
# 2456   DESPAIR            MEH                MEH
# 2457       MEH            JOY                MEH
# 2458       MEH            MEH                MEH
# 2459       JOY            JOY                MEH
#
#      Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 1                             DESPAIR          DESPAIR               DESPAIR
# 3                                 MEH              JOY                   JOY
# 4                             DESPAIR          DESPAIR                   MEH
# 6                                 MEH              MEH                   MEH
# 7                             DESPAIR          DESPAIR               DESPAIR
# ...                               ...              ...                   ...
# 2455                              JOY          DESPAIR                   JOY
# 2456                              MEH          DESPAIR                   MEH
# 2457                              JOY              JOY               DESPAIR
# 2458                              MEH              MEH                   MEH
# 2459                          DESPAIR              MEH               DESPAIR
#
#      Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 1                    MEH                      DESPAIR
# 3                    MEH                      DESPAIR
# 4                    MEH                      DESPAIR
# 6                    MEH                          MEH
# 7                DESPAIR                      DESPAIR
# ...                  ...                          ...
# 2455                 JOY                          JOY
# 2456             DESPAIR                      DESPAIR
# 2457             DESPAIR                      DESPAIR
# 2458                 MEH                          MEH
# 2459                 JOY                      DESPAIR
#
#      Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 1                             MEH             MEH            DESPAIR
# 3                             JOY             MEH                MEH
# 4                             JOY             MEH            DESPAIR
# 6                             MEH             MEH                MEH
# 7                             JOY         DESPAIR            DESPAIR
# ...                           ...             ...                ...
# 2455                          MEH         DESPAIR                MEH
# 2456                          MEH             MEH            DESPAIR
# 2457                          MEH             MEH            DESPAIR
# 2458                          MEH             MEH                MEH
# 2459                          MEH         DESPAIR            DESPAIR
#
#      Q6 | Heath Bar Q6 | Hershey's Dark Chocolate  \
# 1               MEH                           JOY
# 3           DESPAIR                           MEH
# 4           DESPAIR                           JOY
# 6               MEH                           MEH
# 7           DESPAIR                           JOY
# ...             ...                           ...
# 2455        DESPAIR                           JOY
# 2456            JOY                           MEH
# 2457            MEH                           JOY
# 2458            MEH                           MEH
# 2459        DESPAIR                           JOY
#
#      Q6 | Hershey’s Milk Chocolate Q6 | Hershey's Kisses  \
# 1                              JOY                   MEH
# 3                              MEH                   MEH
# 4                              MEH                   MEH
# 6                              MEH                   MEH
# 7                              MEH                   MEH
# ...                            ...                   ...
# 2455                           MEH                   MEH
# 2456                           JOY                   MEH
# 2457                           JOY                   JOY
# 2458                           MEH                   MEH
# 2459                           JOY                   JOY
#
#      Q6 | Hugs (actual physical hugs) Q6 | Jolly Rancher (bad flavor)  \
# 1                             DESPAIR                         DESPAIR
# 3                                 MEH                             MEH
# 4                             DESPAIR                             MEH
# 6                                 MEH                             MEH
# 7                             DESPAIR                         DESPAIR
# ...                               ...                             ...
# 2455                              JOY                             MEH
# 2456                          DESPAIR                             MEH
# 2457                              MEH                         DESPAIR
# 2458                              MEH                             MEH
# 2459                          DESPAIR                         DESPAIR
#
#      Q6 | Jolly Ranchers (good flavor) Q6 | JoyJoy (Mit Iodine!)  \
# 1                                  MEH                   DESPAIR
# 3                                  MEH                   DESPAIR
# 4                                  JOY                       MEH
# 6                                  MEH                       MEH
# 7                              DESPAIR                   DESPAIR
# ...                                ...                       ...
# 2455                               MEH                       MEH
# 2456                               JOY                       MEH
# 2457                               JOY                   DESPAIR
# 2458                               MEH                       MEH
# 2459                               MEH                   DESPAIR
#
#      Q6 | Junior Mints Q6 | Senior Mints Q6 | Kale smoothie  \
# 1              DESPAIR           DESPAIR            DESPAIR
# 3              DESPAIR           DESPAIR            DESPAIR
# 4                  JOY           DESPAIR            DESPAIR
# 6                  MEH               MEH                MEH
# 7              DESPAIR           DESPAIR            DESPAIR
# ...                ...               ...                ...
# 2455           DESPAIR           DESPAIR                MEH
# 2456               JOY               MEH            DESPAIR
# 2457               JOY               MEH            DESPAIR
# 2458               MEH               MEH                MEH
# 2459               JOY           DESPAIR            DESPAIR
#
#      Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy Q6 | LemonHeads  \
# 1                    DESPAIR          JOY         DESPAIR             MEH
# 3                        MEH          MEH             JOY             JOY
# 4                        JOY          JOY             JOY             JOY
# 6                        MEH          MEH             MEH             MEH
# 7                    DESPAIR          MEH             MEH             JOY
# ...                      ...          ...             ...             ...
# 2455                     JOY          JOY             MEH             MEH
# 2456                     MEH          JOY         DESPAIR         DESPAIR
# 2457                 DESPAIR      DESPAIR             JOY         DESPAIR
# 2458                     MEH          MEH             MEH             MEH
# 2459                 DESPAIR          MEH         DESPAIR         DESPAIR
#
#      Q6 | Licorice (not black) Q6 | Licorice (yes black) Q6 | Lindt Truffle  \
# 1                          MEH                       JOY                MEH
# 3                          MEH                       JOY                JOY
# 4                          MEH                   DESPAIR                JOY
# 6                          MEH                       MEH                MEH
# 7                          MEH                   DESPAIR            DESPAIR
# ...                        ...                       ...                ...
# 2455                       JOY                   DESPAIR                JOY
# 2456                       MEH                   DESPAIR                MEH
# 2457                       MEH                   DESPAIR                JOY
# 2458                       MEH                       MEH                MEH
# 2459                   DESPAIR                   DESPAIR                JOY
#
#      Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike Q6 | Milk Duds  \
# 1           DESPAIR   DESPAIR       DESPAIR               MEH            MEH
# 3           DESPAIR       JOY           MEH               MEH        DESPAIR
# 4               MEH       MEH       DESPAIR               MEH            MEH
# 6               MEH       MEH           MEH               MEH            MEH
# 7               MEH       JOY           JOY               JOY            JOY
# ...             ...       ...           ...               ...            ...
# 2455        DESPAIR       MEH           MEH               MEH            JOY
# 2456            MEH       MEH           MEH           DESPAIR            MEH
# 2457            MEH       JOY       DESPAIR               MEH            JOY
# 2458            MEH       MEH           MEH               MEH            MEH
# 2459        DESPAIR       JOY       DESPAIR               MEH        DESPAIR
#
#      Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s Q6 | Blue M&M's  \
# 1               JOY               JOY               MEH             JOY
# 3               JOY               MEH               JOY             MEH
# 4               JOY               JOY               JOY             JOY
# 6               MEH               MEH               MEH             MEH
# 7               JOY               JOY               JOY             JOY
# ...             ...               ...               ...             ...
# 2455            JOY               MEH               JOY             JOY
# 2456            MEH               JOY               JOY             MEH
# 2457            JOY               JOY           DESPAIR             JOY
# 2458            MEH               MEH               MEH             MEH
# 2459            JOY               JOY               JOY             JOY
#
#      Q6 | Red M&M's Q6 | Green Party M&M's Q6 | Independent M&M's  \
# 1               JOY                    JOY                    JOY
# 3               MEH                    MEH                    MEH
# 4               JOY                    JOY                    JOY
# 6               MEH                    MEH                    MEH
# 7               JOY                    JOY                    MEH
# ...             ...                    ...                    ...
# 2455            MEH                    JOY                    JOY
# 2456            MEH                    MEH                    MEH
# 2457            JOY                    JOY                    JOY
# 2458            MEH                    MEH                    MEH
# 2459            JOY                    JOY                DESPAIR
#
#      Q6 | Abstained from M&M'ing. Q6 | Minibags of chips Q6 | Mint Kisses  \
# 1                         DESPAIR                DESPAIR              MEH
# 3                             MEH                DESPAIR          DESPAIR
# 4                             MEH                DESPAIR              JOY
# 6                             MEH                    MEH              MEH
# 7                         DESPAIR                    JOY          DESPAIR
# ...                           ...                    ...              ...
# 2455                          MEH                    MEH              JOY
# 2456                          MEH                    MEH              JOY
# 2457                      DESPAIR                    JOY              JOY
# 2458                          MEH                    MEH              MEH
# 2459                      DESPAIR                    MEH              MEH
#
#      Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers Q6 | Nerds  \
# 1             DESPAIR          DESPAIR           DESPAIR    DESPAIR
# 3                 MEH              MEH           DESPAIR        MEH
# 4                 JOY              MEH           DESPAIR        JOY
# 6                 MEH              MEH               MEH        MEH
# 7             DESPAIR              MEH               MEH        JOY
# ...               ...              ...               ...        ...
# 2455              JOY              JOY               MEH        MEH
# 2456              MEH              JOY           DESPAIR        JOY
# 2457              JOY          DESPAIR           DESPAIR        MEH
# 2458              MEH              MEH               MEH        MEH
# 2459          DESPAIR              JOY               MEH    DESPAIR
#
#      Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 1                   JOY           DESPAIR    DESPAIR      DESPAIR
# 3                   MEH               MEH    DESPAIR      DESPAIR
# 4                   JOY               JOY        MEH      DESPAIR
# 6                   MEH               MEH        MEH          MEH
# 7                   JOY               MEH    DESPAIR      DESPAIR
# ...                 ...               ...        ...          ...
# 2455                JOY               JOY    DESPAIR      DESPAIR
# 2456                MEH               JOY    DESPAIR      DESPAIR
# 2457            DESPAIR               MEH        MEH          MEH
# 2458                MEH               MEH        MEH          MEH
# 2459                MEH           DESPAIR        MEH      DESPAIR
#
#      Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 1           DESPAIR                                            DESPAIR
# 3           DESPAIR                                            DESPAIR
# 4               JOY                                            DESPAIR
# 6               MEH                                                MEH
# 7           DESPAIR                                            DESPAIR
# ...             ...                                                ...
# 2455            JOY                                                MEH
# 2456            MEH                                            DESPAIR
# 2457            JOY                                                JOY
# 2458            MEH                                                MEH
# 2459        DESPAIR                                            DESPAIR
#
#      Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces  \
# 1                                JOY                 JOY
# 3                                JOY                 MEH
# 4                                JOY                 JOY
# 6                                MEH                 MEH
# 7                                JOY                 JOY
# ...                              ...                 ...
# 2455                             JOY                 JOY
# 2456                             JOY                 JOY
# 2457                             JOY                 MEH
# 2458                             MEH                 MEH
# 2459                             MEH             DESPAIR
#
#      Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 1                    DESPAIR        JOY
# 3                        MEH        MEH
# 4                        MEH        JOY
# 6                        MEH        MEH
# 7                        MEH        JOY
# ...                      ...        ...
# 2455                     JOY        JOY
# 2456                     MEH        MEH
# 2457                     MEH        JOY
# 2458                     MEH        MEH
# 2459                 DESPAIR    DESPAIR
#
#      Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 1                                               DESPAIR         DESPAIR
# 3                                               DESPAIR         DESPAIR
# 4                                                   MEH             JOY
# 6                                                   MEH             MEH
# 7                                               DESPAIR             JOY
# ...                                                 ...             ...
# 2455                                                JOY             MEH
# 2456                                            DESPAIR             JOY
# 2457                                            DESPAIR         DESPAIR
# 2458                                                MEH             MEH
# 2459                                            DESPAIR         DESPAIR
#
#      Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 1                     DESPAIR                      DESPAIR           MEH
# 3                     DESPAIR                          MEH           JOY
# 4                         JOY                      DESPAIR           MEH
# 6                         MEH                          MEH           MEH
# 7                         MEH                          JOY           MEH
# ...                       ...                          ...           ...
# 2455                  DESPAIR                      DESPAIR           JOY
# 2456                  DESPAIR                          MEH           JOY
# 2457                      JOY                          MEH       DESPAIR
# 2458                      MEH                          MEH           MEH
# 2459                      MEH                      DESPAIR           JOY
#
#      Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 1                                              DESPAIR           DESPAIR
# 3                                                  MEH           DESPAIR
# 4                                                  MEH           DESPAIR
# 6                                                  MEH               MEH
# 7                                                  JOY           DESPAIR
# ...                                                ...               ...
# 2455                                               JOY               JOY
# 2456                                               MEH               MEH
# 2457                                           DESPAIR           DESPAIR
# 2458                                               MEH               MEH
# 2459                                               JOY           DESPAIR
#
#      Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 1               MEH          DESPAIR               MEH
# 3               MEH              MEH               JOY
# 4               JOY              JOY               MEH
# 6               MEH              MEH               MEH
# 7               MEH              JOY               JOY
# ...             ...              ...               ...
# 2455            JOY              MEH               JOY
# 2456            MEH              MEH               MEH
# 2457        DESPAIR              JOY           DESPAIR
# 2458            MEH              MEH               MEH
# 2459            MEH              MEH           DESPAIR
#
#      Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 1                                 DESPAIR     DESPAIR       DESPAIR
# 3                                     MEH         JOY           MEH
# 4                                 DESPAIR         MEH       DESPAIR
# 6                                     MEH         MEH           MEH
# 7                                     MEH         MEH       DESPAIR
# ...                                   ...         ...           ...
# 2455                              DESPAIR         MEH           JOY
# 2456                                  MEH         JOY       DESPAIR
# 2457                              DESPAIR         MEH           MEH
# 2458                                  MEH         MEH           MEH
# 2459                              DESPAIR     DESPAIR       DESPAIR
#
#      Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 1                                            DESPAIR                   JOY
# 3                                            DESPAIR               DESPAIR
# 4                                            DESPAIR                   JOY
# 6                                                MEH                   MEH
# 7                                            DESPAIR                   JOY
# ...                                              ...                   ...
# 2455                                         DESPAIR                   MEH
# 2456                                         DESPAIR                   MEH
# 2457                                         DESPAIR                   JOY
# 2458                                             MEH                   MEH
# 2459                                         DESPAIR                   JOY
#
#      Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 1                                  JOY        DESPAIR       JOY
# 3                                  JOY            MEH       JOY
# 4                                  JOY        DESPAIR       JOY
# 6                                  MEH            MEH       MEH
# 7                                  MEH        DESPAIR       JOY
# ...                                ...            ...       ...
# 2455                               MEH            JOY       JOY
# 2456                               MEH        DESPAIR       JOY
# 2457                               JOY            MEH       MEH
# 2458                               MEH            MEH       MEH
# 2459                               MEH        DESPAIR   DESPAIR
#
#      Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                                   MEH
# 6                                                   MEH
# 7                                                   JOY
# ...                                                 ...
# 2455                                                MEH
# 2456                                                MEH
# 2457                                                MEH
# 2458                                                MEH
# 2459                                            DESPAIR
#
#      Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 1         DESPAIR                   DESPAIR          DESPAIR
# 3             JOY                       JOY          DESPAIR
# 4             JOY                       JOY          DESPAIR
# 6             MEH                       MEH              MEH
# 7             MEH                   DESPAIR          DESPAIR
# ...           ...                       ...              ...
# 2455          JOY                   DESPAIR              MEH
# 2456          MEH                       JOY          DESPAIR
# 2457          JOY                       MEH          DESPAIR
# 2458          MEH                       MEH              MEH
# 2459          JOY                   DESPAIR              MEH
#
#      Q6 | Whole Wheat anything Q6 | York Peppermint Patties      Q10: DRESS  \
# 1                      DESPAIR                      DESPAIR  White and gold
# 3                      DESPAIR                      DESPAIR  White and gold
# 4                      DESPAIR                          JOY  White and gold
# 6                          MEH                          MEH  White and gold
# 7                      DESPAIR                      DESPAIR  Blue and black
# ...                        ...                          ...             ...
# 2455                   DESPAIR                          MEH  White and gold
# 2456                       MEH                          JOY  Blue and black
# 2457                   DESPAIR                          MEH  Blue and black
# 2458                       MEH                          MEH  White and gold
# 2459                   DESPAIR                          JOY  White and gold
#
#      Q11: DAY  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# 1      Sunday                     41.0                   1.0
# 3      Sunday                     41.0                   1.0
# 4      Friday                     41.0                   1.0
# 6      Friday                     41.0                  41.0
# 7      Friday                     41.0                   1.0
# ...       ...                      ...                   ...
# 2455   Friday                     41.0                  41.0
# 2456   Friday                     41.0                   1.0
# 2457   Friday                     41.0                   1.0
# 2458   Friday                     41.0                  41.0
# 2459   Sunday                      1.0                  41.0
#
#       Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 1                  41.0                41.0                 (84, 25)
# 3                  41.0                41.0                 (75, 23)
# 4                  41.0                41.0                 (70, 10)
# 6                  41.0                41.0                       41
# 7                  41.0                41.0                  (55, 5)
# ...                 ...                 ...                      ...
# 2455               41.0                41.0                       41
# 2456               41.0                41.0                 (70, 26)
# 2457               41.0                41.0                 (67, 35)
# 2458               41.0                41.0                       41
# 2459               41.0                41.0                 (19, 26)
#
# [2248 rows x 115 columns]

# %%
cd.drop(['Q12: MEDIA [Daily Dish]','Q12: MEDIA [Science]','Q12: MEDIA [Yahoo]','Click Coordinates (x, y)'],axis=1,inplace=True)
# Out:
# C:\Users\Laptop Shop\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER  Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male     44.0         USA
# 3        90272840             No       Male     40.0         USA
# 4        90272841             No       Male     23.0         USA
# 6        90272853             No       Male     53.0         USA
# 7        90272854             No       Male     33.0      CANADA
# ...           ...            ...        ...      ...         ...
# 2455     90314359             No       Male     24.0         USA
# 2456     90314580             No     Female     33.0         USA
# 2457     90314634             No     Female     26.0         USA
# 2458     90314658             No       Male     58.0         USA
# 2459     90314802             No     Female     66.0         USA
#
#      Q6 | 100 Grand Bar  \
# 1                   MEH
# 3                   MEH
# 4                   JOY
# 6                   MEH
# 7                   JOY
# ...                 ...
# 2455                JOY
# 2456                MEH
# 2457                MEH
# 2458                MEH
# 2459            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   MEH
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                MEH
# 2459                                            DESPAIR
#
#      Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 1                              JOY              MEH                  DESPAIR
# 3                              JOY              MEH                      MEH
# 4                              JOY          DESPAIR                      MEH
# 6                              MEH              MEH                      MEH
# 7                              JOY          DESPAIR                  DESPAIR
# ...                            ...              ...                      ...
# 2455                           MEH          DESPAIR                  DESPAIR
# 2456                           JOY              MEH                      MEH
# 2457                           JOY          DESPAIR                      MEH
# 2458                           MEH              MEH                      MEH
# 2459                           JOY          DESPAIR                  DESPAIR
#
#      Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 1                          DESPAIR          DESPAIR            DESPAIR
# 3                          DESPAIR              MEH            DESPAIR
# 4                          DESPAIR              MEH            DESPAIR
# 6                              MEH              MEH                MEH
# 7                              MEH              JOY                MEH
# ...                            ...              ...                ...
# 2455                           MEH              MEH            DESPAIR
# 2456                           MEH              MEH            DESPAIR
# 2457                           JOY          DESPAIR                MEH
# 2458                           MEH              MEH                MEH
# 2459                       DESPAIR          DESPAIR                MEH
#
#      Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 1                   DESPAIR           DESPAIR                     MEH
# 3                   DESPAIR               MEH                     MEH
# 4                   DESPAIR               MEH                     MEH
# 6                       MEH               MEH                     MEH
# 7                       JOY               JOY                     JOY
# ...                     ...               ...                     ...
# 2455                DESPAIR               MEH                 DESPAIR
# 2456                DESPAIR               JOY                     JOY
# 2457                    MEH           DESPAIR                     JOY
# 2458                    MEH               MEH                     MEH
# 2459                DESPAIR               JOY                     MEH
#
#      Q6 | Candy Corn  \
# 1                MEH
# 3            DESPAIR
# 4            DESPAIR
# 6                MEH
# 7                JOY
# ...              ...
# 2455         DESPAIR
# 2456             JOY
# 2457         DESPAIR
# 2458             MEH
# 2459             MEH
#
#      Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   MEH
# 7                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                                MEH
# 2458                                                MEH
# 2459                                            DESPAIR
#
#      Q6 | Caramellos Q6 | Cash, or other forms of legal tender  \
# 1                MEH                                       JOY
# 3                MEH                                       JOY
# 4                JOY                                       MEH
# 6                MEH                                       MEH
# 7                JOY                                       JOY
# ...              ...                                       ...
# 2455             JOY                                       JOY
# 2456             JOY                                       JOY
# 2457         DESPAIR                                       JOY
# 2458             MEH                                       MEH
# 2459             MEH                                       JOY
#
#      Q6 | Chardonnay Q6 | Chick-o-Sticks (we don’t know what that is)  \
# 1                MEH                                          DESPAIR
# 3                MEH                                              JOY
# 4                JOY                                          DESPAIR
# 6                MEH                                              MEH
# 7                JOY                                          DESPAIR
# ...              ...                                              ...
# 2455             JOY                                              MEH
# 2456             JOY                                              JOY
# 2457             JOY                                              MEH
# 2458             MEH                                              MEH
# 2459             JOY                                          DESPAIR
#
#      Q6 | Chiclets Q6 | Coffee Crisp  \
# 1          DESPAIR           DESPAIR
# 3              MEH           DESPAIR
# 4          DESPAIR               MEH
# 6              MEH               MEH
# 7              MEH               MEH
# ...            ...               ...
# 2455           JOY               JOY
# 2456       DESPAIR               MEH
# 2457           MEH           DESPAIR
# 2458           MEH               MEH
# 2459           MEH           DESPAIR
#
#      Q6 | Creepy Religious comics/Chick Tracts Q6 | Dental paraphenalia  \
# 1                                      DESPAIR                  DESPAIR
# 3                                      DESPAIR                  DESPAIR
# 4                                      DESPAIR                  DESPAIR
# 6                                          MEH                      MEH
# 7                                      DESPAIR                  DESPAIR
# ...                                        ...                      ...
# 2455                                   DESPAIR                      MEH
# 2456                                   DESPAIR                  DESPAIR
# 2457                                   DESPAIR                  DESPAIR
# 2458                                       MEH                      MEH
# 2459                                   DESPAIR                  DESPAIR
#
#      Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 1          MEH            JOY            DESPAIR
# 3          JOY            JOY                MEH
# 4          MEH            JOY            DESPAIR
# 6          MEH            MEH                MEH
# 7          MEH            MEH                JOY
# ...        ...            ...                ...
# 2455   DESPAIR            JOY                MEH
# 2456   DESPAIR            MEH                MEH
# 2457       MEH            JOY                MEH
# 2458       MEH            MEH                MEH
# 2459       JOY            JOY                MEH
#
#      Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 1                             DESPAIR          DESPAIR               DESPAIR
# 3                                 MEH              JOY                   JOY
# 4                             DESPAIR          DESPAIR                   MEH
# 6                                 MEH              MEH                   MEH
# 7                             DESPAIR          DESPAIR               DESPAIR
# ...                               ...              ...                   ...
# 2455                              JOY          DESPAIR                   JOY
# 2456                              MEH          DESPAIR                   MEH
# 2457                              JOY              JOY               DESPAIR
# 2458                              MEH              MEH                   MEH
# 2459                          DESPAIR              MEH               DESPAIR
#
#      Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 1                    MEH                      DESPAIR
# 3                    MEH                      DESPAIR
# 4                    MEH                      DESPAIR
# 6                    MEH                          MEH
# 7                DESPAIR                      DESPAIR
# ...                  ...                          ...
# 2455                 JOY                          JOY
# 2456             DESPAIR                      DESPAIR
# 2457             DESPAIR                      DESPAIR
# 2458                 MEH                          MEH
# 2459                 JOY                      DESPAIR
#
#      Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 1                             MEH             MEH            DESPAIR
# 3                             JOY             MEH                MEH
# 4                             JOY             MEH            DESPAIR
# 6                             MEH             MEH                MEH
# 7                             JOY         DESPAIR            DESPAIR
# ...                           ...             ...                ...
# 2455                          MEH         DESPAIR                MEH
# 2456                          MEH             MEH            DESPAIR
# 2457                          MEH             MEH            DESPAIR
# 2458                          MEH             MEH                MEH
# 2459                          MEH         DESPAIR            DESPAIR
#
#      Q6 | Heath Bar Q6 | Hershey's Dark Chocolate  \
# 1               MEH                           JOY
# 3           DESPAIR                           MEH
# 4           DESPAIR                           JOY
# 6               MEH                           MEH
# 7           DESPAIR                           JOY
# ...             ...                           ...
# 2455        DESPAIR                           JOY
# 2456            JOY                           MEH
# 2457            MEH                           JOY
# 2458            MEH                           MEH
# 2459        DESPAIR                           JOY
#
#      Q6 | Hershey’s Milk Chocolate Q6 | Hershey's Kisses  \
# 1                              JOY                   MEH
# 3                              MEH                   MEH
# 4                              MEH                   MEH
# 6                              MEH                   MEH
# 7                              MEH                   MEH
# ...                            ...                   ...
# 2455                           MEH                   MEH
# 2456                           JOY                   MEH
# 2457                           JOY                   JOY
# 2458                           MEH                   MEH
# 2459                           JOY                   JOY
#
#      Q6 | Hugs (actual physical hugs) Q6 | Jolly Rancher (bad flavor)  \
# 1                             DESPAIR                         DESPAIR
# 3                                 MEH                             MEH
# 4                             DESPAIR                             MEH
# 6                                 MEH                             MEH
# 7                             DESPAIR                         DESPAIR
# ...                               ...                             ...
# 2455                              JOY                             MEH
# 2456                          DESPAIR                             MEH
# 2457                              MEH                         DESPAIR
# 2458                              MEH                             MEH
# 2459                          DESPAIR                         DESPAIR
#
#      Q6 | Jolly Ranchers (good flavor) Q6 | JoyJoy (Mit Iodine!)  \
# 1                                  MEH                   DESPAIR
# 3                                  MEH                   DESPAIR
# 4                                  JOY                       MEH
# 6                                  MEH                       MEH
# 7                              DESPAIR                   DESPAIR
# ...                                ...                       ...
# 2455                               MEH                       MEH
# 2456                               JOY                       MEH
# 2457                               JOY                   DESPAIR
# 2458                               MEH                       MEH
# 2459                               MEH                   DESPAIR
#
#      Q6 | Junior Mints Q6 | Senior Mints Q6 | Kale smoothie  \
# 1              DESPAIR           DESPAIR            DESPAIR
# 3              DESPAIR           DESPAIR            DESPAIR
# 4                  JOY           DESPAIR            DESPAIR
# 6                  MEH               MEH                MEH
# 7              DESPAIR           DESPAIR            DESPAIR
# ...                ...               ...                ...
# 2455           DESPAIR           DESPAIR                MEH
# 2456               JOY               MEH            DESPAIR
# 2457               JOY               MEH            DESPAIR
# 2458               MEH               MEH                MEH
# 2459               JOY           DESPAIR            DESPAIR
#
#      Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy Q6 | LemonHeads  \
# 1                    DESPAIR          JOY         DESPAIR             MEH
# 3                        MEH          MEH             JOY             JOY
# 4                        JOY          JOY             JOY             JOY
# 6                        MEH          MEH             MEH             MEH
# 7                    DESPAIR          MEH             MEH             JOY
# ...                      ...          ...             ...             ...
# 2455                     JOY          JOY             MEH             MEH
# 2456                     MEH          JOY         DESPAIR         DESPAIR
# 2457                 DESPAIR      DESPAIR             JOY         DESPAIR
# 2458                     MEH          MEH             MEH             MEH
# 2459                 DESPAIR          MEH         DESPAIR         DESPAIR
#
#      Q6 | Licorice (not black) Q6 | Licorice (yes black) Q6 | Lindt Truffle  \
# 1                          MEH                       JOY                MEH
# 3                          MEH                       JOY                JOY
# 4                          MEH                   DESPAIR                JOY
# 6                          MEH                       MEH                MEH
# 7                          MEH                   DESPAIR            DESPAIR
# ...                        ...                       ...                ...
# 2455                       JOY                   DESPAIR                JOY
# 2456                       MEH                   DESPAIR                MEH
# 2457                       MEH                   DESPAIR                JOY
# 2458                       MEH                       MEH                MEH
# 2459                   DESPAIR                   DESPAIR                JOY
#
#      Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike Q6 | Milk Duds  \
# 1           DESPAIR   DESPAIR       DESPAIR               MEH            MEH
# 3           DESPAIR       JOY           MEH               MEH        DESPAIR
# 4               MEH       MEH       DESPAIR               MEH            MEH
# 6               MEH       MEH           MEH               MEH            MEH
# 7               MEH       JOY           JOY               JOY            JOY
# ...             ...       ...           ...               ...            ...
# 2455        DESPAIR       MEH           MEH               MEH            JOY
# 2456            MEH       MEH           MEH           DESPAIR            MEH
# 2457            MEH       JOY       DESPAIR               MEH            JOY
# 2458            MEH       MEH           MEH               MEH            MEH
# 2459        DESPAIR       JOY       DESPAIR               MEH        DESPAIR
#
#      Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s Q6 | Blue M&M's  \
# 1               JOY               JOY               MEH             JOY
# 3               JOY               MEH               JOY             MEH
# 4               JOY               JOY               JOY             JOY
# 6               MEH               MEH               MEH             MEH
# 7               JOY               JOY               JOY             JOY
# ...             ...               ...               ...             ...
# 2455            JOY               MEH               JOY             JOY
# 2456            MEH               JOY               JOY             MEH
# 2457            JOY               JOY           DESPAIR             JOY
# 2458            MEH               MEH               MEH             MEH
# 2459            JOY               JOY               JOY             JOY
#
#      Q6 | Red M&M's Q6 | Green Party M&M's Q6 | Independent M&M's  \
# 1               JOY                    JOY                    JOY
# 3               MEH                    MEH                    MEH
# 4               JOY                    JOY                    JOY
# 6               MEH                    MEH                    MEH
# 7               JOY                    JOY                    MEH
# ...             ...                    ...                    ...
# 2455            MEH                    JOY                    JOY
# 2456            MEH                    MEH                    MEH
# 2457            JOY                    JOY                    JOY
# 2458            MEH                    MEH                    MEH
# 2459            JOY                    JOY                DESPAIR
#
#      Q6 | Abstained from M&M'ing. Q6 | Minibags of chips Q6 | Mint Kisses  \
# 1                         DESPAIR                DESPAIR              MEH
# 3                             MEH                DESPAIR          DESPAIR
# 4                             MEH                DESPAIR              JOY
# 6                             MEH                    MEH              MEH
# 7                         DESPAIR                    JOY          DESPAIR
# ...                           ...                    ...              ...
# 2455                          MEH                    MEH              JOY
# 2456                          MEH                    MEH              JOY
# 2457                      DESPAIR                    JOY              JOY
# 2458                          MEH                    MEH              MEH
# 2459                      DESPAIR                    MEH              MEH
#
#      Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers Q6 | Nerds  \
# 1             DESPAIR          DESPAIR           DESPAIR    DESPAIR
# 3                 MEH              MEH           DESPAIR        MEH
# 4                 JOY              MEH           DESPAIR        JOY
# 6                 MEH              MEH               MEH        MEH
# 7             DESPAIR              MEH               MEH        JOY
# ...               ...              ...               ...        ...
# 2455              JOY              JOY               MEH        MEH
# 2456              MEH              JOY           DESPAIR        JOY
# 2457              JOY          DESPAIR           DESPAIR        MEH
# 2458              MEH              MEH               MEH        MEH
# 2459          DESPAIR              JOY               MEH    DESPAIR
#
#      Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 1                   JOY           DESPAIR    DESPAIR      DESPAIR
# 3                   MEH               MEH    DESPAIR      DESPAIR
# 4                   JOY               JOY        MEH      DESPAIR
# 6                   MEH               MEH        MEH          MEH
# 7                   JOY               MEH    DESPAIR      DESPAIR
# ...                 ...               ...        ...          ...
# 2455                JOY               JOY    DESPAIR      DESPAIR
# 2456                MEH               JOY    DESPAIR      DESPAIR
# 2457            DESPAIR               MEH        MEH          MEH
# 2458                MEH               MEH        MEH          MEH
# 2459                MEH           DESPAIR        MEH      DESPAIR
#
#      Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 1           DESPAIR                                            DESPAIR
# 3           DESPAIR                                            DESPAIR
# 4               JOY                                            DESPAIR
# 6               MEH                                                MEH
# 7           DESPAIR                                            DESPAIR
# ...             ...                                                ...
# 2455            JOY                                                MEH
# 2456            MEH                                            DESPAIR
# 2457            JOY                                                JOY
# 2458            MEH                                                MEH
# 2459        DESPAIR                                            DESPAIR
#
#      Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces  \
# 1                                JOY                 JOY
# 3                                JOY                 MEH
# 4                                JOY                 JOY
# 6                                MEH                 MEH
# 7                                JOY                 JOY
# ...                              ...                 ...
# 2455                             JOY                 JOY
# 2456                             JOY                 JOY
# 2457                             JOY                 MEH
# 2458                             MEH                 MEH
# 2459                             MEH             DESPAIR
#
#      Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 1                    DESPAIR        JOY
# 3                        MEH        MEH
# 4                        MEH        JOY
# 6                        MEH        MEH
# 7                        MEH        JOY
# ...                      ...        ...
# 2455                     JOY        JOY
# 2456                     MEH        MEH
# 2457                     MEH        JOY
# 2458                     MEH        MEH
# 2459                 DESPAIR    DESPAIR
#
#      Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 1                                               DESPAIR         DESPAIR
# 3                                               DESPAIR         DESPAIR
# 4                                                   MEH             JOY
# 6                                                   MEH             MEH
# 7                                               DESPAIR             JOY
# ...                                                 ...             ...
# 2455                                                JOY             MEH
# 2456                                            DESPAIR             JOY
# 2457                                            DESPAIR         DESPAIR
# 2458                                                MEH             MEH
# 2459                                            DESPAIR         DESPAIR
#
#      Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 1                     DESPAIR                      DESPAIR           MEH
# 3                     DESPAIR                          MEH           JOY
# 4                         JOY                      DESPAIR           MEH
# 6                         MEH                          MEH           MEH
# 7                         MEH                          JOY           MEH
# ...                       ...                          ...           ...
# 2455                  DESPAIR                      DESPAIR           JOY
# 2456                  DESPAIR                          MEH           JOY
# 2457                      JOY                          MEH       DESPAIR
# 2458                      MEH                          MEH           MEH
# 2459                      MEH                      DESPAIR           JOY
#
#      Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 1                                              DESPAIR           DESPAIR
# 3                                                  MEH           DESPAIR
# 4                                                  MEH           DESPAIR
# 6                                                  MEH               MEH
# 7                                                  JOY           DESPAIR
# ...                                                ...               ...
# 2455                                               JOY               JOY
# 2456                                               MEH               MEH
# 2457                                           DESPAIR           DESPAIR
# 2458                                               MEH               MEH
# 2459                                               JOY           DESPAIR
#
#      Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 1               MEH          DESPAIR               MEH
# 3               MEH              MEH               JOY
# 4               JOY              JOY               MEH
# 6               MEH              MEH               MEH
# 7               MEH              JOY               JOY
# ...             ...              ...               ...
# 2455            JOY              MEH               JOY
# 2456            MEH              MEH               MEH
# 2457        DESPAIR              JOY           DESPAIR
# 2458            MEH              MEH               MEH
# 2459            MEH              MEH           DESPAIR
#
#      Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 1                                 DESPAIR     DESPAIR       DESPAIR
# 3                                     MEH         JOY           MEH
# 4                                 DESPAIR         MEH       DESPAIR
# 6                                     MEH         MEH           MEH
# 7                                     MEH         MEH       DESPAIR
# ...                                   ...         ...           ...
# 2455                              DESPAIR         MEH           JOY
# 2456                                  MEH         JOY       DESPAIR
# 2457                              DESPAIR         MEH           MEH
# 2458                                  MEH         MEH           MEH
# 2459                              DESPAIR     DESPAIR       DESPAIR
#
#      Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 1                                            DESPAIR                   JOY
# 3                                            DESPAIR               DESPAIR
# 4                                            DESPAIR                   JOY
# 6                                                MEH                   MEH
# 7                                            DESPAIR                   JOY
# ...                                              ...                   ...
# 2455                                         DESPAIR                   MEH
# 2456                                         DESPAIR                   MEH
# 2457                                         DESPAIR                   JOY
# 2458                                             MEH                   MEH
# 2459                                         DESPAIR                   JOY
#
#      Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 1                                  JOY        DESPAIR       JOY
# 3                                  JOY            MEH       JOY
# 4                                  JOY        DESPAIR       JOY
# 6                                  MEH            MEH       MEH
# 7                                  MEH        DESPAIR       JOY
# ...                                ...            ...       ...
# 2455                               MEH            JOY       JOY
# 2456                               MEH        DESPAIR       JOY
# 2457                               JOY            MEH       MEH
# 2458                               MEH            MEH       MEH
# 2459                               MEH        DESPAIR   DESPAIR
#
#      Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                               DESPAIR
# 3                                               DESPAIR
# 4                                                   MEH
# 6                                                   MEH
# 7                                                   JOY
# ...                                                 ...
# 2455                                                MEH
# 2456                                                MEH
# 2457                                                MEH
# 2458                                                MEH
# 2459                                            DESPAIR
#
#      Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 1         DESPAIR                   DESPAIR          DESPAIR
# 3             JOY                       JOY          DESPAIR
# 4             JOY                       JOY          DESPAIR
# 6             MEH                       MEH              MEH
# 7             MEH                   DESPAIR          DESPAIR
# ...           ...                       ...              ...
# 2455          JOY                   DESPAIR              MEH
# 2456          MEH                       JOY          DESPAIR
# 2457          JOY                       MEH          DESPAIR
# 2458          MEH                       MEH              MEH
# 2459          JOY                   DESPAIR              MEH
#
#      Q6 | Whole Wheat anything Q6 | York Peppermint Patties      Q10: DRESS  \
# 1                      DESPAIR                      DESPAIR  White and gold
# 3                      DESPAIR                      DESPAIR  White and gold
# 4                      DESPAIR                          JOY  White and gold
# 6                          MEH                          MEH  White and gold
# 7                      DESPAIR                      DESPAIR  Blue and black
# ...                        ...                          ...             ...
# 2455                   DESPAIR                          MEH  White and gold
# 2456                       MEH                          JOY  Blue and black
# 2457                   DESPAIR                          MEH  Blue and black
# 2458                       MEH                          MEH  White and gold
# 2459                   DESPAIR                          JOY  White and gold
#
#      Q11: DAY  Q12: MEDIA [ESPN]
# 1      Sunday               41.0
# 3      Sunday               41.0
# 4      Friday               41.0
# 6      Friday               41.0
# 7      Friday               41.0
# ...       ...                ...
# 2455   Friday               41.0
# 2456   Friday               41.0
# 2457   Friday               41.0
# 2458   Friday               41.0
# 2459   Sunday               41.0
#
# [2248 rows x 111 columns]

# %%
cdj=[]
cdd=[]
for i in cd6:
    cdj.append( [i,cd[i].value_counts()['DESPAIR']])
    cdd.append( [i,cd[i].value_counts()['JOY']])

# %%
cdj=pd.DataFrame(cdq,columns=['Type','Joy'])
cdd=pd.DataFrame(cdq,columns=['Type','Despair'])
cdj.sort_values(by=['Joy'],inplace=True,ascending=False)
cdd.sort_values(by=['Despair'],inplace=True,ascending=False)

# %%
cdd=cdd.head(10)
cdd
# Out:
#                                                   Type  Despair
# 8                               Q6 | Broken glow stick     1516
# 74   Q6 | Real Housewives of Orange County Season 9...     1378
# 28                        Q6 | Gum from baseball cards     1361
# 100                                   Q6 | White Bread     1357
# 42                                  Q6 | Kale smoothie     1341
# 20                            Q6 | Dental paraphenalia     1334
# 19           Q6 | Creepy Religious comics/Chick Tracts     1308
# 12   Q6 | Candy that is clearly just the stuff give...     1231
# 101                          Q6 | Whole Wheat anything     1205
# 92     Q6 | Those odd marshmallow circus peanut things     1164

# %%
cdj=cdj.head(10)
cdj
# Out:
#                                          Type   Joy
# 2               Q6 | Any full-sized candy bar  1453
# 75            Q6 | Reese’s Peanut Butter Cups  1396
# 44                               Q6 | Kit Kat  1346
# 14  Q6 | Cash, or other forms of legal tender  1346
# 96                                  Q6 | Twix  1322
# 83                              Q6 | Snickers  1301
# 94          Q6 | Tolberone something or other  1231
# 57                          Q6 | Peanut M&M’s  1202
# 49                         Q6 | Lindt Truffle  1190
# 69                         Q6 | Nestle Crunch  1104

# %%
plt.barh(cdj['Type'],cdj['Joy'])
plt.show()

# %%
plt.barh(cdd['Type'],cdd['Despair'])
plt.show()
