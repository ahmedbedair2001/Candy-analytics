# %% [markdown]
# <h2>Importing libraries</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# <h2>Reading Data</h2>

# %%
cd=pd.read_csv('C:/Users/Laptop Shop/Downloads/candyhierarchy2017.csv')

# %%
pd.set_option('display.max_columns',120)
pd.set_option('display.max_rows',120)

# %% [markdown]
# <h2>Exploring Data</h2>

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0        90258773            NaN        NaN     NaN         NaN
# 1        90272821             No       Male      44        USA
# 2        90272829            NaN       Male      49         USA
# 3        90272840             No       Male      40          us
# 4        90272841             No       Male      23         usa
# ...           ...            ...        ...     ...         ...
# 2455     90314359             No       Male      24         USA
# 2456     90314580             No     Female      33         USA
# 2457     90314634             No     Female      26        USA
# 2458     90314658             No       Male      58         Usa
# 2459     90314802             No     Female      66         usa
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                                 NaN                NaN
# 1                                  NM                MEH
# ...

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Columns: 120 entries, Internal ID to Click Coordinates (x, y)
# dtypes: float64(4), int64(1), object(115)
# memory usage: 2.3+ MB

# %%
for i in cd:
    print(cd[i].value_counts())
# Out:
# 90273795    1
# 90277365    1
# 90279452    1
# 90274486    1
# 90277176    1
#            ..
# 90273164    1
# 90275215    1
# 90277264    1
# 90288432    1
# 90277887    1
# Name: Internal ID, Length: 2460, dtype: int64
# No     2038
# Yes     312
# Name: Q1: GOING OUT?, dtype: int64
# Male                  1467
# Female                 839
# I'd rather not say      83
# Other                   30
# Name: Q2: GENDER, dtype: int64
# 40                                                  92
# 34                                                  90
# 37                                                  89
# 43                                                  86
# 42                                                  79
# 36                                                  79
# 35                                                  77
# 38                                                  76
# 44                                                  76
# ...

# %%
cd.duplicated().sum()
# Out:
# 0

# %%
cd['Internal ID'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h2>Dropping na values from q1</h2>

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0        90258773            NaN        NaN     NaN         NaN
# 1        90272821             No       Male      44        USA
# 2        90272829            NaN       Male      49         USA
# 3        90272840             No       Male      40          us
# 4        90272841             No       Male      23         usa
# ...           ...            ...        ...     ...         ...
# 2455     90314359             No       Male      24         USA
# 2456     90314580             No     Female      33         USA
# 2457     90314634             No     Female      26        USA
# 2458     90314658             No       Male      58         Usa
# 2459     90314802             No     Female      66         usa
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                                 NaN                NaN
# 1                                  NM                MEH
# ...

# %% [markdown]
# <h2>Exploring and cleaning data of q2</h2>

# %%
print(cd['Q2: GENDER'].value_counts())
# Out:
# Male                  1467
# Female                 839
# I'd rather not say      83
# Other                   30
# Name: Q2: GENDER, dtype: int64

# %%
print(cd['Q2: GENDER'].isna().sum())
# Out:
# 41

# %%
cd['Q2: GENDER'].fillna('I\'d rather not say',inplace=True)

# %% [markdown]
# <h2>Exploring and cleaning data of q4</h2>

# %%
cd['Q4: COUNTRY'].value_counts()
# Out:
# USA                            699
# United States                  497
# usa                            217
# Canada                         179
# Usa                            139
#                               ...
# Greece                           1
# USA? Hard to tell anymore..      1
# UAE                              1
# UK                               1
# Trumpistan                       1
# Name: Q4: COUNTRY, Length: 128, dtype: int64

# %%
cd['Q4: COUNTRY']=cd['Q4: COUNTRY'].str.upper()
cd['Q4: COUNTRY']=cd['Q4: COUNTRY'].str.strip()
cd['Q4: COUNTRY']=cd['Q4: COUNTRY'].str.replace('.','')

# %%
cd['Q4: COUNTRY'].value_counts()
# Out:
# USA                                                                    1138
# UNITED STATES                                                           592
# CANADA                                                                  224
# US                                                                      194
# UNITED STATES OF AMERICA                                                 73
# UK                                                                       19
# UNITED KINGDOM                                                           14
# GERMANY                                                                  10
# AUSTRALIA                                                                 7
# NETHERLANDS                                                               6
# AMERICA                                                                   6
# SCOTLAND                                                                  5
# ...

# %%
x='USA'
cd['Q4: COUNTRY'].replace({"United States": x , "'MERICA": x,"UNITED STSTES": x,"USA USA USA!!!!": x,"UNITED STATES": x}, inplace=True)

# %%
cd['Q4: COUNTRY'].replace({"US": x , "'MERICA": x,"UNITED STATES OF AMERICA": x,"U S A": x,"US OF A": x,"UNIED STATES": x,"UNITED STATSS": x}, inplace=True)

# %%
cd['Q4: COUNTRY'].replace({"N AMERICA": x , "'MERICA": x,"I PRETEND TO BE FROM CANADA, BUT I AM REALLY FROM THE UNITED STATES": x,"UNITED STATEA": x,"MURICA": x,"UNITED STAES": x,"USA! USA! USA!": x,"UNITES STATES":x}, inplace=True)

# %%
cd['Q4: COUNTRY'].replace({"AHEMAMERCA": x , "USAUSAUSA": x,"THE UNITED STATES": x,"NORTH CAROLINA": x,"EARTH": x,"UNITE STATES": x,"USA? HARD TO TELL ANYMORE": x,"USAS":x}, inplace=True)
cd['Q4: COUNTRY'].replace({"PITTSBURGH": x , "UNITED STATE": x,"UNITED SATES": x,"UNITED STATED": x,"USSA": x,"USAA": x,"USA? HARD TO TELL ANYMORE": x,"USAS":x}, inplace=True)

# %%
cd['Q4: COUNTRY'].replace({"U S": x , "THE UNITED STATES OF AMERICA": x,"SUBSCRIBE TO DM4UZ3 ON YOUTUBE": x,"I DON'T KNOW ANYMORE": x,"FEAR AND LOATHING": x,"MURRIKA":x
        }, inplace=True)

# %%
cd['Q4: COUNTRY'].replace({"45": x , "46": x,"32": x,"36": x,"1": x,"A":x,'ALASKA':x,'NEW JERSEY':x,'INSANITY LATELY':x,'UNHINGED STATES':x
        }, inplace=True)

# %%
cd['Q4: COUNTRY'].unique()
# Out:
# array([nan, 'USA', 'CANADA', 'UK', 'UNITED KINGDOM', 'UAE', 'ENGLAND',
#        'MEXICO', 'AMERICA', '35', 'FRANCE', 'FINLAND', 'NETHERLANDS',
#        'GERMANY', 'EUROPE', 'COSTA RICA', 'CASCADIA', 'AUSTRALIA',
#        'GREECE', 'CAN', 'CANAE', 'NEW YORK', 'TRUMPISTAN', 'IRELAND',
#        'KOREA', 'CALIFORNIA', 'JAPAN', 'SOUTH AFRICA', 'ICELAND',
#        'CANADA`', 'SCOTLAND', 'DENMARK', 'SWITZERLAND', 'UD',
#        'SOUTH KOREA', 'INDONESIA', 'THE NETHERLANDS', 'ENDLAND',
#        'ATLANTIS', 'SOVIET CANUCKISTAN', 'SINGAPORE', 'CHINA', 'TAIWAN',
#        'HONG KONG', 'SPAIN', 'SWEDEN', 'NARNIA'], dtype=object)

# %%
cd['Q4: COUNTRY'].replace({'NARNIA': x ,'AMERICA': x,'CALIFORNIA': x,'NARNIA': x,'UD': x,'35':x
        }, inplace=True)

# %%
y='CANADA'
z='UK'
cd['Q4: COUNTRY'].replace({'CANAE':y,'CAN':y,'UNITED KINGDOM':z,'ENGLAND':z
        }, inplace=True)

# %%
cd[cd['Q4: COUNTRY']=='EUROPE']
# Out:
#      Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 433     90273991            Yes     Female      10      EUROPE
#
#     Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 433                          America            DESPAIR
#
#     Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 433                                                MEH
#
#     Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 433                           JOY              MEH                      MEH
#
#     Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 433                       DESPAIR              MEH            DESPAIR
#
#     Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 433                DESPAIR               JOY                     JOY
#
#     Q6 | Candy Corn  \
# 433         DESPAIR
#
# ...

# %%
cd['Q4: COUNTRY'].replace({'EUROPE':x,'ATLANTIS':x}, inplace=True)

# %%
cd['Q4: COUNTRY'].unique()
# Out:
# array([nan, 'USA', 'CANADA', 'UK', 'UAE', 'MEXICO', 'FRANCE', 'FINLAND',
#        'NETHERLANDS', 'GERMANY', 'COSTA RICA', 'CASCADIA', 'AUSTRALIA',
#        'GREECE', 'NEW YORK', 'TRUMPISTAN', 'IRELAND', 'KOREA', 'JAPAN',
#        'SOUTH AFRICA', 'ICELAND', 'CANADA`', 'SCOTLAND', 'DENMARK',
#        'SWITZERLAND', 'SOUTH KOREA', 'INDONESIA', 'THE NETHERLANDS',
#        'ENDLAND', 'SOVIET CANUCKISTAN', 'SINGAPORE', 'CHINA', 'TAIWAN',
#        'HONG KONG', 'SPAIN', 'SWEDEN'], dtype=object)

# %%
cd.dropna(subset=['Q4: COUNTRY'],inplace=True)

# %%
cd[cd['Q4: COUNTRY']=='SOVIET CANUCKISTAN']
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE         Q4: COUNTRY  \
# 1652     90281296             No       Male      15  SOVIET CANUCKISTAN
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 1652                              NaN                NaN
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1652                                                NaN
#
#      Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 1652                           NaN              NaN                      NaN
#
#      Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 1652                           NaN              NaN                NaN
#
#      Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 1652                    NaN               NaN                     NaN
#
#      Q6 | Candy Corn  \
# 1652             NaN
#
# ...

# %%
cd.drop(index=1652,inplace=True)
cd['Q4: COUNTRY'].unique()
# Out:
# array(['USA', 'CANADA', 'UK', 'UAE', 'MEXICO', 'FRANCE', 'FINLAND',
#        'NETHERLANDS', 'GERMANY', 'COSTA RICA', 'CASCADIA', 'AUSTRALIA',
#        'GREECE', 'NEW YORK', 'TRUMPISTAN', 'IRELAND', 'KOREA', 'JAPAN',
#        'SOUTH AFRICA', 'ICELAND', 'CANADA`', 'SCOTLAND', 'DENMARK',
#        'SWITZERLAND', 'SOUTH KOREA', 'INDONESIA', 'THE NETHERLANDS',
#        'ENDLAND', 'SINGAPORE', 'CHINA', 'TAIWAN', 'HONG KONG', 'SPAIN',
#        'SWEDEN'], dtype=object)

# %%
cd['Q4: COUNTRY'].replace({'TRUMPISTAN':x,'ENDLAND':y}, inplace=True)

# %%
cd['Q4: COUNTRY'].unique()
# Out:
# array(['USA', 'CANADA', 'UK', 'UAE', 'MEXICO', 'FRANCE', 'FINLAND',
#        'NETHERLANDS', 'GERMANY', 'COSTA RICA', 'CASCADIA', 'AUSTRALIA',
#        'GREECE', 'NEW YORK', 'IRELAND', 'KOREA', 'JAPAN', 'SOUTH AFRICA',
#        'ICELAND', 'CANADA`', 'SCOTLAND', 'DENMARK', 'SWITZERLAND',
#        'SOUTH KOREA', 'INDONESIA', 'THE NETHERLANDS', 'SINGAPORE',
#        'CHINA', 'TAIWAN', 'HONG KONG', 'SPAIN', 'SWEDEN'], dtype=object)

# %% [markdown]
# <h2>Exploring and cleaning Data of q3</h2>

# %%
cd['Q3: AGE'].unique()
# Out:
# array(['44', '49', '40', '23', '53', '33', '56', '64', '43', '37', '59',
#        '48', '54', '36', '45', '25', '34', '35', '38', '58', '50', '47',
#        '16', '52', '63', '65', '41', '27', '31', '61', '46', '42', '62',
#        '29', '39', '32', '28', '69', '67', '30', '22', '26', '51', '70',
#        '24', '18', nan, '19', 'Old enough', '57', '60', '66', '12',
#        'Many', '55', '72', '?', '21', '11', 'no', '9', '68', '20', '6',
#        '10', '71', '90', '13', '45-55', '312', '99', '7', 'hahahahaha',
#        '88', '39.4', '74', '102', 'older than dirt', '17', '15', '8',
#        '75', '5u', 'Enough', 'See question 2', '24-50', '14', 'Over 50',
#        '76', '100', '1000', 'sixty-nine', '46 Halloweens.', 'ancient',
#        '77', 'OLD', 'old', '73', '70 1/2', '1', 'MY NAME JEFF', '4',
#        '59 on the day after Halloween', 'old enough', 'your mom',
#        'I can remember when Java was a cool new language', '60+'],
#       dtype=object)

# %%
import random
random.seed()
cd['Q3: AGE'].replace({'sixty-nine':'69','70 1/2':'70','46 Halloweens.':'46','59 on the day after Halloween':'59','39.4':'39',
'45-55':str(np.random.randint(45, 55)),'Over 50':str(np.random.randint(51, 80)),'60+':str(np.random.randint(61, 80))   }, inplace=True)

# %%
cd['Q3: AGE'] = pd.to_numeric(cd['Q3: AGE'], errors='coerce')
cd=cd[(cd['Q3: AGE']<100 )& (cd['Q3: AGE']>9)]

# %%
cd['Q3: AGE'].mean()
# Out:
# 42.25

# %%
cd.fillna(np.random.randint(int(cd['Q3: AGE'].mean()-2*cd['Q3: AGE'].std()),int( cd['Q3: AGE'].mean()+2*cd['Q3: AGE'].std())),inplace=True)

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER  Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male     44.0         USA
# 2        90272829             47       Male     49.0         USA
# 3        90272840             No       Male     40.0         USA
# 4        90272841             No       Male     23.0         USA
# 6        90272853             No       Male     53.0         USA
# ...           ...            ...        ...      ...         ...
# 2455     90314359             No       Male     24.0         USA
# 2456     90314580             No     Female     33.0         USA
# 2457     90314634             No     Female     26.0         USA
# 2458     90314658             No       Male     58.0         USA
# 2459     90314802             No     Female     66.0         USA
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 1                                  NM                MEH
# 2                            Virginia                 47
# ...

# %%
cd['Q3: AGE'].unique()
# Out:
# array([44., 49., 40., 23., 53., 33., 56., 64., 43., 37., 59., 48., 54.,
#        36., 45., 25., 34., 35., 38., 58., 50., 47., 16., 52., 63., 65.,
#        41., 27., 31., 61., 46., 42., 62., 29., 39., 32., 28., 69., 67.,
#        30., 22., 26., 51., 70., 24., 18., 19., 57., 60., 66., 12., 55.,
#        72., 21., 11., 68., 20., 10., 71., 90., 13., 99., 88., 74., 17.,
#        15., 75., 14., 76., 77., 73.])

# %% [markdown]
# <h2>Exploring and cleaning Data of q2</h2>

# %%
cd['Q2: GENDER'].value_counts()
# Out:
# Male                  1421
# Female                 816
# I'd rather not say      72
# Other                   27
# Name: Q2: GENDER, dtype: int64

# %%
cd['Q2: GENDER'].replace({'I\'d rather not say': 'Male' ,'Other':'Male'}, inplace=True)

# %%
cd['Q2: GENDER'].value_counts()
# Out:
# Male      1520
# Female     816
# Name: Q2: GENDER, dtype: int64

# %%
for i in cd:
    print(cd[i].value_counts())
# Out:
# 90273795    1
# 90286107    1
# 90292907    1
# 90274476    1
# 90276525    1
#            ..
# 90275201    1
# 90281346    1
# 90287292    1
# 90277706    1
# 90277887    1
# Name: Internal ID, Length: 2336, dtype: int64
# No     1967
# Yes     286
# 47       83
# Name: Q1: GOING OUT?, dtype: int64
# Male      1520
# Female     816
# Name: Q2: GENDER, dtype: int64
# 40.0    92
# 34.0    90
# 37.0    88
# 43.0    84
# 42.0    79
# 36.0    79
# 35.0    77
# 44.0    76
# 38.0    76
# 33.0    75
# 45.0    75
# 41.0    74
# 50.0    71
# 39.0    70
# 49.0    69
# 32.0    68
# 48.0    64
# 47.0    63
# 30.0    62
# 53.0    58
# 46.0    55
# 52.0    51
# 56.0    46
# 27.0    45
# 31.0    45
# 51.0    41
# 28.0    37
# 54.0    36
# 58.0    34
# 55.0    32
# 60.0    31
# 29.0    27
# 59.0    25
# 57.0    25
# 26.0    23
# 63.0    21
# 61.0    20
# 62.0    20
# 25.0    19
# 64.0    17
# 24.0    16
# 21.0    14
# 65.0    13
# 20.0    12
# 22.0    11
# 18.0    10
# 66.0     9
# 23.0     9
# ...

# %% [markdown]
# <h3>Dropping Useless Columns</h3>

# %%
cd.drop(['Q5: STATE, PROVINCE, COUNTY, ETC','Q7: JOY OTHER','Q8: DESPAIR OTHER','Q9: OTHER COMMENTS'
,'Q12: MEDIA [Daily Dish]','Q12: MEDIA [Science]','Q12: MEDIA [Yahoo]','Click Coordinates (x, y)','Unnamed: 113'],axis=1,inplace=True)

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER  Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male     44.0         USA
# 2        90272829             47       Male     49.0         USA
# 3        90272840             No       Male     40.0         USA
# 4        90272841             No       Male     23.0         USA
# 6        90272853             No       Male     53.0         USA
# ...           ...            ...        ...      ...         ...
# 2455     90314359             No       Male     24.0         USA
# 2456     90314580             No     Female     33.0         USA
# 2457     90314634             No     Female     26.0         USA
# 2458     90314658             No       Male     58.0         USA
# 2459     90314802             No     Female     66.0         USA
#
#      Q6 | 100 Grand Bar  \
# 1                   MEH
# 2                    47
# 3                   MEH
# 4                   JOY
# 6                    47
# ...                 ...
# ...

# %% [markdown]
# <h2>Exploring and cleaning Data of q6</h2>

# %%
cd6=cd.loc[:,'Q6 | 100 Grand Bar':'Q6 | York Peppermint Patties']

# %%
for i in cd6:
         cd6[i]=cd6[i].str.strip()

# %%
cd6
# Out:
#      Q6 | 100 Grand Bar  \
# 1                   MEH
# 2                   NaN
# 3                   MEH
# 4                   JOY
# 6                   NaN
# ...                 ...
# 2455                JOY
# 2456                MEH
# 2457                MEH
# 2458                NaN
# 2459            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                               DESPAIR
# 2                                                   NaN
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   NaN
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                NaN
# ...

# %%
for i in cd6:
     cd6[i].fillna('MEH',inplace=True)
cd6
# Out:
#      Q6 | 100 Grand Bar  \
# 1                   MEH
# 2                   MEH
# 3                   MEH
# 4                   JOY
# 6                   MEH
# ...                 ...
# 2455                JOY
# 2456                MEH
# 2457                MEH
# 2458                MEH
# 2459            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                               DESPAIR
# 2                                                   MEH
# 3                                               DESPAIR
# 4                                               DESPAIR
# 6                                                   MEH
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                MEH
# ...

# %%
cd.loc[:,'Q6 | 100 Grand Bar':'Q6 | York Peppermint Patties']=cd6

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER  Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male     44.0         USA
# 2        90272829             47       Male     49.0         USA
# 3        90272840             No       Male     40.0         USA
# 4        90272841             No       Male     23.0         USA
# 6        90272853             No       Male     53.0         USA
# ...           ...            ...        ...      ...         ...
# 2455     90314359             No       Male     24.0         USA
# 2456     90314580             No     Female     33.0         USA
# 2457     90314634             No     Female     26.0         USA
# 2458     90314658             No       Male     58.0         USA
# 2459     90314802             No     Female     66.0         USA
#
#      Q6 | 100 Grand Bar  \
# 1                   MEH
# 2                   MEH
# 3                   MEH
# 4                   JOY
# 6                   MEH
# ...                 ...
# ...

# %% [markdown]
# <h2>Exploring and cleaning Data of q10,q11</h2>

# %%
cd.loc[:,'Q10: DRESS']=cd.loc[:,'Q10: DRESS'].str.strip()
cd['Q10: DRESS'].fillna(cd['Q10: DRESS'].mode()[0],inplace=True)

# %%
cd.loc[:,'Q11: DAY']=cd.loc[:,'Q11: DAY'].str.strip()
cd['Q11: DAY'].fillna(cd['Q11: DAY'].mode()[0],inplace=True)

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER  Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male     44.0         USA
# 2        90272829             47       Male     49.0         USA
# 3        90272840             No       Male     40.0         USA
# 4        90272841             No       Male     23.0         USA
# 6        90272853             No       Male     53.0         USA
# ...           ...            ...        ...      ...         ...
# 2455     90314359             No       Male     24.0         USA
# 2456     90314580             No     Female     33.0         USA
# 2457     90314634             No     Female     26.0         USA
# 2458     90314658             No       Male     58.0         USA
# 2459     90314802             No     Female     66.0         USA
#
#      Q6 | 100 Grand Bar  \
# 1                   MEH
# 2                   MEH
# 3                   MEH
# 4                   JOY
# 6                   MEH
# ...                 ...
# ...

# %%
cd
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER  Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male     44.0         USA
# 2        90272829             47       Male     49.0         USA
# 3        90272840             No       Male     40.0         USA
# 4        90272841             No       Male     23.0         USA
# 6        90272853             No       Male     53.0         USA
# ...           ...            ...        ...      ...         ...
# 2455     90314359             No       Male     24.0         USA
# 2456     90314580             No     Female     33.0         USA
# 2457     90314634             No     Female     26.0         USA
# 2458     90314658             No       Male     58.0         USA
# 2459     90314802             No     Female     66.0         USA
#
#      Q6 | 100 Grand Bar  \
# 1                   MEH
# 2                   MEH
# 3                   MEH
# 4                   JOY
# 6                   MEH
# ...                 ...
# ...

# %% [markdown]
# <h2>Choosing most 10 loved and hated chocolates</h2>

# %%
cdj=[]
cdd=[]
for i in cd6:
    cdj.append( [i,cd[i].value_counts()['DESPAIR']])
    cdd.append( [i,cd[i].value_counts()['JOY']])

# %%
cdj=pd.DataFrame(cdj,columns=['Type','Joy'])
cdd=pd.DataFrame(cdd,columns=['Type','Despair'])
cdj.sort_values(by=['Joy'],inplace=True,ascending=False)
cdd.sort_values(by=['Despair'],inplace=True,ascending=False)

# %%
cdd=cdd.head(10)
cdd.sort_values(by=['Despair'],inplace=True)
cdd
# Out:
#                                          Type  Despair
# 69                         Q6 | Nestle Crunch     1150
# 49                         Q6 | Lindt Truffle     1232
# 57                          Q6 | Peanut M&M’s     1253
# 94          Q6 | Tolberone something or other     1278
# 83                              Q6 | Snickers     1350
# 96                                  Q6 | Twix     1368
# 14  Q6 | Cash, or other forms of legal tender     1390
# 44                               Q6 | Kit Kat     1393
# 75            Q6 | Reese’s Peanut Butter Cups     1448
# 2               Q6 | Any full-sized candy bar     1507

# %%
cdj=cdj.head(10)
cdj.sort_values(by=['Joy'],inplace=True)
cdj
# Out:
#                                                   Type   Joy
# 92     Q6 | Those odd marshmallow circus peanut things  1208
# 101                          Q6 | Whole Wheat anything  1247
# 12   Q6 | Candy that is clearly just the stuff give...  1282
# 19           Q6 | Creepy Religious comics/Chick Tracts  1357
# 20                            Q6 | Dental paraphenalia  1383
# 42                                  Q6 | Kale smoothie  1389
# 100                                   Q6 | White Bread  1407
# 28                        Q6 | Gum from baseball cards  1413
# 74   Q6 | Real Housewives of Orange County Season 9...  1429
# 8                               Q6 | Broken glow stick  1573

# %% [markdown]
# <h3>Visualizing final results</h3>

# %%
plt.figure(figsize=(10,7))
plt.barh(cdj['Type'],cdj['Joy'])
plt.title('Top 10 loved chocolates')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.barh(cdd['Type'],cdd['Despair'])
plt.title('Top 10 hated chocolates')
plt.show()
